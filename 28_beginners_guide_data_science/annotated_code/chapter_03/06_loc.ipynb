# %% [markdown]
# # 06 — Loc / 06 Loc
#
# **Chapter 03 — File 6 of 9 / 第03章 — 第6个文件（共9个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **This is a list of neighborhoods with higher average sale prices**.
#
# 本脚本演示 **This is a list of neighborhoods with higher average sale prices**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import pandas as pd

Ames = pd.read_csv('Ames.csv')

# %% [markdown]
# ---
# ## Step 2 — This is a list of neighborhoods with higher average sale prices

# %%
high_value_neighborhoods = ['NridgHt', 'NoRidge', 'StoneBr']

# %% [markdown]
# ---
# ## Step 3 — Use df.loc[] to select houses in high-value neighborhoods based on your conditions

# %%
high_value_houses = Ames.loc[(Ames['BedroomAbvGr'] > 3) &
                             (Ames['SalePrice'] < 300000) &
                             (Ames['Neighborhood'].isin(high_value_neighborhoods)),
                             ['Neighborhood', 'SalePrice', 'GrLivArea']]

print(high_value_houses.head())

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: This is a list of neighborhoods with higher average sale prices 是机器学习中的常用技术。
#   *This is a list of neighborhoods with higher average sale prices is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Loc / 06 Loc
# Complete Code / 完整代码
# ===============================

import pandas as pd

Ames = pd.read_csv('Ames.csv')

# This is a list of neighborhoods with higher average sale prices
high_value_neighborhoods = ['NridgHt', 'NoRidge', 'StoneBr']

# Use df.loc[] to select houses in high-value neighborhoods based on your conditions
high_value_houses = Ames.loc[(Ames['BedroomAbvGr'] > 3) &
                             (Ames['SalePrice'] < 300000) &
                             (Ames['Neighborhood'].isin(high_value_neighborhoods)),
                             ['Neighborhood', 'SalePrice', 'GrLivArea']]

print(high_value_houses.head())

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 7 of 9
