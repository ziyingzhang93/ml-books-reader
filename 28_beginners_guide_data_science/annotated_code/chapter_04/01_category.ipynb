# %% [markdown]
# # 01 — Category / 01 Category
#
# **Chapter 04 — File 1 of 8 / 第04章 — 第1个文件（共8个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Load the dataset**.
#
# 本脚本演示 **Load the dataset**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import pandas as pd

# %% [markdown]
# ---
# ## Step 2 — Load the dataset

# %%
Ames = pd.read_csv('Ames.csv')

# %% [markdown]
# ---
# ## Step 3 — Define the quartiles

# %%
quantiles = Ames['SalePrice'].quantile([0.25, 0.5, 0.75])

# %% [markdown]
# ---
# ## Step 4 — Function to categorize each row

# %%
def categorize_by_price(row):
    if row['SalePrice'] <= quantiles.iloc[0]:
        return 'Low'
    elif row['SalePrice'] <= quantiles.iloc[1]:
        return 'Medium'
    elif row['SalePrice'] <= quantiles.iloc[2]:
        return 'High'
    else:
        return 'Premium'

# %% [markdown]
# ---
# ## Step 5 — Apply the function to create a new column

# %%
Ames['Price_Category'] = Ames.apply(categorize_by_price, axis=1)
print(Ames[['SalePrice','Price_Category']])

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Load the dataset 是机器学习中的常用技术。
#   *Load the dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Category / 01 Category
# Complete Code / 完整代码
# ===============================

import pandas as pd

# Load the dataset
Ames = pd.read_csv('Ames.csv')

# Define the quartiles
quantiles = Ames['SalePrice'].quantile([0.25, 0.5, 0.75])

# Function to categorize each row
def categorize_by_price(row):
    if row['SalePrice'] <= quantiles.iloc[0]:
        return 'Low'
    elif row['SalePrice'] <= quantiles.iloc[1]:
        return 'Medium'
    elif row['SalePrice'] <= quantiles.iloc[2]:
        return 'High'
    else:
        return 'Premium'

# Apply the function to create a new column
Ames['Price_Category'] = Ames.apply(categorize_by_price, axis=1)
print(Ames[['SalePrice','Price_Category']])

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 8
