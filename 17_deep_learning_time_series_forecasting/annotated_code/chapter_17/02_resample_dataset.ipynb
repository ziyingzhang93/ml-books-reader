# %% [markdown]
# # 02 — Resample Dataset / 02 Resample Dataset
#
# **Chapter 17 — File 2 of 4 / 第17章 — 第2个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **resample minute data to total for each day for the power usage dataset**.
#
# 本脚本演示 **resample minute data to total for each day for the power usage dataset**。

# %% [markdown]
# ---
# ## Step 1 — resample minute data to total for each day for the power usage dataset

# %%
from pandas import read_csv

# %% [markdown]
# ---
# ## Step 2 — load the new file

# %%
dataset = read_csv('household_power_consumption.csv', header=0, infer_datetime_format=True, parse_dates=['datetime'], index_col=['datetime'])

# %% [markdown]
# ---
# ## Step 3 — resample data to daily

# %%
daily_groups = dataset.resample('D')
daily_data = daily_groups.sum()

# %% [markdown]
# ---
# ## Step 4 — summarize

# %%
print(daily_data.shape)
print(daily_data.head())

# %% [markdown]
# ---
# ## Step 5 — save

# %%
daily_data.to_csv('household_power_consumption_days.csv')

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: resample minute data to total for each day for the power usage dataset 是机器学习中的常用技术。
#   *resample minute data to total for each day for the power usage dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Resample Dataset / 02 Resample Dataset
# Complete Code / 完整代码
# ===============================

# resample minute data to total for each day for the power usage dataset
from pandas import read_csv
# load the new file
dataset = read_csv('household_power_consumption.csv', header=0, infer_datetime_format=True, parse_dates=['datetime'], index_col=['datetime'])
# resample data to daily
daily_groups = dataset.resample('D')
daily_data = daily_groups.sum()
# summarize
print(daily_data.shape)
print(daily_data.head())
# save
daily_data.to_csv('household_power_consumption_days.csv')

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 4
