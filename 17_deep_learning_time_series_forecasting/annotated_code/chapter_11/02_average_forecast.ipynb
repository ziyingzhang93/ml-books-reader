# %% [markdown]
# # 02 — Average Forecast / 预测
#
# **Chapter 11 — File 2 of 12 / 第11章 — 第2个文件（共12个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of an average forecast**.
#
# 本脚本演示 **example of an average forecast**。

# %% [markdown]
# ---
# ## Step 1 — example of an average forecast

# %%
from numpy import mean
from numpy import median

# %% [markdown]
# ---
# ## Step 2 — one-step average forecast

# %%
def average_forecast(history, config):
	n, avg_type = config

# %% [markdown]
# ---
# ## Step 3 — mean of last n values

# %%
if avg_type is 'mean':
		return mean(history[-n:])

# %% [markdown]
# ---
# ## Step 4 — median of last n values

# %%
return median(history[-n:])

# %% [markdown]
# ---
# ## Step 5 — define dataset

# %%
data = [10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0]
print(data)

# %% [markdown]
# ---
# ## Step 6 — test naive forecast

# %%
for i in range(1, len(data)+1):
	print(average_forecast(data, (i, 'mean')))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of an average forecast 是机器学习中的常用技术。
#   *example of an average forecast is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Average Forecast / 预测
# Complete Code / 完整代码
# ===============================

# example of an average forecast
from numpy import mean
from numpy import median

# one-step average forecast
def average_forecast(history, config):
	n, avg_type = config
	# mean of last n values
	if avg_type is 'mean':
		return mean(history[-n:])
	# median of last n values
	return median(history[-n:])

# define dataset
data = [10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0]
print(data)
# test naive forecast
for i in range(1, len(data)+1):
	print(average_forecast(data, (i, 'mean')))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 12
