# %% [markdown]
# # 04 — Plots Of Monthly Power Consumption / 04 Plots Of Monthly Power Consumption
#
# **Chapter 16 — File 4 of 8 / 第16章 — 第4个文件（共8个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **monthly line plots for power usage dataset**.
#
# 本脚本演示 **monthly line plots for power usage dataset**。

# %% [markdown]
# ---
# ## Step 1 — monthly line plots for power usage dataset

# %%
from pandas import read_csv
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — load the new file

# %%
dataset = read_csv('household_power_consumption.csv', header=0, infer_datetime_format=True, parse_dates=['datetime'], index_col=['datetime'])

# %% [markdown]
# ---
# ## Step 3 — plot active power for each year

# %%
months = [x for x in range(1, 13)]
pyplot.figure()
for i in range(len(months)):

# %% [markdown]
# ---
# ## Step 4 — prepare subplot

# %%
ax = pyplot.subplot(len(months), 1, i+1)

# %% [markdown]
# ---
# ## Step 5 — determine the month to plot

# %%
month = '2007-' + str(months[i])

# %% [markdown]
# ---
# ## Step 6 — get all observations for the month

# %%
result = dataset[month]

# %% [markdown]
# ---
# ## Step 7 — plot the active power for the month

# %%
pyplot.plot(result['Global_active_power'])

# %% [markdown]
# ---
# ## Step 8 — add a title to the subplot

# %%
pyplot.title(month, y=0, loc='left')

# %% [markdown]
# ---
# ## Step 9 — turn off ticks to remove clutter

# %%
pyplot.yticks([])
	pyplot.xticks([])
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: monthly line plots for power usage dataset 是机器学习中的常用技术。
#   *monthly line plots for power usage dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Plots Of Monthly Power Consumption / 04 Plots Of Monthly Power Consumption
# Complete Code / 完整代码
# ===============================

# monthly line plots for power usage dataset
from pandas import read_csv
from matplotlib import pyplot
# load the new file
dataset = read_csv('household_power_consumption.csv', header=0, infer_datetime_format=True, parse_dates=['datetime'], index_col=['datetime'])
# plot active power for each year
months = [x for x in range(1, 13)]
pyplot.figure()
for i in range(len(months)):
	# prepare subplot
	ax = pyplot.subplot(len(months), 1, i+1)
	# determine the month to plot
	month = '2007-' + str(months[i])
	# get all observations for the month
	result = dataset[month]
	# plot the active power for the month
	pyplot.plot(result['Global_active_power'])
	# add a title to the subplot
	pyplot.title(month, y=0, loc='left')
	# turn off ticks to remove clutter
	pyplot.yticks([])
	pyplot.xticks([])
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 8
