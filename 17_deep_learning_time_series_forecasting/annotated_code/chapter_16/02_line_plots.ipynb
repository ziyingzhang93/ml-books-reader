# %% [markdown]
# # 02 — Line Plots / 02 Line Plots
#
# **Chapter 16 — File 2 of 8 / 第16章 — 第2个文件（共8个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **line plots for power usage dataset**.
#
# 本脚本演示 **line plots for power usage dataset**。

# %% [markdown]
# ---
# ## Step 1 — line plots for power usage dataset

# %%
from pandas import read_csv
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — load the new file

# %%
dataset = read_csv('household_power_consumption.csv', header=0, infer_datetime_format=True, parse_dates=['datetime'], index_col=['datetime'])

# %% [markdown]
# ---
# ## Step 3 — line plot for each variable

# %%
pyplot.figure()
for i in range(len(dataset.columns)):

# %% [markdown]
# ---
# ## Step 4 — create subplot

# %%
pyplot.subplot(len(dataset.columns), 1, i+1)

# %% [markdown]
# ---
# ## Step 5 — get variable name

# %%
name = dataset.columns[i]

# %% [markdown]
# ---
# ## Step 6 — plot data

# %%
pyplot.plot(dataset[name])

# %% [markdown]
# ---
# ## Step 7 — set title

# %%
pyplot.title(name, y=0)

# %% [markdown]
# ---
# ## Step 8 — turn off ticks to remove clutter

# %%
pyplot.yticks([])
	pyplot.xticks([])
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: line plots for power usage dataset 是机器学习中的常用技术。
#   *line plots for power usage dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Line Plots / 02 Line Plots
# Complete Code / 完整代码
# ===============================

# line plots for power usage dataset
from pandas import read_csv
from matplotlib import pyplot
# load the new file
dataset = read_csv('household_power_consumption.csv', header=0, infer_datetime_format=True, parse_dates=['datetime'], index_col=['datetime'])
# line plot for each variable
pyplot.figure()
for i in range(len(dataset.columns)):
	# create subplot
	pyplot.subplot(len(dataset.columns), 1, i+1)
	# get variable name
	name = dataset.columns[i]
	# plot data
	pyplot.plot(dataset[name])
	# set title
	pyplot.title(name, y=0)
	# turn off ticks to remove clutter
	pyplot.yticks([])
	pyplot.xticks([])
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 8
