# %% [markdown]
# # 03 — Plots Of Yearly Power Consumption / 03 Plots Of Yearly Power Consumption
#
# **Chapter 16 — File 3 of 8 / 第16章 — 第3个文件（共8个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **yearly line plots for power usage dataset**.
#
# 本脚本演示 **yearly line plots for power usage dataset**。

# %% [markdown]
# ---
# ## Step 1 — yearly line plots for power usage dataset

# %%
from pandas import read_csv
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — load the new file

# %%
dataset = read_csv('household_power_consumption.csv', header=0, infer_datetime_format=True, parse_dates=['datetime'], index_col=['datetime'])

# %% [markdown]
# ---
# ## Step 3 — plot active power for each year

# %%
years = ['2007', '2008', '2009', '2010']
pyplot.figure()
for i in range(len(years)):

# %% [markdown]
# ---
# ## Step 4 — prepare subplot

# %%
ax = pyplot.subplot(len(years), 1, i+1)

# %% [markdown]
# ---
# ## Step 5 — determine the year to plot

# %%
year = years[i]

# %% [markdown]
# ---
# ## Step 6 — get all observations for the year

# %%
result = dataset[str(year)]

# %% [markdown]
# ---
# ## Step 7 — plot the active power for the year

# %%
pyplot.plot(result['Global_active_power'])

# %% [markdown]
# ---
# ## Step 8 — add a title to the subplot

# %%
pyplot.title(str(year), y=0, loc='left')

# %% [markdown]
# ---
# ## Step 9 — turn off ticks to remove clutter

# %%
pyplot.yticks([])
	pyplot.xticks([])
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: yearly line plots for power usage dataset 是机器学习中的常用技术。
#   *yearly line plots for power usage dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Plots Of Yearly Power Consumption / 03 Plots Of Yearly Power Consumption
# Complete Code / 完整代码
# ===============================

# yearly line plots for power usage dataset
from pandas import read_csv
from matplotlib import pyplot
# load the new file
dataset = read_csv('household_power_consumption.csv', header=0, infer_datetime_format=True, parse_dates=['datetime'], index_col=['datetime'])
# plot active power for each year
years = ['2007', '2008', '2009', '2010']
pyplot.figure()
for i in range(len(years)):
	# prepare subplot
	ax = pyplot.subplot(len(years), 1, i+1)
	# determine the year to plot
	year = years[i]
	# get all observations for the year
	result = dataset[str(year)]
	# plot the active power for the year
	pyplot.plot(result['Global_active_power'])
	# add a title to the subplot
	pyplot.title(str(year), y=0, loc='left')
	# turn off ticks to remove clutter
	pyplot.yticks([])
	pyplot.xticks([])
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 8
