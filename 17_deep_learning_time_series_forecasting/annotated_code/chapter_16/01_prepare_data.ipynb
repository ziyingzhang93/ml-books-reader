# %% [markdown]
# # 01 — Prepare Data / 数据准备
#
# **Chapter 16 — File 1 of 8 / 第16章 — 第1个文件（共8个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **load and clean-up power usage data**.
#
# 本脚本演示 **load and clean-up power usage data**。

# %% [markdown]
# ---
# ## Step 1 — load and clean-up power usage data

# %%
from numpy import nan
from pandas import read_csv

# %% [markdown]
# ---
# ## Step 2 — load all data

# %%
dataset = read_csv('household_power_consumption.txt', sep=';', header=0, low_memory=False, infer_datetime_format=True, parse_dates={'datetime':[0,1]}, index_col=['datetime'])

# %% [markdown]
# ---
# ## Step 3 — summarize

# %%
print(dataset.shape)
print(dataset.head())

# %% [markdown]
# ---
# ## Step 4 — mark all missing values

# %%
dataset.replace('?', nan, inplace=True)

# %% [markdown]
# ---
# ## Step 5 — add a column for the remainder of sub metering

# %%
values = dataset.values.astype('float32')
dataset['sub_metering_4'] = (values[:,0] * 1000 / 60) - (values[:,4] + values[:,5] + values[:,6])

# %% [markdown]
# ---
# ## Step 6 — save updated dataset

# %%
dataset.to_csv('household_power_consumption.csv')

# %% [markdown]
# ---
# ## Step 7 — load the new dataset and summarize

# %%
dataset = read_csv('household_power_consumption.csv', header=0, infer_datetime_format=True, parse_dates=['datetime'], index_col=['datetime'])
print(dataset.head())

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: load and clean-up power usage data 是机器学习中的常用技术。
#   *load and clean-up power usage data is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Prepare Data / 数据准备
# Complete Code / 完整代码
# ===============================

# load and clean-up power usage data
from numpy import nan
from pandas import read_csv
# load all data
dataset = read_csv('household_power_consumption.txt', sep=';', header=0, low_memory=False, infer_datetime_format=True, parse_dates={'datetime':[0,1]}, index_col=['datetime'])
# summarize
print(dataset.shape)
print(dataset.head())
# mark all missing values
dataset.replace('?', nan, inplace=True)
# add a column for the remainder of sub metering
values = dataset.values.astype('float32')
dataset['sub_metering_4'] = (values[:,0] * 1000 / 60) - (values[:,4] + values[:,5] + values[:,6])
# save updated dataset
dataset.to_csv('household_power_consumption.csv')
# load the new dataset and summarize
dataset = read_csv('household_power_consumption.csv', header=0, infer_datetime_format=True, parse_dates=['datetime'], index_col=['datetime'])
print(dataset.head())

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 8
