# %% [markdown]
# # 01 — Load Dataset / 01 Load Dataset
#
# **Chapter 15 — File 1 of 5 / 第15章 — 第1个文件（共5个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **load and plot monthly airline passengers dataset**.
#
# 本脚本演示 **load and plot monthly airline passengers dataset**。

# %% [markdown]
# ---
# ## Step 1 — load and plot monthly airline passengers dataset

# %%
from pandas import read_csv
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — load

# %%
series = read_csv('monthly-airline-passengers.csv', header=0, index_col=0)

# %% [markdown]
# ---
# ## Step 3 — summarize shape

# %%
print(series.shape)

# %% [markdown]
# ---
# ## Step 4 — plot

# %%
pyplot.plot(series)
pyplot.xticks([])
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: load and plot monthly airline passengers dataset 是机器学习中的常用技术。
#   *load and plot monthly airline passengers dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Load Dataset / 01 Load Dataset
# Complete Code / 完整代码
# ===============================

# load and plot monthly airline passengers dataset
from pandas import read_csv
from matplotlib import pyplot
# load
series = read_csv('monthly-airline-passengers.csv', header=0, index_col=0)
# summarize shape
print(series.shape)
# plot
pyplot.plot(series)
pyplot.xticks([])
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 5
