# %% [markdown]
# # 03 — Example Load Data / 03 Example Load Data
#
# **Chapter 06 — File 3 of 7 / 第06章 — 第3个文件（共7个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of defining a dataset**.
#
# 本脚本演示 **example of defining a dataset**。

# %% [markdown]
# ---
# ## Step 1 — example of defining a dataset

# %%
from numpy import array

# %% [markdown]
# ---
# ## Step 2 — define the dataset

# %%
data = list()
n = 5000
for i in range(n):
	data.append([i+1, (i+1)*10])
data = array(data)
print(data[:5, :])
print(data.shape)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of defining a dataset 是机器学习中的常用技术。
#   *example of defining a dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Example Load Data / 03 Example Load Data
# Complete Code / 完整代码
# ===============================

# example of defining a dataset
from numpy import array

# define the dataset
data = list()
n = 5000
for i in range(n):
	data.append([i+1, (i+1)*10])
data = array(data)
print(data[:5, :])
print(data.shape)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 7
