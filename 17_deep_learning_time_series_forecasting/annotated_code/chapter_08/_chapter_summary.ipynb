# %% [markdown]
# # Chapter 08 Summary / 第08章总结
#
# ## Theme / 主题: Chapter 08 / Chapter 08
#
# This chapter contains **15 code files** demonstrating chapter 08.
#
# 本章包含 **15 个代码文件**，演示Chapter 08。

# %% [markdown]
# ---
# ## Evolution / 演化路线
#
#   1. `01_univariate_dataset.ipynb` — Univariate Dataset
#   2. `02_cnn_univariate.ipynb` — Cnn Univariate
#   3. `03_dependent_time_series_dataset.ipynb` — Dependent Time Series Dataset
#   4. `04_split_samples_dependent_time_series.ipynb` — Split Samples Dependent Time Series
#   5. `05_cnn_multivariate_dependent_series.ipynb` — Cnn Multivariate Dependent Series
#   6. `06_multiheaded_cnn_multivariate_dependent_series.ipynb` — Multiheaded Cnn Multivariate Dependent Series
#   7. `07_split_parallel_series.ipynb` — Split Parallel Series
#   8. `08_cnn_multivariate_parallel_series.ipynb` — Cnn Multivariate Parallel Series
#   9. `09_multi_output_cnn_multivariate_parallel_series.ipynb` — Multi Output Cnn Multivariate Parallel Series
#   10. `10_multi_step_dataset.ipynb` — Multi Step Dataset
#   11. `11_vector_cnn_multi_step.ipynb` — Vector Cnn Multi Step
#   12. `12_multivariate_multistep_dependent_dataset.ipynb` — Multivariate Multistep Dependent Dataset
#   13. `13_cnn_multivariate_dependent_multistep.ipynb` — Cnn Multivariate Dependent Multistep
#   14. `14_multivariate_multistep_parallel_dataset.ipynb` — Multivariate Multistep Parallel Dataset
#   15. `15_cnn_multivariate_parallel_multistep.ipynb` — Cnn Multivariate Parallel Multistep

# %% [markdown]
# ---
# ## ML Relevance / ML 关联
#
# The techniques in this chapter (Chapter 08) are fundamental building blocks in machine learning pipelines.
#
# 本章技术（Chapter 08）是机器学习流水线中的基础构建块。
