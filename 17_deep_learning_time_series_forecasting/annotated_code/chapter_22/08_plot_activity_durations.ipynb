# %% [markdown]
# # 08 — Plot Activity Durations / 08 Plot Activity Durations
#
# **Chapter 22 — File 8 of 8 / 第22章 — 第8个文件（共8个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **plot durations of each activity by subject from the har dataset**.
#
# 本脚本演示 **plot durations of each activity by subject from the har dataset**。

# %% [markdown]
# ---
# ## Step 1 — plot durations of each activity by subject from the har dataset

# %%
from numpy import dstack
from numpy import unique
from pandas import read_csv
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — load a single file as a numpy array

# %%
def load_file(filepath):
	dataframe = read_csv(filepath, header=None, delim_whitespace=True)
	return dataframe.values

# %% [markdown]
# ---
# ## Step 3 — load a list of files, such as x, y, z data for a given variable

# %%
def load_group(filenames, prefix=''):
	loaded = list()
	for name in filenames:
		data = load_file(prefix + name)
		loaded.append(data)

# %% [markdown]
# ---
# ## Step 4 — stack group so that features are the 3rd dimension

# %%
loaded = dstack(loaded)
	return loaded

# %% [markdown]
# ---
# ## Step 5 — load a dataset group, such as train or test

# %%
def load_dataset(group, prefix=''):
	filepath = prefix + group + '/Inertial Signals/'

# %% [markdown]
# ---
# ## Step 6 — load all 9 files as a single array

# %%
filenames = list()

# %% [markdown]
# ---
# ## Step 7 — total acceleration

# %%
filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']

# %% [markdown]
# ---
# ## Step 8 — body acceleration

# %%
filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']

# %% [markdown]
# ---
# ## Step 9 — body gyroscope

# %%
filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']

# %% [markdown]
# ---
# ## Step 10 — load input data

# %%
X = load_group(filenames, filepath)

# %% [markdown]
# ---
# ## Step 11 — load class output

# %%
y = load_file(prefix + group + '/y_'+group+'.txt')
	return X, y

# %% [markdown]
# ---
# ## Step 12 — get all data for one subject

# %%
def data_for_subject(X, y, sub_map, sub_id):

# %% [markdown]
# ---
# ## Step 13 — get row indexes for the subject id

# %%
ix = [i for i in range(len(sub_map)) if sub_map[i]==sub_id]

# %% [markdown]
# ---
# ## Step 14 — return the selected samples

# %%
return X[ix, :, :], y[ix]

# %% [markdown]
# ---
# ## Step 15 — convert a series of windows to a 1D list

# %%
def to_series(windows):
	series = list()
	for window in windows:

# %% [markdown]
# ---
# ## Step 16 — remove the overlap from the window

# %%
half = int(len(window) / 2) - 1
		for value in window[-half:]:
			series.append(value)
	return series

# %% [markdown]
# ---
# ## Step 17 — group data by activity

# %%
def data_by_activity(X, y, activities):

# %% [markdown]
# ---
# ## Step 18 — group windows by activity

# %%
return {a:X[y[:,0]==a, :, :] for a in activities}

# %% [markdown]
# ---
# ## Step 19 — plot activity durations by subject

# %%
def plot_activity_durations_by_subject(X, y, sub_map):

# %% [markdown]
# ---
# ## Step 20 — get unique subjects and activities

# %%
subject_ids = unique(sub_map[:,0])
	activity_ids = unique(y[:,0])

# %% [markdown]
# ---
# ## Step 21 — enumerate subjects

# %%
activity_windows = {a:list() for a in activity_ids}
	for sub_id in subject_ids:

# %% [markdown]
# ---
# ## Step 22 — get data for one subject

# %%
_, subj_y = data_for_subject(X, y, sub_map, sub_id)

# %% [markdown]
# ---
# ## Step 23 — count windows by activity

# %%
for a in activity_ids:
			activity_windows[a].append(len(subj_y[subj_y[:,0]==a]))

# %% [markdown]
# ---
# ## Step 24 — organize durations into a list of lists

# %%
durations = [activity_windows[a] for a in activity_ids]
	pyplot.boxplot(durations, labels=activity_ids)
	pyplot.show()

# %% [markdown]
# ---
# ## Step 25 — load training dataset

# %%
X, y = load_dataset('train', 'HARDataset/')

# %% [markdown]
# ---
# ## Step 26 — load mapping of rows to subjects

# %%
sub_map = load_file('HARDataset/train/subject_train.txt')

# %% [markdown]
# ---
# ## Step 27 — plot durations

# %%
plot_activity_durations_by_subject(X, y, sub_map)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: plot durations of each activity by subject from the har dataset 是机器学习中的常用技术。
#   *plot durations of each activity by subject from the har dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Plot Activity Durations / 08 Plot Activity Durations
# Complete Code / 完整代码
# ===============================

# plot durations of each activity by subject from the har dataset
from numpy import dstack
from numpy import unique
from pandas import read_csv
from matplotlib import pyplot

# load a single file as a numpy array
def load_file(filepath):
	dataframe = read_csv(filepath, header=None, delim_whitespace=True)
	return dataframe.values

# load a list of files, such as x, y, z data for a given variable
def load_group(filenames, prefix=''):
	loaded = list()
	for name in filenames:
		data = load_file(prefix + name)
		loaded.append(data)
	# stack group so that features are the 3rd dimension
	loaded = dstack(loaded)
	return loaded

# load a dataset group, such as train or test
def load_dataset(group, prefix=''):
	filepath = prefix + group + '/Inertial Signals/'
	# load all 9 files as a single array
	filenames = list()
	# total acceleration
	filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
	# body acceleration
	filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
	# body gyroscope
	filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
	# load input data
	X = load_group(filenames, filepath)
	# load class output
	y = load_file(prefix + group + '/y_'+group+'.txt')
	return X, y

# get all data for one subject
def data_for_subject(X, y, sub_map, sub_id):
	# get row indexes for the subject id
	ix = [i for i in range(len(sub_map)) if sub_map[i]==sub_id]
	# return the selected samples
	return X[ix, :, :], y[ix]

# convert a series of windows to a 1D list
def to_series(windows):
	series = list()
	for window in windows:
		# remove the overlap from the window
		half = int(len(window) / 2) - 1
		for value in window[-half:]:
			series.append(value)
	return series

# group data by activity
def data_by_activity(X, y, activities):
	# group windows by activity
	return {a:X[y[:,0]==a, :, :] for a in activities}

# plot activity durations by subject
def plot_activity_durations_by_subject(X, y, sub_map):
	# get unique subjects and activities
	subject_ids = unique(sub_map[:,0])
	activity_ids = unique(y[:,0])
	# enumerate subjects
	activity_windows = {a:list() for a in activity_ids}
	for sub_id in subject_ids:
		# get data for one subject
		_, subj_y = data_for_subject(X, y, sub_map, sub_id)
		# count windows by activity
		for a in activity_ids:
			activity_windows[a].append(len(subj_y[subj_y[:,0]==a]))
	# organize durations into a list of lists
	durations = [activity_windows[a] for a in activity_ids]
	pyplot.boxplot(durations, labels=activity_ids)
	pyplot.show()

# load training dataset
X, y = load_dataset('train', 'HARDataset/')
# load mapping of rows to subjects
sub_map = load_file('HARDataset/train/subject_train.txt')
# plot durations
plot_activity_durations_by_subject(X, y, sub_map)
