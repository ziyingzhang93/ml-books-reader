# %% [markdown]
# # 03 — Load All Files / 03 Load All Files
#
# **Chapter 22 — File 3 of 8 / 第22章 — 第3个文件（共8个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **load all train and test data from the har dataset**.
#
# 本脚本演示 **load all train and test data from the har dataset**。

# %% [markdown]
# ---
# ## Step 1 — load all train and test data from the har dataset

# %%
from numpy import dstack
from pandas import read_csv

# %% [markdown]
# ---
# ## Step 2 — load a single file as a numpy array

# %%
def load_file(filepath):
	dataframe = read_csv(filepath, header=None, delim_whitespace=True)
	return dataframe.values

# %% [markdown]
# ---
# ## Step 3 — load a list of files, such as x, y, z data for a given variable

# %%
def load_group(filenames, prefix=''):
	loaded = list()
	for name in filenames:
		data = load_file(prefix + name)
		loaded.append(data)

# %% [markdown]
# ---
# ## Step 4 — stack group so that features are the 3rd dimension

# %%
loaded = dstack(loaded)
	return loaded

# %% [markdown]
# ---
# ## Step 5 — load a dataset group, such as train or test

# %%
def load_dataset(group, prefix=''):
	filepath = prefix + group + '/Inertial Signals/'

# %% [markdown]
# ---
# ## Step 6 — load all 9 files as a single array

# %%
filenames = list()

# %% [markdown]
# ---
# ## Step 7 — total acceleration

# %%
filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']

# %% [markdown]
# ---
# ## Step 8 — body acceleration

# %%
filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']

# %% [markdown]
# ---
# ## Step 9 — body gyroscope

# %%
filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']

# %% [markdown]
# ---
# ## Step 10 — load input data

# %%
X = load_group(filenames, filepath)

# %% [markdown]
# ---
# ## Step 11 — load class output

# %%
y = load_file(prefix + group + '/y_'+group+'.txt')
	return X, y

# %% [markdown]
# ---
# ## Step 12 — load all train

# %%
trainX, trainy = load_dataset('train', 'HARDataset/')
print(trainX.shape, trainy.shape)

# %% [markdown]
# ---
# ## Step 13 — load all test

# %%
testX, testy = load_dataset('test', 'HARDataset/')
print(testX.shape, testy.shape)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: load all train and test data from the har dataset 是机器学习中的常用技术。
#   *load all train and test data from the har dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Load All Files / 03 Load All Files
# Complete Code / 完整代码
# ===============================

# load all train and test data from the har dataset
from numpy import dstack
from pandas import read_csv

# load a single file as a numpy array
def load_file(filepath):
	dataframe = read_csv(filepath, header=None, delim_whitespace=True)
	return dataframe.values

# load a list of files, such as x, y, z data for a given variable
def load_group(filenames, prefix=''):
	loaded = list()
	for name in filenames:
		data = load_file(prefix + name)
		loaded.append(data)
	# stack group so that features are the 3rd dimension
	loaded = dstack(loaded)
	return loaded

# load a dataset group, such as train or test
def load_dataset(group, prefix=''):
	filepath = prefix + group + '/Inertial Signals/'
	# load all 9 files as a single array
	filenames = list()
	# total acceleration
	filenames += ['total_acc_x_'+group+'.txt', 'total_acc_y_'+group+'.txt', 'total_acc_z_'+group+'.txt']
	# body acceleration
	filenames += ['body_acc_x_'+group+'.txt', 'body_acc_y_'+group+'.txt', 'body_acc_z_'+group+'.txt']
	# body gyroscope
	filenames += ['body_gyro_x_'+group+'.txt', 'body_gyro_y_'+group+'.txt', 'body_gyro_z_'+group+'.txt']
	# load input data
	X = load_group(filenames, filepath)
	# load class output
	y = load_file(prefix + group + '/y_'+group+'.txt')
	return X, y

# load all train
trainX, trainy = load_dataset('train', 'HARDataset/')
print(trainX.shape, trainy.shape)
# load all test
testX, testy = load_dataset('test', 'HARDataset/')
print(testX.shape, testy.shape)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 8
