# %% [markdown]
# # 02 — Mlp Univariate / 单变量
#
# **Chapter 07 — File 2 of 15 / 第07章 — 第2个文件（共15个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **univariate mlp example**.
#
# 本脚本演示 **univariate mlp example**。

# %% [markdown]
# ---
# ## Step 1 — univariate mlp example

# %%
from numpy import array
from keras.models import Sequential
from keras.layers import Dense

# %% [markdown]
# ---
# ## Step 2 — split a univariate sequence into samples

# %%
def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):

# %% [markdown]
# ---
# ## Step 3 — find the end of this pattern

# %%
end_ix = i + n_steps

# %% [markdown]
# ---
# ## Step 4 — check if we are beyond the sequence

# %%
if end_ix > len(sequence)-1:
			break

# %% [markdown]
# ---
# ## Step 5 — gather input and output parts of the pattern

# %%
seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# %% [markdown]
# ---
# ## Step 6 — define input sequence

# %%
raw_seq = [10, 20, 30, 40, 50, 60, 70, 80, 90]

# %% [markdown]
# ---
# ## Step 7 — choose a number of time steps

# %%
n_steps = 3

# %% [markdown]
# ---
# ## Step 8 — split into samples

# %%
X, y = split_sequence(raw_seq, n_steps)

# %% [markdown]
# ---
# ## Step 9 — define model

# %%
model = Sequential()
model.add(Dense(100, activation='relu', input_dim=n_steps))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# ---
# ## Step 10 — fit model

# %%
model.fit(X, y, epochs=2000, verbose=0)

# %% [markdown]
# ---
# ## Step 11 — demonstrate prediction

# %%
x_input = array([70, 80, 90])
x_input = x_input.reshape((1, n_steps))
yhat = model.predict(x_input, verbose=0)
print(yhat)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: univariate mlp example 是机器学习中的常用技术。
#   *univariate mlp example is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Mlp Univariate / 单变量
# Complete Code / 完整代码
# ===============================

# univariate mlp example
from numpy import array
from keras.models import Sequential
from keras.layers import Dense

# split a univariate sequence into samples
def split_sequence(sequence, n_steps):
	X, y = list(), list()
	for i in range(len(sequence)):
		# find the end of this pattern
		end_ix = i + n_steps
		# check if we are beyond the sequence
		if end_ix > len(sequence)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = sequence[i:end_ix], sequence[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return array(X), array(y)

# define input sequence
raw_seq = [10, 20, 30, 40, 50, 60, 70, 80, 90]
# choose a number of time steps
n_steps = 3
# split into samples
X, y = split_sequence(raw_seq, n_steps)
# define model
model = Sequential()
model.add(Dense(100, activation='relu', input_dim=n_steps))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# fit model
model.fit(X, y, epochs=2000, verbose=0)
# demonstrate prediction
x_input = array([70, 80, 90])
x_input = x_input.reshape((1, n_steps))
yhat = model.predict(x_input, verbose=0)
print(yhat)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 15
