# %% [markdown]
# # 06 — Swiglu / 06 Swiglu
#
# **Chapter 16 — File 4 of 5 / 第16章 — 第4个文件（共5个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Swiglu**.
#
# 本脚本演示 **06 Swiglu**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import torch.nn as nn

class SwiGLU(nn.Module):
    def __init__(self, hidden_dim, intermediate_dim):
        super().__init__()
        self.gate = nn.Linear(hidden_dim, intermediate_dim)
        self.up = nn.Linear(hidden_dim, intermediate_dim)
        self.down = nn.Linear(intermediate_dim, hidden_dim)
        self.act = nn.SiLU()

    def forward(self, x):
        x = self.act(self.gate(x)) * self.up(x)
        x = self.down(x)
        return x

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Swiglu 是机器学习中的常用技术。
#   *Swiglu is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Swiglu / 06 Swiglu
# Complete Code / 完整代码
# ===============================

import torch.nn as nn

class SwiGLU(nn.Module):
    def __init__(self, hidden_dim, intermediate_dim):
        super().__init__()
        self.gate = nn.Linear(hidden_dim, intermediate_dim)
        self.up = nn.Linear(hidden_dim, intermediate_dim)
        self.down = nn.Linear(intermediate_dim, hidden_dim)
        self.act = nn.SiLU()

    def forward(self, x):
        x = self.act(self.gate(x)) * self.up(x)
        x = self.down(x)
        return x

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 5
