# %% [markdown]
# # Chapter 14 Summary / 第14章总结
#
# ## Theme / 主题: Chapter 14 / Chapter 14
#
# This chapter contains **11 code files** demonstrating chapter 14.
#
# 本章包含 **11 个代码文件**，演示Chapter 14。

# %% [markdown]
# ---
# ## Evolution / 演化路线
#
#   1. `01_download.ipynb` — Download
#   2. `02_read.ipynb` — Read
#   3. `03_tokenizer.ipynb` — Tokenizer
#   4. `04_test_tokenizer.ipynb` — Test Tokenizer
#   5. `05_encoder.ipynb` — Encoder
#   6. `06_decoder.ipynb` — Decoder
#   7. `07_model.ipynb` — Model
#   8. `08_dataset.ipynb` — Dataset
#   9. `09_one_sample.ipynb` — One Sample
#   10. `10_create_model.ipynb` — Create Model
#   11. `14_complete.ipynb` — Complete

# %% [markdown]
# ---
# ## ML Relevance / ML 关联
#
# The techniques in this chapter (Chapter 14) are fundamental building blocks in machine learning pipelines.
#
# 本章技术（Chapter 14）是机器学习流水线中的基础构建块。
