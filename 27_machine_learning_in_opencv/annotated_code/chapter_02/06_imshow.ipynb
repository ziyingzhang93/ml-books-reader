# %% [markdown]
# # 06 — Imshow / 06 Imshow
#
# **Chapter 02 — File 4 of 10 / 第02章 — 第4个文件（共10个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Imshow**.
#
# 本脚本演示 **06 Imshow**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import cv2

img = cv2.imread('Images/Dog.jpg')
cv2.imshow('Displaying image using OpenCV', img)
cv2.waitKey(0)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Imshow 是机器学习中的常用技术。
#   *Imshow is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Imshow / 06 Imshow
# Complete Code / 完整代码
# ===============================

import cv2

img = cv2.imread('Images/Dog.jpg')
cv2.imshow('Displaying image using OpenCV', img)
cv2.waitKey(0)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 10
