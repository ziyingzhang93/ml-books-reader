# %% [markdown]
# # 07 — Quantize / 07 Quantize
#
# **Chapter 10 — File 3 of 3 / 第10章 — 第3个文件（共3个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Read image**.
#
# 本脚本演示 **Read image**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## Step 2 — Read image

# %%
img = cv2.imread('Images/bricks.jpg')

# %% [markdown]
# ---
# ## Step 3 — Convert it from BGR to RGB

# %%
img_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %% [markdown]
# ---
# ## Step 4 — Reshape image to an Mx3 array

# %%
img_data = img_RGB.reshape(-1, 3)

# %% [markdown]
# ---
# ## Step 5 — Find the number of unique RGB values

# %%
print(len(np.unique(img_data, axis=0)), 'unique RGB values out of',
      img_data.shape[0], 'pixels')

# %% [markdown]
# ---
# ## Step 6 — Specify the algorithm's termination criteria

# %%
criteria = (cv2.TERM_CRITERIA_MAX_ITER + cv2.TERM_CRITERIA_EPS, 10, 1.0)

# %% [markdown]
# ---
# ## Step 7 — Run the k-means clustering algorithm on the pixel values

# %%
compactness, labels, centers = cv2.kmeans(data=img_data.astype(np.float32), K=5,
                                          bestLabels=None, criteria=criteria, attempts=10,
                                          flags=cv2.KMEANS_RANDOM_CENTERS)

# %% [markdown]
# ---
# ## Step 8 — Apply the RGB values of the cluster centers to all pixel labels

# %%
colors = centers[labels].reshape(-1, 3)

# %% [markdown]
# ---
# ## Step 9 — Find the number of unique RGB values

# %%
print(len(np.unique(colors, axis=0)), 'unique RGB values out of',
      img_data.shape[0], 'pixels')

# %% [markdown]
# ---
# ## Step 10 — Reshape array to the original image shape

# %%
img_colors = colors.reshape(img_RGB.shape)

# %% [markdown]
# ---
# ## Step 11 — Display the quantized image

# %%
plt.imshow(img_colors.astype(np.uint8))
plt.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Read image 是机器学习中的常用技术。
#   *Read image is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Quantize / 07 Quantize
# Complete Code / 完整代码
# ===============================

import cv2
import numpy as np
import matplotlib.pyplot as plt

# Read image
img = cv2.imread('Images/bricks.jpg')

# Convert it from BGR to RGB
img_RGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Reshape image to an Mx3 array
img_data = img_RGB.reshape(-1, 3)

# Find the number of unique RGB values
print(len(np.unique(img_data, axis=0)), 'unique RGB values out of',
      img_data.shape[0], 'pixels')

# Specify the algorithm's termination criteria
criteria = (cv2.TERM_CRITERIA_MAX_ITER + cv2.TERM_CRITERIA_EPS, 10, 1.0)

# Run the k-means clustering algorithm on the pixel values
compactness, labels, centers = cv2.kmeans(data=img_data.astype(np.float32), K=5,
                                          bestLabels=None, criteria=criteria, attempts=10,
                                          flags=cv2.KMEANS_RANDOM_CENTERS)

# Apply the RGB values of the cluster centers to all pixel labels
colors = centers[labels].reshape(-1, 3)

# Find the number of unique RGB values
print(len(np.unique(colors, axis=0)), 'unique RGB values out of',
      img_data.shape[0], 'pixels')

# Reshape array to the original image shape
img_colors = colors.reshape(img_RGB.shape)

# Display the quantized image
plt.imshow(img_colors.astype(np.uint8))
plt.show()
