# %% [markdown]
# # 04 — Video Capture / 04 Video Capture
#
# **Chapter 03 — File 1 of 4 / 第03章 — 第1个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Video Capture**.
#
# 本脚本演示 **04 Video Capture**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import cv2

capture = cv2.VideoCapture(0)

if not capture.isOpened():
    print("Error establishing connection")

ret, frame = capture.read()

if ret:
    cv2.imshow('Displaying image frames from a webcam', frame)
    cv2.waitKey(0)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Video Capture 是机器学习中的常用技术。
#   *Video Capture is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Video Capture / 04 Video Capture
# Complete Code / 完整代码
# ===============================

import cv2

capture = cv2.VideoCapture(0)

if not capture.isOpened():
    print("Error establishing connection")

ret, frame = capture.read()

if ret:
    cv2.imshow('Displaying image frames from a webcam', frame)
    cv2.waitKey(0)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 4
