# %% [markdown]
# # 03 — Inference Infogan / 生成对抗网络
#
# **Chapter 18 — File 3 of 4 / 第18章 — 第3个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of loading the generator model and generating images**.
#
# 本脚本演示 **example of loading the generator model and generating images**。

# %% [markdown]
# ---
# ## Step 1 — example of loading the generator model and generating images

# %%
from math import sqrt
from numpy import hstack
from numpy.random import randn
from numpy.random import randint
from keras.models import load_model
from keras.utils import to_categorical
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — generate points in latent space as input for the generator

# %%
def generate_latent_points(latent_dim, n_cat, n_samples):

# %% [markdown]
# ---
# ## Step 3 — generate points in the latent space

# %%
z_latent = randn(latent_dim * n_samples)

# %% [markdown]
# ---
# ## Step 4 — reshape into a batch of inputs for the network

# %%
z_latent = z_latent.reshape(n_samples, latent_dim)

# %% [markdown]
# ---
# ## Step 5 — generate categorical codes

# %%
cat_codes = randint(0, n_cat, n_samples)

# %% [markdown]
# ---
# ## Step 6 — one hot encode

# %%
cat_codes = to_categorical(cat_codes, num_classes=n_cat)

# %% [markdown]
# ---
# ## Step 7 — concatenate latent points and control codes

# %%
z_input = hstack((z_latent, cat_codes))
	return [z_input, cat_codes]

# %% [markdown]
# ---
# ## Step 8 — create a plot of generated images

# %%
def create_plot(examples, n_examples):

# %% [markdown]
# ---
# ## Step 9 — plot images

# %%
for i in range(n_examples):

# %% [markdown]
# ---
# ## Step 10 — define subplot

# %%
pyplot.subplot(sqrt(n_examples), sqrt(n_examples), 1 + i)

# %% [markdown]
# ---
# ## Step 11 — turn off axis

# %%
pyplot.axis('off')

# %% [markdown]
# ---
# ## Step 12 — plot raw pixel data

# %%
pyplot.imshow(examples[i, :, :, 0], cmap='gray_r')
	pyplot.show()

# %% [markdown]
# ---
# ## Step 13 — load model

# %%
model = load_model('model_93700.h5')

# %% [markdown]
# ---
# ## Step 14 — number of values for the categorical control code

# %%
n_cat = 10

# %% [markdown]
# ---
# ## Step 15 — size of the latent space

# %%
latent_dim = 62

# %% [markdown]
# ---
# ## Step 16 — number of examples to generate

# %%
n_samples = 100

# %% [markdown]
# ---
# ## Step 17 — generate points in latent space and control codes

# %%
z_input, _ = generate_latent_points(latent_dim, n_cat, n_samples)

# %% [markdown]
# ---
# ## Step 18 — predict outputs

# %%
X = model.predict(z_input)

# %% [markdown]
# ---
# ## Step 19 — scale from [-1,1] to [0,1]

# %%
X = (X + 1) / 2.0

# %% [markdown]
# ---
# ## Step 20 — plot the result

# %%
create_plot(X, n_samples)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of loading the generator model and generating images 是机器学习中的常用技术。
#   *example of loading the generator model and generating images is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Inference Infogan / 生成对抗网络
# Complete Code / 完整代码
# ===============================

# example of loading the generator model and generating images
from math import sqrt
from numpy import hstack
from numpy.random import randn
from numpy.random import randint
from keras.models import load_model
from keras.utils import to_categorical
from matplotlib import pyplot

# generate points in latent space as input for the generator
def generate_latent_points(latent_dim, n_cat, n_samples):
	# generate points in the latent space
	z_latent = randn(latent_dim * n_samples)
	# reshape into a batch of inputs for the network
	z_latent = z_latent.reshape(n_samples, latent_dim)
	# generate categorical codes
	cat_codes = randint(0, n_cat, n_samples)
	# one hot encode
	cat_codes = to_categorical(cat_codes, num_classes=n_cat)
	# concatenate latent points and control codes
	z_input = hstack((z_latent, cat_codes))
	return [z_input, cat_codes]

# create a plot of generated images
def create_plot(examples, n_examples):
	# plot images
	for i in range(n_examples):
		# define subplot
		pyplot.subplot(sqrt(n_examples), sqrt(n_examples), 1 + i)
		# turn off axis
		pyplot.axis('off')
		# plot raw pixel data
		pyplot.imshow(examples[i, :, :, 0], cmap='gray_r')
	pyplot.show()

# load model
model = load_model('model_93700.h5')
# number of values for the categorical control code
n_cat = 10
# size of the latent space
latent_dim = 62
# number of examples to generate
n_samples = 100
# generate points in latent space and control codes
z_input, _ = generate_latent_points(latent_dim, n_cat, n_samples)
# predict outputs
X = model.predict(z_input)
# scale from [-1,1] to [0,1]
X = (X + 1) / 2.0
# plot the result
create_plot(X, n_samples)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 4
