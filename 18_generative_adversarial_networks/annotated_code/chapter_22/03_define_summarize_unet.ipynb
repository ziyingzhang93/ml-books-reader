# %% [markdown]
# # 03 — Define Summarize Unet / 03 Define Summarize Unet
#
# **Chapter 22 — File 3 of 4 / 第22章 — 第3个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of defining a u-net encoder-decoder generator model**.
#
# 本脚本演示 **example of defining a u-net encoder-decoder generator model**。

# %% [markdown]
# ---
# ## Step 1 — example of defining a u-net encoder-decoder generator model

# %%
from keras.initializers import RandomNormal
from keras.models import Model
from keras.models import Input
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Activation
from keras.layers import Concatenate
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU
from keras.utils.vis_utils import plot_model

# %% [markdown]
# ---
# ## Step 2 — define an encoder block

# %%
def define_encoder_block(layer_in, n_filters, batchnorm=True):

# %% [markdown]
# ---
# ## Step 3 — weight initialization

# %%
init = RandomNormal(stddev=0.02)

# %% [markdown]
# ---
# ## Step 4 — add downsampling layer

# %%
g = Conv2D(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(layer_in)

# %% [markdown]
# ---
# ## Step 5 — conditionally add batch normalization

# %%
if batchnorm:
		g = BatchNormalization()(g, training=True)

# %% [markdown]
# ---
# ## Step 6 — leaky relu activation

# %%
g = LeakyReLU(alpha=0.2)(g)
	return g

# %% [markdown]
# ---
# ## Step 7 — define a decoder block

# %%
def decoder_block(layer_in, skip_in, n_filters, dropout=True):

# %% [markdown]
# ---
# ## Step 8 — weight initialization

# %%
init = RandomNormal(stddev=0.02)

# %% [markdown]
# ---
# ## Step 9 — add upsampling layer

# %%
g = Conv2DTranspose(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(layer_in)

# %% [markdown]
# ---
# ## Step 10 — add batch normalization

# %%
g = BatchNormalization()(g, training=True)

# %% [markdown]
# ---
# ## Step 11 — conditionally add dropout

# %%
if dropout:
		g = Dropout(0.5)(g, training=True)

# %% [markdown]
# ---
# ## Step 12 — merge with skip connection

# %%
g = Concatenate()([g, skip_in])

# %% [markdown]
# ---
# ## Step 13 — relu activation

# %%
g = Activation('relu')(g)
	return g

# %% [markdown]
# ---
# ## Step 14 — define the standalone generator model

# %%
def define_generator(image_shape=(256,256,3)):

# %% [markdown]
# ---
# ## Step 15 — weight initialization

# %%
init = RandomNormal(stddev=0.02)

# %% [markdown]
# ---
# ## Step 16 — image input

# %%
in_image = Input(shape=image_shape)

# %% [markdown]
# ---
# ## Step 17 — encoder model: C64-C128-C256-C512-C512-C512-C512-C512

# %%
e1 = define_encoder_block(in_image, 64, batchnorm=False)
	e2 = define_encoder_block(e1, 128)
	e3 = define_encoder_block(e2, 256)
	e4 = define_encoder_block(e3, 512)
	e5 = define_encoder_block(e4, 512)
	e6 = define_encoder_block(e5, 512)
	e7 = define_encoder_block(e6, 512)

# %% [markdown]
# ---
# ## Step 18 — bottleneck, no batch norm and relu

# %%
b = Conv2D(512, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(e7)
	b = Activation('relu')(b)

# %% [markdown]
# ---
# ## Step 19 — decoder model: CD512-CD1024-CD1024-C1024-C1024-C512-C256-C128

# %%
d1 = decoder_block(b, e7, 512)
	d2 = decoder_block(d1, e6, 512)
	d3 = decoder_block(d2, e5, 512)
	d4 = decoder_block(d3, e4, 512, dropout=False)
	d5 = decoder_block(d4, e3, 256, dropout=False)
	d6 = decoder_block(d5, e2, 128, dropout=False)
	d7 = decoder_block(d6, e1, 64, dropout=False)

# %% [markdown]
# ---
# ## Step 20 — output

# %%
g = Conv2DTranspose(3, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d7)
	out_image = Activation('tanh')(g)

# %% [markdown]
# ---
# ## Step 21 — define model

# %%
model = Model(in_image, out_image)
	return model

# %% [markdown]
# ---
# ## Step 22 — define image shape

# %%
image_shape = (256,256,3)

# %% [markdown]
# ---
# ## Step 23 — create the model

# %%
model = define_generator(image_shape)

# %% [markdown]
# ---
# ## Step 24 — summarize the model

# %%
model.summary()

# %% [markdown]
# ---
# ## Step 25 — plot the model

# %%
plot_model(model, to_file='generator_model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of defining a u-net encoder-decoder generator model 是机器学习中的常用技术。
#   *example of defining a u-net encoder-decoder generator model is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Define Summarize Unet / 03 Define Summarize Unet
# Complete Code / 完整代码
# ===============================

# example of defining a u-net encoder-decoder generator model
from keras.initializers import RandomNormal
from keras.models import Model
from keras.models import Input
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Activation
from keras.layers import Concatenate
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU
from keras.utils.vis_utils import plot_model

# define an encoder block
def define_encoder_block(layer_in, n_filters, batchnorm=True):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# add downsampling layer
	g = Conv2D(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(layer_in)
	# conditionally add batch normalization
	if batchnorm:
		g = BatchNormalization()(g, training=True)
	# leaky relu activation
	g = LeakyReLU(alpha=0.2)(g)
	return g

# define a decoder block
def decoder_block(layer_in, skip_in, n_filters, dropout=True):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# add upsampling layer
	g = Conv2DTranspose(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(layer_in)
	# add batch normalization
	g = BatchNormalization()(g, training=True)
	# conditionally add dropout
	if dropout:
		g = Dropout(0.5)(g, training=True)
	# merge with skip connection
	g = Concatenate()([g, skip_in])
	# relu activation
	g = Activation('relu')(g)
	return g

# define the standalone generator model
def define_generator(image_shape=(256,256,3)):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# image input
	in_image = Input(shape=image_shape)
	# encoder model: C64-C128-C256-C512-C512-C512-C512-C512
	e1 = define_encoder_block(in_image, 64, batchnorm=False)
	e2 = define_encoder_block(e1, 128)
	e3 = define_encoder_block(e2, 256)
	e4 = define_encoder_block(e3, 512)
	e5 = define_encoder_block(e4, 512)
	e6 = define_encoder_block(e5, 512)
	e7 = define_encoder_block(e6, 512)
	# bottleneck, no batch norm and relu
	b = Conv2D(512, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(e7)
	b = Activation('relu')(b)
	# decoder model: CD512-CD1024-CD1024-C1024-C1024-C512-C256-C128
	d1 = decoder_block(b, e7, 512)
	d2 = decoder_block(d1, e6, 512)
	d3 = decoder_block(d2, e5, 512)
	d4 = decoder_block(d3, e4, 512, dropout=False)
	d5 = decoder_block(d4, e3, 256, dropout=False)
	d6 = decoder_block(d5, e2, 128, dropout=False)
	d7 = decoder_block(d6, e1, 64, dropout=False)
	# output
	g = Conv2DTranspose(3, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d7)
	out_image = Activation('tanh')(g)
	# define model
	model = Model(in_image, out_image)
	return model

# define image shape
image_shape = (256,256,3)
# create the model
model = define_generator(image_shape)
# summarize the model
model.summary()
# plot the model
plot_model(model, to_file='generator_model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 4
