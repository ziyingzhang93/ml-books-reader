# %% [markdown]
# # 02 — Plot Cifar10 / 02 Plot Cifar10
#
# **Chapter 08 — File 2 of 10 / 第08章 — 第2个文件（共10个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of loading and plotting the cifar10 dataset**.
#
# 本脚本演示 **example of loading and plotting the cifar10 dataset**。

# %% [markdown]
# ---
# ## Step 1 — example of loading and plotting the cifar10 dataset

# %%
from keras.datasets.cifar10 import load_data
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — load the images into memory

# %%
(trainX, trainy), (testX, testy) = load_data()

# %% [markdown]
# ---
# ## Step 3 — plot images from the training dataset

# %%
for i in range(49):

# %% [markdown]
# ---
# ## Step 4 — define subplot

# %%
pyplot.subplot(7, 7, 1 + i)

# %% [markdown]
# ---
# ## Step 5 — turn off axis

# %%
pyplot.axis('off')

# %% [markdown]
# ---
# ## Step 6 — plot raw pixel data

# %%
pyplot.imshow(trainX[i])
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of loading and plotting the cifar10 dataset 是机器学习中的常用技术。
#   *example of loading and plotting the cifar10 dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Plot Cifar10 / 02 Plot Cifar10
# Complete Code / 完整代码
# ===============================

# example of loading and plotting the cifar10 dataset
from keras.datasets.cifar10 import load_data
from matplotlib import pyplot
# load the images into memory
(trainX, trainy), (testX, testy) = load_data()
# plot images from the training dataset
for i in range(49):
	# define subplot
	pyplot.subplot(7, 7, 1 + i)
	# turn off axis
	pyplot.axis('off')
	# plot raw pixel data
	pyplot.imshow(trainX[i])
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 10
