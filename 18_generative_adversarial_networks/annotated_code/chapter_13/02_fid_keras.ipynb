# %% [markdown]
# # 02 — Fid Keras / Keras
#
# **Chapter 13 — File 2 of 3 / 第13章 — 第2个文件（共3个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of calculating the frechet inception distance in Keras**.
#
# 本脚本演示 **example of calculating the frechet inception distance in Keras**。

# %% [markdown]
# ---
# ## Step 1 — example of calculating the frechet inception distance in Keras

# %%
import numpy
from numpy import cov
from numpy import trace
from numpy import iscomplexobj
from numpy import asarray
from numpy.random import randint
from scipy.linalg import sqrtm
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from skimage.transform import resize

# %% [markdown]
# ---
# ## Step 2 — scale an array of images to a new size

# %%
def scale_images(images, new_shape):
	images_list = list()
	for image in images:

# %% [markdown]
# ---
# ## Step 3 — resize with nearest neighbor interpolation

# %%
new_image = resize(image, new_shape, 0)

# %% [markdown]
# ---
# ## Step 4 — store

# %%
images_list.append(new_image)
	return asarray(images_list)

# %% [markdown]
# ---
# ## Step 5 — calculate frechet inception distance

# %%
def calculate_fid(model, images1, images2):

# %% [markdown]
# ---
# ## Step 6 — calculate activations

# %%
act1 = model.predict(images1)
	act2 = model.predict(images2)

# %% [markdown]
# ---
# ## Step 7 — calculate mean and covariance statistics

# %%
mu1, sigma1 = act1.mean(axis=0), cov(act1, rowvar=False)
	mu2, sigma2 = act2.mean(axis=0), cov(act2, rowvar=False)

# %% [markdown]
# ---
# ## Step 8 — calculate sum squared difference between means

# %%
ssdiff = numpy.sum((mu1 - mu2)**2.0)

# %% [markdown]
# ---
# ## Step 9 — calculate sqrt of product between cov

# %%
covmean = sqrtm(sigma1.dot(sigma2))

# %% [markdown]
# ---
# ## Step 10 — check and correct imaginary numbers from sqrt

# %%
if iscomplexobj(covmean):
		covmean = covmean.real

# %% [markdown]
# ---
# ## Step 11 — calculate score

# %%
fid = ssdiff + trace(sigma1 + sigma2 - 2.0 * covmean)
	return fid

# %% [markdown]
# ---
# ## Step 12 — prepare the inception v3 model

# %%
model = InceptionV3(include_top=False, pooling='avg', input_shape=(299,299,3))

# %% [markdown]
# ---
# ## Step 13 — define two fake collections of images

# %%
images1 = randint(0, 255, 10*32*32*3)
images1 = images1.reshape((10,32,32,3))
images2 = randint(0, 255, 10*32*32*3)
images2 = images2.reshape((10,32,32,3))
print('Prepared', images1.shape, images2.shape)

# %% [markdown]
# ---
# ## Step 14 — convert integer to floating point values

# %%
images1 = images1.astype('float32')
images2 = images2.astype('float32')

# %% [markdown]
# ---
# ## Step 15 — resize images

# %%
images1 = scale_images(images1, (299,299,3))
images2 = scale_images(images2, (299,299,3))
print('Scaled', images1.shape, images2.shape)

# %% [markdown]
# ---
# ## Step 16 — pre-process images

# %%
images1 = preprocess_input(images1)
images2 = preprocess_input(images2)

# %% [markdown]
# ---
# ## Step 17 — fid between images1 and images1

# %%
fid = calculate_fid(model, images1, images1)
print('FID (same): %.3f' % fid)

# %% [markdown]
# ---
# ## Step 18 — fid between images1 and images2

# %%
fid = calculate_fid(model, images1, images2)
print('FID (different): %.3f' % fid)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of calculating the frechet inception distance in Keras 是机器学习中的常用技术。
#   *example of calculating the frechet inception distance in Keras is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Fid Keras / Keras
# Complete Code / 完整代码
# ===============================

# example of calculating the frechet inception distance in Keras
import numpy
from numpy import cov
from numpy import trace
from numpy import iscomplexobj
from numpy import asarray
from numpy.random import randint
from scipy.linalg import sqrtm
from keras.applications.inception_v3 import InceptionV3
from keras.applications.inception_v3 import preprocess_input
from skimage.transform import resize

# scale an array of images to a new size
def scale_images(images, new_shape):
	images_list = list()
	for image in images:
		# resize with nearest neighbor interpolation
		new_image = resize(image, new_shape, 0)
		# store
		images_list.append(new_image)
	return asarray(images_list)

# calculate frechet inception distance
def calculate_fid(model, images1, images2):
	# calculate activations
	act1 = model.predict(images1)
	act2 = model.predict(images2)
	# calculate mean and covariance statistics
	mu1, sigma1 = act1.mean(axis=0), cov(act1, rowvar=False)
	mu2, sigma2 = act2.mean(axis=0), cov(act2, rowvar=False)
	# calculate sum squared difference between means
	ssdiff = numpy.sum((mu1 - mu2)**2.0)
	# calculate sqrt of product between cov
	covmean = sqrtm(sigma1.dot(sigma2))
	# check and correct imaginary numbers from sqrt
	if iscomplexobj(covmean):
		covmean = covmean.real
	# calculate score
	fid = ssdiff + trace(sigma1 + sigma2 - 2.0 * covmean)
	return fid

# prepare the inception v3 model
model = InceptionV3(include_top=False, pooling='avg', input_shape=(299,299,3))
# define two fake collections of images
images1 = randint(0, 255, 10*32*32*3)
images1 = images1.reshape((10,32,32,3))
images2 = randint(0, 255, 10*32*32*3)
images2 = images2.reshape((10,32,32,3))
print('Prepared', images1.shape, images2.shape)
# convert integer to floating point values
images1 = images1.astype('float32')
images2 = images2.astype('float32')
# resize images
images1 = scale_images(images1, (299,299,3))
images2 = scale_images(images2, (299,299,3))
print('Scaled', images1.shape, images2.shape)
# pre-process images
images1 = preprocess_input(images1)
images2 = preprocess_input(images2)
# fid between images1 and images1
fid = calculate_fid(model, images1, images1)
print('FID (same): %.3f' % fid)
# fid between images1 and images2
fid = calculate_fid(model, images1, images2)
print('FID (different): %.3f' % fid)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 3
