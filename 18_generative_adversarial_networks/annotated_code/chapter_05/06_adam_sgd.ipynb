# %% [markdown]
# # 06 — Adam Sgd / 06 Adam Sgd
#
# **Chapter 05 — File 6 of 11 / 第05章 — 第6个文件（共11个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of using adam when training a discriminator model**.
#
# 本脚本演示 **example of using adam when training a discriminator model**。

# %% [markdown]
# ---
# ## Step 1 — example of using adam when training a discriminator model

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.optimizers import Adam

# %% [markdown]
# ---
# ## Step 2 — define model

# %%
model = Sequential()
model.add(Conv2D(64, (3,3), strides=(2,2), padding='same', input_shape=(64,64,3)))

# %% [markdown]
# ---
# ## Step 3 — compile model

# %%
opt = Adam(lr=0.0002, beta_1=0.5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of using adam when training a discriminator model 是机器学习中的常用技术。
#   *example of using adam when training a discriminator model is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Adam Sgd / 06 Adam Sgd
# Complete Code / 完整代码
# ===============================

# example of using adam when training a discriminator model
from keras.models import Sequential
from keras.layers import Conv2D
from keras.optimizers import Adam
# define model
model = Sequential()
model.add(Conv2D(64, (3,3), strides=(2,2), padding='same', input_shape=(64,64,3)))
# compile model
opt = Adam(lr=0.0002, beta_1=0.5)
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 7 of 11
