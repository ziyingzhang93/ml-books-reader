# %% [markdown]
# # 11 — Noisy Labels / 11 Noisy Labels
#
# **Chapter 05 — File 11 of 11 / 第05章 — 第11个文件（共11个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of noisy labels**.
#
# 本脚本演示 **example of noisy labels**。

# %% [markdown]
# ---
# ## Step 1 — example of noisy labels

# %%
from numpy import ones
from numpy import zeros
from numpy.random import choice

# %% [markdown]
# ---
# ## Step 2 — randomly flip some labels

# %%
def noisy_labels(y, p_flip):

# %% [markdown]
# ---
# ## Step 3 — determine the number of labels to flip

# %%
n_select = int(p_flip * y.shape[0])

# %% [markdown]
# ---
# ## Step 4 — choose labels to flip

# %%
flip_ix = choice([i for i in range(y.shape[0])], size=n_select)

# %% [markdown]
# ---
# ## Step 5 — invert the labels in place

# %%
y[flip_ix] = 1 - y[flip_ix]
	return y

# %% [markdown]
# ---
# ## Step 6 — generate 'real' class labels (1)

# %%
n_samples = 1000
y = ones((n_samples, 1))

# %% [markdown]
# ---
# ## Step 7 — flip labels with 5% probability

# %%
y = noisy_labels(y, 0.05)

# %% [markdown]
# ---
# ## Step 8 — summarize labels

# %%
print(y.sum())

# %% [markdown]
# ---
# ## Step 9 — generate 'fake' class labels (0)

# %%
y = zeros((n_samples, 1))

# %% [markdown]
# ---
# ## Step 10 — flip labels with 5% probability

# %%
y = noisy_labels(y, 0.05)

# %% [markdown]
# ---
# ## Step 11 — summarize labels

# %%
print(y.sum())

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of noisy labels 是机器学习中的常用技术。
#   *example of noisy labels is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Noisy Labels / 11 Noisy Labels
# Complete Code / 完整代码
# ===============================

# example of noisy labels
from numpy import ones
from numpy import zeros
from numpy.random import choice

# randomly flip some labels
def noisy_labels(y, p_flip):
	# determine the number of labels to flip
	n_select = int(p_flip * y.shape[0])
	# choose labels to flip
	flip_ix = choice([i for i in range(y.shape[0])], size=n_select)
	# invert the labels in place
	y[flip_ix] = 1 - y[flip_ix]
	return y

# generate 'real' class labels (1)
n_samples = 1000
y = ones((n_samples, 1))
# flip labels with 5% probability
y = noisy_labels(y, 0.05)
# summarize labels
print(y.sum())

# generate 'fake' class labels (0)
y = zeros((n_samples, 1))
# flip labels with 5% probability
y = noisy_labels(y, 0.05)
# summarize labels
print(y.sum())
