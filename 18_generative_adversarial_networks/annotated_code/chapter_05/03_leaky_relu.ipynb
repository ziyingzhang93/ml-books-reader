# %% [markdown]
# # 03 — Leaky Relu / 03 Leaky Relu
#
# **Chapter 05 — File 3 of 11 / 第05章 — 第3个文件（共11个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of using leakyrelu in a discriminator model**.
#
# 本脚本演示 **example of using leakyrelu in a discriminator model**。

# %% [markdown]
# ---
# ## Step 1 — example of using leakyrelu in a discriminator model

# %%
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import LeakyReLU

# %% [markdown]
# ---
# ## Step 2 — define model

# %%
model = Sequential()
model.add(Conv2D(64, (3,3), strides=(2,2), padding='same', input_shape=(64,64,3)))
model.add(LeakyReLU(0.2))

# %% [markdown]
# ---
# ## Step 3 — summarize model

# %%
model.summary()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of using leakyrelu in a discriminator model 是机器学习中的常用技术。
#   *example of using leakyrelu in a discriminator model is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Leaky Relu / 03 Leaky Relu
# Complete Code / 完整代码
# ===============================

# example of using leakyrelu in a discriminator model
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import LeakyReLU
# define model
model = Sequential()
model.add(Conv2D(64, (3,3), strides=(2,2), padding='same', input_shape=(64,64,3)))
model.add(LeakyReLU(0.2))
# summarize model
model.summary()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 11
