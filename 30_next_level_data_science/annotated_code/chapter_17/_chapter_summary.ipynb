# %% [markdown]
# # Chapter 17 Summary / 第17章总结
#
# ## Theme / 主题: Chapter 17 / Chapter 17
#
# This chapter contains **3 code files** demonstrating chapter 17.
#
# 本章包含 **3 个代码文件**，演示Chapter 17。

# %% [markdown]
# ---
# ## Evolution / 演化路线
#
#   1. `02_lightgbm.ipynb` — Lightgbm
#   2. `03_training.ipynb` — Training
#   3. `04_compare.ipynb` — Compare

# %% [markdown]
# ---
# ## ML Relevance / ML 关联
#
# The techniques in this chapter (Chapter 17) are fundamental building blocks in machine learning pipelines.
#
# 本章技术（Chapter 17）是机器学习流水线中的基础构建块。
