# %% [markdown]
# # 02 — Load And Encode / 数据编码
#
# **Chapter 12 — File 2 of 7 / 第12章 — 第2个文件（共7个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of loading and preparing the breast cancer dataset**.
#
# 本脚本演示 **example of loading and preparing the breast cancer dataset**。

# %% [markdown]
# ---
# ## Step 1 — example of loading and preparing the breast cancer dataset

# %%
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

# %% [markdown]
# ---
# ## Step 2 — load the dataset

# %%
def load_dataset(filename):

# %% [markdown]
# ---
# ## Step 3 — load the dataset

# %%
data = read_csv(filename, header=None)

# %% [markdown]
# ---
# ## Step 4 — retrieve array

# %%
dataset = data.values

# %% [markdown]
# ---
# ## Step 5 — split into input and output variables

# %%
X = dataset[:, :-1]
	y = dataset[:,-1]

# %% [markdown]
# ---
# ## Step 6 — format all fields as string

# %%
X = X.astype(str)
	return X, y

# %% [markdown]
# ---
# ## Step 7 — prepare input data

# %%
def prepare_inputs(X_train, X_test):
	oe = OrdinalEncoder()
	oe.fit(X_train)
	X_train_enc = oe.transform(X_train)
	X_test_enc = oe.transform(X_test)
	return X_train_enc, X_test_enc

# %% [markdown]
# ---
# ## Step 8 — prepare target

# %%
def prepare_targets(y_train, y_test):
	le = LabelEncoder()
	le.fit(y_train)
	y_train_enc = le.transform(y_train)
	y_test_enc = le.transform(y_test)
	return y_train_enc, y_test_enc

# %% [markdown]
# ---
# ## Step 9 — load the dataset

# %%
X, y = load_dataset('breast-cancer.csv')

# %% [markdown]
# ---
# ## Step 10 — split into train and test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)

# %% [markdown]
# ---
# ## Step 11 — prepare input data

# %%
X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)

# %% [markdown]
# ---
# ## Step 12 — prepare output data

# %%
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)

# %% [markdown]
# ---
# ## Step 13 — summarize

# %%
print('Train', X_train_enc.shape, y_train_enc.shape)
print('Test', X_test_enc.shape, y_test_enc.shape)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of loading and preparing the breast cancer dataset 是机器学习中的常用技术。
#   *example of loading and preparing the breast cancer dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Load And Encode / 数据编码
# Complete Code / 完整代码
# ===============================

# example of loading and preparing the breast cancer dataset
from pandas import read_csv
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OrdinalEncoder

# load the dataset
def load_dataset(filename):
	# load the dataset
	data = read_csv(filename, header=None)
	# retrieve array
	dataset = data.values
	# split into input and output variables
	X = dataset[:, :-1]
	y = dataset[:,-1]
	# format all fields as string
	X = X.astype(str)
	return X, y

# prepare input data
def prepare_inputs(X_train, X_test):
	oe = OrdinalEncoder()
	oe.fit(X_train)
	X_train_enc = oe.transform(X_train)
	X_test_enc = oe.transform(X_test)
	return X_train_enc, X_test_enc

# prepare target
def prepare_targets(y_train, y_test):
	le = LabelEncoder()
	le.fit(y_train)
	y_train_enc = le.transform(y_train)
	y_test_enc = le.transform(y_test)
	return y_train_enc, y_test_enc

# load the dataset
X, y = load_dataset('breast-cancer.csv')
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# prepare input data
X_train_enc, X_test_enc = prepare_inputs(X_train, X_test)
# prepare output data
y_train_enc, y_test_enc = prepare_targets(y_train, y_test)
# summarize
print('Train', X_train_enc.shape, y_train_enc.shape)
print('Test', X_test_enc.shape, y_test_enc.shape)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 7
