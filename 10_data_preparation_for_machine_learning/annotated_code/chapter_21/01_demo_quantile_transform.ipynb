# %% [markdown]
# # 01 — Demo Quantile Transform / 数据变换
#
# **Chapter 21 — File 1 of 8 / 第21章 — 第1个文件（共8个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **demonstration of the quantile transform**.
#
# 本脚本演示 **demonstration of the quantile transform**。

# %% [markdown]
# ---
# ## Step 1 — demonstration of the quantile transform

# %%
from numpy import exp
from numpy.random import randn
from sklearn.preprocessing import QuantileTransformer
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — generate gaussian data sample

# %%
data = randn(1000)

# %% [markdown]
# ---
# ## Step 3 — add a skew to the data distribution

# %%
data = exp(data)

# %% [markdown]
# ---
# ## Step 4 — histogram of the raw data with a skew

# %%
pyplot.hist(data, bins=25)
pyplot.show()

# %% [markdown]
# ---
# ## Step 5 — reshape data to have rows and columns

# %%
data = data.reshape((len(data),1))

# %% [markdown]
# ---
# ## Step 6 — quantile transform the raw data

# %%
quantile = QuantileTransformer(output_distribution='normal')
data_trans = quantile.fit_transform(data)

# %% [markdown]
# ---
# ## Step 7 — histogram of the transformed data

# %%
pyplot.hist(data_trans, bins=25)
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: demonstration of the quantile transform 是机器学习中的常用技术。
#   *demonstration of the quantile transform is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Demo Quantile Transform / 数据变换
# Complete Code / 完整代码
# ===============================

# demonstration of the quantile transform
from numpy import exp
from numpy.random import randn
from sklearn.preprocessing import QuantileTransformer
from matplotlib import pyplot
# generate gaussian data sample
data = randn(1000)
# add a skew to the data distribution
data = exp(data)
# histogram of the raw data with a skew
pyplot.hist(data, bins=25)
pyplot.show()
# reshape data to have rows and columns
data = data.reshape((len(data),1))
# quantile transform the raw data
quantile = QuantileTransformer(output_distribution='normal')
data_trans = quantile.fit_transform(data)
# histogram of the transformed data
pyplot.hist(data_trans, bins=25)
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 8
