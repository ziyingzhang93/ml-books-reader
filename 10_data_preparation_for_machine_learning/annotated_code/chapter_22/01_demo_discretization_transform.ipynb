# %% [markdown]
# # 01 — Demo Discretization Transform / 数据变换
#
# **Chapter 22 — File 1 of 10 / 第22章 — 第1个文件（共10个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **demonstration of the discretization transform**.
#
# 本脚本演示 **demonstration of the discretization transform**。

# %% [markdown]
# ---
# ## Step 1 — demonstration of the discretization transform

# %%
from numpy.random import randn
from sklearn.preprocessing import KBinsDiscretizer
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — generate gaussian data sample

# %%
data = randn(1000)

# %% [markdown]
# ---
# ## Step 3 — histogram of the raw data

# %%
pyplot.hist(data, bins=25)
pyplot.show()

# %% [markdown]
# ---
# ## Step 4 — reshape data to have rows and columns

# %%
data = data.reshape((len(data),1))

# %% [markdown]
# ---
# ## Step 5 — discretization transform the raw data

# %%
kbins = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
data_trans = kbins.fit_transform(data)

# %% [markdown]
# ---
# ## Step 6 — summarize first few rows

# %%
print(data_trans[:10, :])

# %% [markdown]
# ---
# ## Step 7 — histogram of the transformed data

# %%
pyplot.hist(data_trans, bins=10)
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: demonstration of the discretization transform 是机器学习中的常用技术。
#   *demonstration of the discretization transform is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Demo Discretization Transform / 数据变换
# Complete Code / 完整代码
# ===============================

# demonstration of the discretization transform
from numpy.random import randn
from sklearn.preprocessing import KBinsDiscretizer
from matplotlib import pyplot
# generate gaussian data sample
data = randn(1000)
# histogram of the raw data
pyplot.hist(data, bins=25)
pyplot.show()
# reshape data to have rows and columns
data = data.reshape((len(data),1))
# discretization transform the raw data
kbins = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
data_trans = kbins.fit_transform(data)
# summarize first few rows
print(data_trans[:10, :])
# histogram of the transformed data
pyplot.hist(data_trans, bins=10)
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 10
