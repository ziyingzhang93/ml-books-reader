# %% [markdown]
# # 04 — Uniform Discretization Transform / 数据变换
#
# **Chapter 22 — File 4 of 10 / 第22章 — 第4个文件（共10个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **visualize a uniform ordinal discretization transform of the sonar dataset**.
#
# 本脚本演示 **visualize a uniform ordinal discretization transform of the sonar dataset**。

# %% [markdown]
# ---
# ## Step 1 — visualize a uniform ordinal discretization transform of the sonar dataset

# %%
from pandas import read_csv
from pandas import DataFrame
from sklearn.preprocessing import KBinsDiscretizer
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — load dataset

# %%
dataset = read_csv('sonar.csv', header=None)

# %% [markdown]
# ---
# ## Step 3 — retrieve just the numeric input values

# %%
data = dataset.values[:, :-1]

# %% [markdown]
# ---
# ## Step 4 — perform a uniform discretization transform of the dataset

# %%
trans = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
data = trans.fit_transform(data)

# %% [markdown]
# ---
# ## Step 5 — convert the array back to a dataframe

# %%
dataset = DataFrame(data)

# %% [markdown]
# ---
# ## Step 6 — histograms of the variables

# %%
fig = dataset.hist(xlabelsize=4, ylabelsize=4)
[x.title.set_size(4) for x in fig.ravel()]

# %% [markdown]
# ---
# ## Step 7 — show the plot

# %%
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: visualize a uniform ordinal discretization transform of the sonar dataset 是机器学习中的常用技术。
#   *visualize a uniform ordinal discretization transform of the sonar dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Uniform Discretization Transform / 数据变换
# Complete Code / 完整代码
# ===============================

# visualize a uniform ordinal discretization transform of the sonar dataset
from pandas import read_csv
from pandas import DataFrame
from sklearn.preprocessing import KBinsDiscretizer
from matplotlib import pyplot
# load dataset
dataset = read_csv('sonar.csv', header=None)
# retrieve just the numeric input values
data = dataset.values[:, :-1]
# perform a uniform discretization transform of the dataset
trans = KBinsDiscretizer(n_bins=10, encode='ordinal', strategy='uniform')
data = trans.fit_transform(data)
# convert the array back to a dataframe
dataset = DataFrame(data)
# histograms of the variables
fig = dataset.hist(xlabelsize=4, ylabelsize=4)
[x.title.set_size(4) for x in fig.ravel()]
# show the plot
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 10
