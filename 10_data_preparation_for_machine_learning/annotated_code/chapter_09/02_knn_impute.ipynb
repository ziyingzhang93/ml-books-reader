# %% [markdown]
# # 02 — Knn Impute / 02 Knn Impute
#
# **Chapter 09 — File 2 of 5 / 第09章 — 第2个文件（共5个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **knn imputation transform for the horse colic dataset**.
#
# 本脚本演示 **knn imputation transform for the horse colic dataset**。

# %% [markdown]
# ---
# ## Step 1 — knn imputation transform for the horse colic dataset

# %%
from numpy import isnan
from pandas import read_csv
from sklearn.impute import KNNImputer

# %% [markdown]
# ---
# ## Step 2 — load dataset

# %%
dataframe = read_csv('horse-colic.csv', header=None, na_values='?')

# %% [markdown]
# ---
# ## Step 3 — split into input and output elements

# %%
data = dataframe.values
ix = [i for i in range(data.shape[1]) if i != 23]
X, y = data[:, ix], data[:, 23]

# %% [markdown]
# ---
# ## Step 4 — summarize total missing

# %%
print('Missing: %d' % sum(isnan(X).flatten()))

# %% [markdown]
# ---
# ## Step 5 — define imputer

# %%
imputer = KNNImputer()

# %% [markdown]
# ---
# ## Step 6 — fit on the dataset

# %%
imputer.fit(X)

# %% [markdown]
# ---
# ## Step 7 — transform the dataset

# %%
Xtrans = imputer.transform(X)

# %% [markdown]
# ---
# ## Step 8 — summarize total missing

# %%
print('Missing: %d' % sum(isnan(Xtrans).flatten()))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: knn imputation transform for the horse colic dataset 是机器学习中的常用技术。
#   *knn imputation transform for the horse colic dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Knn Impute / 02 Knn Impute
# Complete Code / 完整代码
# ===============================

# knn imputation transform for the horse colic dataset
from numpy import isnan
from pandas import read_csv
from sklearn.impute import KNNImputer
# load dataset
dataframe = read_csv('horse-colic.csv', header=None, na_values='?')
# split into input and output elements
data = dataframe.values
ix = [i for i in range(data.shape[1]) if i != 23]
X, y = data[:, ix], data[:, 23]
# summarize total missing
print('Missing: %d' % sum(isnan(X).flatten()))
# define imputer
imputer = KNNImputer()
# fit on the dataset
imputer.fit(X)
# transform the dataset
Xtrans = imputer.transform(X)
# summarize total missing
print('Missing: %d' % sum(isnan(Xtrans).flatten()))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 5
