# %% [markdown]
# # 07 — Onehot Encode Dataset / 数据编码
#
# **Chapter 19 — File 7 of 8 / 第19章 — 第7个文件（共8个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **one-hot encode the breast cancer dataset**.
#
# 本脚本演示 **one-hot encode the breast cancer dataset**。

# %% [markdown]
# ---
# ## Step 1 — one-hot encode the breast cancer dataset

# %%
from pandas import read_csv
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ---
# ## Step 2 — load the dataset

# %%
dataset = read_csv('breast-cancer.csv', header=None)

# %% [markdown]
# ---
# ## Step 3 — retrieve the array of data

# %%
data = dataset.values

# %% [markdown]
# ---
# ## Step 4 — separate into input and output columns

# %%
X = data[:, :-1].astype(str)
y = data[:, -1].astype(str)

# %% [markdown]
# ---
# ## Step 5 — one hot encode input variables

# %%
onehot_encoder = OneHotEncoder(sparse=False)
X = onehot_encoder.fit_transform(X)

# %% [markdown]
# ---
# ## Step 6 — ordinal encode target variable

# %%
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)

# %% [markdown]
# ---
# ## Step 7 — summarize the transformed data

# %%
print('Input', X.shape)
print(X[:5, :])

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: one-hot encode the breast cancer dataset 是机器学习中的常用技术。
#   *one-hot encode the breast cancer dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Onehot Encode Dataset / 数据编码
# Complete Code / 完整代码
# ===============================

# one-hot encode the breast cancer dataset
from pandas import read_csv
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
# load the dataset
dataset = read_csv('breast-cancer.csv', header=None)
# retrieve the array of data
data = dataset.values
# separate into input and output columns
X = data[:, :-1].astype(str)
y = data[:, -1].astype(str)
# one hot encode input variables
onehot_encoder = OneHotEncoder(sparse=False)
X = onehot_encoder.fit_transform(X)
# ordinal encode target variable
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(y)
# summarize the transformed data
print('Input', X.shape)
print(X[:5, :])

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 8 of 8
