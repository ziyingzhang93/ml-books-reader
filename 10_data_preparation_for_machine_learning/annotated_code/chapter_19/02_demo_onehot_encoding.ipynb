# %% [markdown]
# # 02 — Demo Onehot Encoding / 02 Demo Onehot Encoding
#
# **Chapter 19 — File 2 of 8 / 第19章 — 第2个文件（共8个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of a one hot encoding**.
#
# 本脚本演示 **example of a one hot encoding**。

# %% [markdown]
# ---
# ## Step 1 — example of a one hot encoding

# %%
from numpy import asarray
from sklearn.preprocessing import OneHotEncoder

# %% [markdown]
# ---
# ## Step 2 — define data

# %%
data = asarray([['red'], ['green'], ['blue']])
print(data)

# %% [markdown]
# ---
# ## Step 3 — define one hot encoding

# %%
encoder = OneHotEncoder(sparse=False)

# %% [markdown]
# ---
# ## Step 4 — transform data

# %%
onehot = encoder.fit_transform(data)
print(onehot)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of a one hot encoding 是机器学习中的常用技术。
#   *example of a one hot encoding is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Demo Onehot Encoding / 02 Demo Onehot Encoding
# Complete Code / 完整代码
# ===============================

# example of a one hot encoding
from numpy import asarray
from sklearn.preprocessing import OneHotEncoder
# define data
data = asarray([['red'], ['green'], ['blue']])
print(data)
# define one hot encoding
encoder = OneHotEncoder(sparse=False)
# transform data
onehot = encoder.fit_transform(data)
print(onehot)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 8
