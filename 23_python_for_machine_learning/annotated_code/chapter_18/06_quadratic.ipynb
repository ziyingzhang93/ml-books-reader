# %% [markdown]
# # 06 — Quadratic / 06 Quadratic
#
# **Chapter 18 — File 4 of 12 / 第18章 — 第4个文件（共12个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Quadratic**.
#
# 本脚本演示 **06 Quadratic**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
from math import sqrt

def quadratic(a,b,c):
    discrim = b*b - 4*a*c
    x = -b/(2*a)
    y = sqrt(discrim)/(2*a)
    return x-y, x+y

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Quadratic 是机器学习中的常用技术。
#   *Quadratic is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Quadratic / 06 Quadratic
# Complete Code / 完整代码
# ===============================

from math import sqrt

def quadratic(a,b,c):
    discrim = b*b - 4*a*c
    x = -b/(2*a)
    y = sqrt(discrim)/(2*a)
    return x-y, x+y

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 12
