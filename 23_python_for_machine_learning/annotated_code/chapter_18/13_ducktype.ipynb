# %% [markdown]
# # 13 — Ducktype / 13 Ducktype
#
# **Chapter 18 — File 11 of 12 / 第18章 — 第11个文件（共12个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Select rows from arrays X and y randomly**.
#
# 本脚本演示 **Select rows from arrays X and y randomly**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import pandas as pd
import numpy as np

def datagen(X, y, batch_size, sampling_rate=0.7):
    """A generator to produce samples from input numpy arrays X and y
    """

# %% [markdown]
# ---
# ## Step 2 — Select rows from arrays X and y randomly

# %%
indexing = np.random.random(len(X)) < sampling_rate
    Xsam, ysam = X[indexing], y[indexing]

# %% [markdown]
# ---
# ## Step 3 — Actual logic to generate batches

# %%
def _gen(batch_size):
        while True:
            Xbatch, ybatch = [], []
            for _ in range(batch_size):
                i = np.random.randint(len(Xsam))
                Xbatch.append(Xsam[i])  # iloc?
                ybatch.append(ysam[i])  # iloc?
            yield np.array(Xbatch), np.array(ybatch)

# %% [markdown]
# ---
# ## Step 4 — Create and return a generator

# %%
return _gen(batch_size)

X = pd.DataFrame(np.random.random((100,3)))
y = pd.DataFrame(np.random.random(100))

gen3 = datagen(X, y, 3)
print(next(gen3))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Select rows from arrays X and y randomly 是机器学习中的常用技术。
#   *Select rows from arrays X and y randomly is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Ducktype / 13 Ducktype
# Complete Code / 完整代码
# ===============================

import pandas as pd
import numpy as np

def datagen(X, y, batch_size, sampling_rate=0.7):
    """A generator to produce samples from input numpy arrays X and y
    """
    # Select rows from arrays X and y randomly
    indexing = np.random.random(len(X)) < sampling_rate
    Xsam, ysam = X[indexing], y[indexing]

    # Actual logic to generate batches
    def _gen(batch_size):
        while True:
            Xbatch, ybatch = [], []
            for _ in range(batch_size):
                i = np.random.randint(len(Xsam))
                Xbatch.append(Xsam[i])  # iloc?
                ybatch.append(ysam[i])  # iloc?
            yield np.array(Xbatch), np.array(ybatch)

    # Create and return a generator
    return _gen(batch_size)

X = pd.DataFrame(np.random.random((100,3)))
y = pd.DataFrame(np.random.random(100))

gen3 = datagen(X, y, 3)
print(next(gen3))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 12 of 12
