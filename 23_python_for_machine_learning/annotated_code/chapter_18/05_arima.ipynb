# %% [markdown]
# # 05 — Arima / ARIMA 模型
#
# **Chapter 18 — File 3 of 12 / 第18章 — 第3个文件（共12个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Arima**.
#
# 本脚本演示 **ARIMA 模型**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import numpy as np
import pandas as pd

data = [266.0,145.9,183.1,119.3,180.3,168.5,231.8,224.5,192.8,122.9,336.5,185.9,
        194.3,149.5,210.1,273.3,191.4,287.0,226.0,303.6,289.9,421.6,264.5,342.3,
        339.7,440.4,315.9,439.3,401.3,437.4,575.5,407.6,682.0,475.3,581.3,646.9]
model = SARIMAX(data, order=(5,1,0))
res = model.fit(disp=False)
print("AIC = ", res.aic)

y = np.array(data)
model = SARIMAX(y, order=(5,1,0))
res = model.fit(disp=False)
print("AIC = ", res.aic)

y = pd.Series(data)
model = SARIMAX(y, order=(5,1,0))
res = model.fit(disp=False)
print("AIC = ", res.aic)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Arima 是机器学习中的常用技术。
#   *Arima is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Arima / ARIMA 模型
# Complete Code / 完整代码
# ===============================

from statsmodels.tsa.statespace.sarimax import SARIMAX
import numpy as np
import pandas as pd

data = [266.0,145.9,183.1,119.3,180.3,168.5,231.8,224.5,192.8,122.9,336.5,185.9,
        194.3,149.5,210.1,273.3,191.4,287.0,226.0,303.6,289.9,421.6,264.5,342.3,
        339.7,440.4,315.9,439.3,401.3,437.4,575.5,407.6,682.0,475.3,581.3,646.9]
model = SARIMAX(data, order=(5,1,0))
res = model.fit(disp=False)
print("AIC = ", res.aic)

y = np.array(data)
model = SARIMAX(y, order=(5,1,0))
res = model.fit(disp=False)
print("AIC = ", res.aic)

y = pd.Series(data)
model = SARIMAX(y, order=(5,1,0))
res = model.fit(disp=False)
print("AIC = ", res.aic)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 12
