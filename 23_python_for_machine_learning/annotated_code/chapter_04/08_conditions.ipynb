# %% [markdown]
# # 08 — Conditions / 08 Conditions
#
# **Chapter 04 — File 8 of 15 / 第04章 — 第8个文件（共15个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Only add keys which are greater than 2**.
#
# 本脚本演示 **Only add keys which are greater than 2**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
original_dict = {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# %% [markdown]
# ---
# ## Step 2 — Only add keys which are greater than 2

# %%
new_dict_high_keys = {key:'number ' + value
                      for (key, value) in original_dict.items() if key>2}
print(new_dict_high_keys)

# %% [markdown]
# ---
# ## Step 3 — Only change values with key>2

# %%
new_dict_2 = {key:('number ' + value if key>2 else value)
              for (key, value) in original_dict.items() }
print(new_dict_2)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Only add keys which are greater than 2 是机器学习中的常用技术。
#   *Only add keys which are greater than 2 is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Conditions / 08 Conditions
# Complete Code / 完整代码
# ===============================

original_dict = {1: 'one', 2: 'two', 3: 'three', 4: 'four'}

# Only add keys which are greater than 2
new_dict_high_keys = {key:'number ' + value
                      for (key, value) in original_dict.items() if key>2}
print(new_dict_high_keys)

# Only change values with key>2
new_dict_2 = {key:('number ' + value if key>2 else value)
              for (key, value) in original_dict.items() }
print(new_dict_2)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 9 of 15
