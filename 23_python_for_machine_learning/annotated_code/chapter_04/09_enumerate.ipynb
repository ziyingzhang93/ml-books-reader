# %% [markdown]
# # 09 — Enumerate / 09 Enumerate
#
# **Chapter 04 — File 9 of 15 / 第04章 — 第9个文件（共15个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **enumerate returns two iterables**.
#
# 本脚本演示 **enumerate returns two iterables**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
name = ['Triangle', 'Square', 'Hexagon', 'Pentagon']

# %% [markdown]
# ---
# ## Step 2 — enumerate returns two iterables

# %%
for i, n in enumerate(name):
    print(i, 'name: ', n)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: enumerate returns two iterables 是机器学习中的常用技术。
#   *enumerate returns two iterables is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Enumerate / 09 Enumerate
# Complete Code / 完整代码
# ===============================

name = ['Triangle', 'Square', 'Hexagon', 'Pentagon']

# enumerate returns two iterables
for i, n in enumerate(name):
    print(i, 'name: ', n)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 10 of 15
