# %% [markdown]
# # 16 — Imagegen / 图像处理
#
# **Chapter 04 — File 15 of 15 / 第04章 — 第15个文件（共15个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **The next() function will load 8 images from CIFAR**.
#
# 本脚本演示 **The next() function will load 8 images from CIFAR**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import tensorflow.keras as keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

(x_train, y_train), _ = keras.datasets.cifar10.load_data()
datagen = ImageDataGenerator()
data_iterator = datagen.flow(x_train, y_train, batch_size=8)

fig, ax = plt.subplots(nrows=4, ncols=8, figsize=(18,6),
                       subplot_kw=dict(xticks=[], yticks=[]))
for i in range(4):

# %% [markdown]
# ---
# ## Step 2 — The next() function will load 8 images from CIFAR

# %%
X, Y = data_iterator.next()
    for j, img in enumerate(X):
        ax[i, j].imshow(img.astype('int'))
plt.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: The next() function will load 8 images from CIFAR 是机器学习中的常用技术。
#   *The next() function will load 8 images from CIFAR is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Imagegen / 图像处理
# Complete Code / 完整代码
# ===============================

import tensorflow.keras as keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

(x_train, y_train), _ = keras.datasets.cifar10.load_data()
datagen = ImageDataGenerator()
data_iterator = datagen.flow(x_train, y_train, batch_size=8)

fig, ax = plt.subplots(nrows=4, ncols=8, figsize=(18,6),
                       subplot_kw=dict(xticks=[], yticks=[]))
for i in range(4):
    # The next() function will load 8 images from CIFAR
    X, Y = data_iterator.next()
    for j, img in enumerate(X):
        ax[i, j].imshow(img.astype('int'))
plt.show()
