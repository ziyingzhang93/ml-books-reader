# %% [markdown]
# # 10 — Enumerate / 10 Enumerate
#
# **Chapter 04 — File 10 of 15 / 第04章 — 第10个文件（共15个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Enumerate**.
#
# 本脚本演示 **10 Enumerate**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
data = [1,4,1,5,9,2,6,5,3,5,8,9,7,9,3]
for n, digit in enumerate(data[5:], 6):
    print("The %d-th digit is %d" % (n, digit))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Enumerate 是机器学习中的常用技术。
#   *Enumerate is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Enumerate / 10 Enumerate
# Complete Code / 完整代码
# ===============================

data = [1,4,1,5,9,2,6,5,3,5,8,9,7,9,3]
for n, digit in enumerate(data[5:], 6):
    print("The %d-th digit is %d" % (n, digit))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 11 of 15
