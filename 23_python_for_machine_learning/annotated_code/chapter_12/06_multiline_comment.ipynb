# %% [markdown]
# # 06 — Multiline Comment / 06 Multiline Comment
#
# **Chapter 12 — File 4 of 10 / 第12章 — 第4个文件（共10个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Scan dirs for files and populate a list**.
#
# 本脚本演示 **Scan dirs for files and populate a list**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
async def main(indir):

# %% [markdown]
# ---
# ## Step 2 — Scan dirs for files and populate a list

# %%
filepaths = []
    for path, dirs, files in os.walk(indir):
        for basename in files:
            filepath = os.path.join(path, basename)
            filepaths.append(filepath)

    """Create the "process pool" of 4 and run asyncio.
    The processes will execute the worker function
    concurrently with each file path as parameter
    """
    loop = asyncio.get_running_loop()
    with concurrent.futures.ProcessPoolExecutor(max_workers=4) as executor:
        futures = [loop.run_in_executor(executor, func, f) for f in filepaths]
        for fut in asyncio.as_completed(futures):
            try:
                filepath = await fut
                print(filepath)
            except Exception as exc:
                print("failed one job")

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Scan dirs for files and populate a list 是机器学习中的常用技术。
#   *Scan dirs for files and populate a list is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Multiline Comment / 06 Multiline Comment
# Complete Code / 完整代码
# ===============================

async def main(indir):
    # Scan dirs for files and populate a list
    filepaths = []
    for path, dirs, files in os.walk(indir):
        for basename in files:
            filepath = os.path.join(path, basename)
            filepaths.append(filepath)

    """Create the "process pool" of 4 and run asyncio.
    The processes will execute the worker function
    concurrently with each file path as parameter
    """
    loop = asyncio.get_running_loop()
    with concurrent.futures.ProcessPoolExecutor(max_workers=4) as executor:
        futures = [loop.run_in_executor(executor, func, f) for f in filepaths]
        for fut in asyncio.as_completed(futures):
            try:
                filepath = await fut
                print(filepath)
            except Exception as exc:
                print("failed one job")

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 10
