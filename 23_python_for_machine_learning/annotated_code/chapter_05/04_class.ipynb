# %% [markdown]
# # 04 — Class / 04 Class
#
# **Chapter 05 — File 1 of 5 / 第05章 — 第1个文件（共5个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Class**.
#
# 本脚本演示 **04 Class**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
class Dog:
	family = "Canine"

	def __init__(self, name, breed):
		self.name = name
		self.breed = breed

dog1 = Dog("Lassie", "Rough Collie")
print(dog1.name)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Class 是机器学习中的常用技术。
#   *Class is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Class / 04 Class
# Complete Code / 完整代码
# ===============================

class Dog:
	family = "Canine"

	def __init__(self, name, breed):
		self.name = name
		self.breed = breed

dog1 = Dog("Lassie", "Rough Collie")
print(dog1.name)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 5
