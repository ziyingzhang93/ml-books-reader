# %% [markdown]
# # 06 — Methods / 06 Methods
#
# **Chapter 05 — File 2 of 5 / 第05章 — 第2个文件（共5个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Methods**.
#
# 本脚本演示 **06 Methods**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
class Dog:
	family = "Canine"

	def __init__(self, name, breed):
		self.name = name
		self.breed = breed
		self.tricks = []

	def add_tricks(self, x):
		self.tricks.append(x)

	def info(self, x):
		self.add_tricks(x)
		print(self.name, "is a female", self.breed, "that", self.tricks[0])

dog1 = Dog("Lassie", "Rough Collie")
dog1.info("barks on command")

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Methods 是机器学习中的常用技术。
#   *Methods is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Methods / 06 Methods
# Complete Code / 完整代码
# ===============================

class Dog:
	family = "Canine"

	def __init__(self, name, breed):
		self.name = name
		self.breed = breed
		self.tricks = []

	def add_tricks(self, x):
		self.tricks.append(x)

	def info(self, x):
		self.add_tricks(x)
		print(self.name, "is a female", self.breed, "that", self.tricks[0])

dog1 = Dog("Lassie", "Rough Collie")
dog1.info("barks on command")

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 5
