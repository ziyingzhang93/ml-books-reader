# %% [markdown]
# # 07 — String Hack / 07 String Hack
#
# **Chapter 15 — File 4 of 6 / 第15章 — 第4个文件（共6个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Covariance matrix and Cholesky decomposition**.
#
# 本脚本演示 **Covariance matrix and Cholesky decomposition**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import numpy as np
import scipy.stats as stats

# %% [markdown]
# ---
# ## Step 2 — Covariance matrix and Cholesky decomposition

# %%
cov = np.array([[1, 0.8], [0.8, 1]])
L = np.linalg.cholesky(cov)

# %% [markdown]
# ---
# ## Step 3 — Generate 100 pairs of bi-variate Gaussian random numbers

# %%
if not "USE SCIPY":
   z = np.random.randn(100,2)
   x = z @ L.T
else:
   x = stats.multivariate_normal(mean=[0, 0], cov=cov).rvs(100)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Covariance matrix and Cholesky decomposition 是机器学习中的常用技术。
#   *Covariance matrix and Cholesky decomposition is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# String Hack / 07 String Hack
# Complete Code / 完整代码
# ===============================

import numpy as np
import scipy.stats as stats

# Covariance matrix and Cholesky decomposition
cov = np.array([[1, 0.8], [0.8, 1]])
L = np.linalg.cholesky(cov)

# Generate 100 pairs of bi-variate Gaussian random numbers
if not "USE SCIPY":
   z = np.random.randn(100,2)
   x = z @ L.T
else:
   x = stats.multivariate_normal(mean=[0, 0], cov=cov).rvs(100)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 6
