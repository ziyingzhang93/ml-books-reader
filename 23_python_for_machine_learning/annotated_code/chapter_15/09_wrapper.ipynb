# %% [markdown]
# # 09 — Wrapper / 09 Wrapper
#
# **Chapter 15 — File 6 of 6 / 第15章 — 第6个文件（共6个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Student's t distribution with 3 degree of freedom**.
#
# 本脚本演示 **Student's t distribution with 3 degree of freedom**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import numpy as np

DIST = "t"

if DIST == "normal":
    rangen = np.random.normal
elif DIST == "uniform":
    rangen = np.random.uniform
elif DIST == "t":
    def t_wrapper(size):

# %% [markdown]
# ---
# ## Step 2 — Student's t distribution with 3 degree of freedom

# %%
return np.random.standard_t(df=3, size=size)
    rangen = t_wrapper
else:
    raise NotImplementedError

random_data = rangen(size=(10,5))
print(random_data)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Student's t distribution with 3 degree of freedom 是机器学习中的常用技术。
#   *Student's t distribution with 3 degree of freedom is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Wrapper / 09 Wrapper
# Complete Code / 完整代码
# ===============================

import numpy as np

DIST = "t"

if DIST == "normal":
    rangen = np.random.normal
elif DIST == "uniform":
    rangen = np.random.uniform
elif DIST == "t":
    def t_wrapper(size):
        # Student's t distribution with 3 degree of freedom
        return np.random.standard_t(df=3, size=size)
    rangen = t_wrapper
else:
    raise NotImplementedError

random_data = rangen(size=(10,5))
print(random_data)
