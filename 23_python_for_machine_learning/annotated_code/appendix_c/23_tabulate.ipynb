# %% [markdown]
# # 23 — Tabulate / 23 Tabulate
#
# **Chapter appendix_c — File 17 of 17 / 第appendix_c章 — 第17个文件（共17个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Rating equivalency**.
#
# 本脚本演示 **Rating equivalency**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
from tabulate import tabulate

# %% [markdown]
# ---
# ## Step 2 — Rating equivalency

# %%
ratings = [dict(zip(
    ["Moodys", "Fitch", "S&P", "FitchFactor", "MoodysFactor"], x)) for x in [
    ["Caa1",   "CCC+",  "CCC+",   62.8,         4770],
    ["Caa2",   "CCC",   "CCC",    62.8,         6500],
    ["Caa3",   "CCC-",  "CCC-",   62.8,         8070],
    ["Ca",     "CC",    "CC",    100,          10000],
    ["Ca",     "C",     "C",     100,          10000],
    ["C",      "DDD",   "RD",    100,          10000],
    [None,     "DD",    "SD",    100,           None],
    [None,     "D",     "D",     100,           None],
    ["NR",     "NR",    "NR",   None,           None],
    ["NA",     "NA",    "NA",   None,           None],
]]

print(tabulate(ratings, headers="keys", tablefmt="simple"))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Rating equivalency 是机器学习中的常用技术。
#   *Rating equivalency is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Tabulate / 23 Tabulate
# Complete Code / 完整代码
# ===============================

from tabulate import tabulate

# Rating equivalency
ratings = [dict(zip(
    ["Moodys", "Fitch", "S&P", "FitchFactor", "MoodysFactor"], x)) for x in [
    ["Caa1",   "CCC+",  "CCC+",   62.8,         4770],
    ["Caa2",   "CCC",   "CCC",    62.8,         6500],
    ["Caa3",   "CCC-",  "CCC-",   62.8,         8070],
    ["Ca",     "CC",    "CC",    100,          10000],
    ["Ca",     "C",     "C",     100,          10000],
    ["C",      "DDD",   "RD",    100,          10000],
    [None,     "DD",    "SD",    100,           None],
    [None,     "D",     "D",     100,           None],
    ["NR",     "NR",    "NR",   None,           None],
    ["NA",     "NA",    "NA",   None,           None],
]]

print(tabulate(ratings, headers="keys", tablefmt="simple"))
