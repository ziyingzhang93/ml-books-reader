# %% [markdown]
# # 03 — Serialization / 03 Serialization
#
# **Chapter 14 — File 3 of 13 / 第14章 — 第3个文件（共13个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **A test object**.
#
# 本脚本演示 **A test object**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import pickle

# %% [markdown]
# ---
# ## Step 2 — A test object

# %%
test_dict = {"Hello": "World!"}

# %% [markdown]
# ---
# ## Step 3 — Serialization

# %%
with open("test.pickle", "wb") as outfile:
    pickle.dump(test_dict, outfile)
print("Written object", test_dict)

# %% [markdown]
# ---
# ## Step 4 — Deserialization

# %%
with open("test.pickle", "rb") as infile:
    test_dict_reconstructed = pickle.load(infile)
print("Reconstructed object", test_dict_reconstructed)

if test_dict == test_dict_reconstructed:
    print("Reconstruction success")

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: A test object 是机器学习中的常用技术。
#   *A test object is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Serialization / 03 Serialization
# Complete Code / 完整代码
# ===============================

import pickle

# A test object
test_dict = {"Hello": "World!"}

# Serialization
with open("test.pickle", "wb") as outfile:
    pickle.dump(test_dict, outfile)
print("Written object", test_dict)

# Deserialization
with open("test.pickle", "rb") as infile:
    test_dict_reconstructed = pickle.load(infile)
print("Reconstructed object", test_dict_reconstructed)

if test_dict == test_dict_reconstructed:
    print("Reconstruction success")

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 13
