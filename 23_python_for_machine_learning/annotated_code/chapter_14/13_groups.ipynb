# %% [markdown]
# # 13 — Groups / 13 Groups
#
# **Chapter 14 — File 9 of 13 / 第14章 — 第9个文件（共13个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **creates new group_1 in file**.
#
# 本脚本演示 **creates new group_1 in file**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import h5py

with h5py.File("test.hdf5", "w") as file:

# %% [markdown]
# ---
# ## Step 2 — creates new group_1 in file

# %%
file.create_group("group_1")
    group1 = file["group_1"]

# %% [markdown]
# ---
# ## Step 3 — creates dataset inside group1

# %%
group1.create_dataset("dataset1", shape=(10,))

# %% [markdown]
# ---
# ## Step 4 — to access the dataset

# %%
dataset = file["group_1"]["dataset1"]

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: creates new group_1 in file 是机器学习中的常用技术。
#   *creates new group_1 in file is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Groups / 13 Groups
# Complete Code / 完整代码
# ===============================

import h5py

with h5py.File("test.hdf5", "w") as file:
    # creates new group_1 in file
    file.create_group("group_1")
    group1 = file["group_1"]
    # creates dataset inside group1
    group1.create_dataset("dataset1", shape=(10,))
    # to access the dataset
    dataset = file["group_1"]["dataset1"]

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 10 of 13
