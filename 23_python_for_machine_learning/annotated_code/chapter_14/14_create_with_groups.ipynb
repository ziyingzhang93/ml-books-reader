# %% [markdown]
# # 14 — Create With Groups / 14 Create With Groups
#
# **Chapter 14 — File 10 of 13 / 第14章 — 第10个文件（共13个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **creates dataset inside group1**.
#
# 本脚本演示 **creates dataset inside group1**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import h5py

with h5py.File("test.hdf5", "w") as file:

# %% [markdown]
# ---
# ## Step 2 — creates dataset inside group1

# %%
file.create_dataset("group1/dataset1", shape=(10,))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: creates dataset inside group1 是机器学习中的常用技术。
#   *creates dataset inside group1 is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Create With Groups / 14 Create With Groups
# Complete Code / 完整代码
# ===============================

import h5py

with h5py.File("test.hdf5", "w") as file:
    # creates dataset inside group1
    file.create_dataset("group1/dataset1", shape=(10,))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 11 of 13
