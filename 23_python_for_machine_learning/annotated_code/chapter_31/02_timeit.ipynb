# %% [markdown]
# # 02 — Timeit / 02 Timeit
#
# **Chapter 31 — File 1 of 5 / 第31章 — 第1个文件（共5个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Timeit**.
#
# 本脚本演示 **02 Timeit**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import timeit
import numpy as np

time = timeit.timeit("np.random.random()", globals=globals())
print(time)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Timeit 是机器学习中的常用技术。
#   *Timeit is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Timeit / 02 Timeit
# Complete Code / 完整代码
# ===============================

import timeit
import numpy as np

time = timeit.timeit("np.random.random()", globals=globals())
print(time)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 5
