# %% [markdown]
# # 06 — Diabetes / 06 Diabetes
#
# **Chapter 23 — File 6 of 16 / 第23章 — 第6个文件（共16个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Diabetes**.
#
# 本脚本演示 **06 Diabetes**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import sklearn.datasets

data = sklearn.datasets.fetch_openml("diabetes", version=1,
                                     as_frame=True, return_X_y=False)
data = data["frame"]
print(data)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Diabetes 是机器学习中的常用技术。
#   *Diabetes is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Diabetes / 06 Diabetes
# Complete Code / 完整代码
# ===============================

import sklearn.datasets

data = sklearn.datasets.fetch_openml("diabetes", version=1,
                                     as_frame=True, return_X_y=False)
data = data["frame"]
print(data)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 7 of 16
