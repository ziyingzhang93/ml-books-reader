# %% [markdown]
# # 15 — Regression / 回归
#
# **Chapter 23 — File 15 of 16 / 第23章 — 第15个文件（共16个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Generate 10-dimensional features and 1-dimensional targets**.
#
# 本脚本演示 **Generate 10-dimensional features and 1-dimensional targets**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
import numpy as np

# %% [markdown]
# ---
# ## Step 2 — Generate 10-dimensional features and 1-dimensional targets

# %%
X, y = make_regression(n_samples=500, n_features=10, n_targets=1, n_informative=4,
                       noise=0.5, bias=-2.5, random_state=42)

# %% [markdown]
# ---
# ## Step 3 — Run linear regression on the data

# %%
reg = LinearRegression()
reg.fit(X, y)

# %% [markdown]
# ---
# ## Step 4 — Print the coefficient and intercept found

# %%
with np.printoptions(precision=5, linewidth=100, suppress=True):
    print(np.array(reg.coef_))
    print(reg.intercept_)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Generate 10-dimensional features and 1-dimensional targets 是机器学习中的常用技术。
#   *Generate 10-dimensional features and 1-dimensional targets is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Regression / 回归
# Complete Code / 完整代码
# ===============================

from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
import numpy as np

# Generate 10-dimensional features and 1-dimensional targets
X, y = make_regression(n_samples=500, n_features=10, n_targets=1, n_informative=4,
                       noise=0.5, bias=-2.5, random_state=42)

# Run linear regression on the data
reg = LinearRegression()
reg.fit(X, y)

# Print the coefficient and intercept found
with np.printoptions(precision=5, linewidth=100, suppress=True):
    print(np.array(reg.coef_))
    print(reg.intercept_)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 16 of 16
