# %% [markdown]
# # 05 — Housing / 05 Housing
#
# **Chapter 23 — File 5 of 16 / 第23章 — 第5个文件（共16个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Housing**.
#
# 本脚本演示 **05 Housing**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import sklearn.datasets

data = sklearn.datasets.fetch_california_housing(return_X_y=False, as_frame=True)
data = data["frame"]
print(data)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Housing 是机器学习中的常用技术。
#   *Housing is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Housing / 05 Housing
# Complete Code / 完整代码
# ===============================

import sklearn.datasets

data = sklearn.datasets.fetch_california_housing(return_X_y=False, as_frame=True)
data = data["frame"]
print(data)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 6 of 16
