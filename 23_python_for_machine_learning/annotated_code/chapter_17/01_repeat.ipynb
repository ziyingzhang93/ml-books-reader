# %% [markdown]
# # 01 — Repeat / 01 Repeat
#
# **Chapter 17 — File 1 of 9 / 第17章 — 第1个文件（共9个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Repeat**.
#
# 本脚本演示 **01 Repeat**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
def repeat(fn):
    fn()
    fn()

def hello_world():
    print("Hello world!")

repeat(hello_world)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Repeat 是机器学习中的常用技术。
#   *Repeat is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Repeat / 01 Repeat
# Complete Code / 完整代码
# ===============================

def repeat(fn):
    fn()
    fn()

def hello_world():
    print("Hello world!")

repeat(hello_world)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 9
