# %% [markdown]
# # 11 — Lrucache / 11 Lrucache
#
# **Chapter 17 — File 9 of 9 / 第17章 — 第9个文件（共9个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **memoize using lru_cache**.
#
# 本脚本演示 **memoize using lru_cache**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import functools

import pandas_datareader as pdr

# %% [markdown]
# ---
# ## Step 2 — memoize using lru_cache

# %%
@functools.lru_cache
def get_stock_data(ticker):

# %% [markdown]
# ---
# ## Step 3 — pull data from stooq

# %%
df = pdr.stooq.StooqDailyReader(symbols=ticker, start="1/1/00", end="31/12/21"
                                   ).read()
    return df

# %% [markdown]
# ---
# ## Step 4 — testing call to function

# %%
import cProfile as profile
import pstats

for i in range(1, 3):
    print(f"Run {i}")
    run_profile = profile.Profile()
    run_profile.enable()
    get_stock_data("^DJI")
    run_profile.disable()
    pstats.Stats(run_profile).print_stats(0)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: memoize using lru_cache 是机器学习中的常用技术。
#   *memoize using lru_cache is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Lrucache / 11 Lrucache
# Complete Code / 完整代码
# ===============================

import functools

import pandas_datareader as pdr

# memoize using lru_cache
@functools.lru_cache
def get_stock_data(ticker):
    # pull data from stooq
    df = pdr.stooq.StooqDailyReader(symbols=ticker, start="1/1/00", end="31/12/21"
                                   ).read()
    return df

# testing call to function
import cProfile as profile
import pstats

for i in range(1, 3):
    print(f"Run {i}")
    run_profile = profile.Profile()
    run_profile.enable()
    get_stock_data("^DJI")
    run_profile.disable()
    pstats.Stats(run_profile).print_stats(0)
