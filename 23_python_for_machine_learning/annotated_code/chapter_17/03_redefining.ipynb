# %% [markdown]
# # 03 — Redefining / 03 Redefining
#
# **Chapter 17 — File 3 of 9 / 第17章 — 第3个文件（共9个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **returns a function**.
#
# 本脚本演示 **returns a function**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
def repeat_decorator(fn):
    def decorated_fn():
        fn()
        fn()

# %% [markdown]
# ---
# ## Step 2 — returns a function

# %%
return decorated_fn

def hello_world():
    print ("Hello world!")

hello_world = repeat_decorator(hello_world)

# %% [markdown]
# ---
# ## Step 3 — call the function

# %%
hello_world()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: returns a function 是机器学习中的常用技术。
#   *returns a function is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Redefining / 03 Redefining
# Complete Code / 完整代码
# ===============================

def repeat_decorator(fn):
    def decorated_fn():
        fn()
        fn()
    # returns a function
    return decorated_fn

def hello_world():
    print ("Hello world!")

hello_world = repeat_decorator(hello_world)

# call the function
hello_world()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 9
