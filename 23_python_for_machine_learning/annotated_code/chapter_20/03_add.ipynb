# %% [markdown]
# # 03 — Add / 03 Add
#
# **Chapter 20 — File 3 of 13 / 第20章 — 第3个文件（共13个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Add**.
#
# 本脚本演示 **03 Add**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
def add(a, b):
    try:
        a = float(a)
        b = float(b)
    except ValueError:
        raise ValueError("Input must be numbers")
    return a + b

add("one", "two")

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Add 是机器学习中的常用技术。
#   *Add is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Add / 03 Add
# Complete Code / 完整代码
# ===============================

def add(a, b):
    try:
        a = float(a)
        b = float(b)
    except ValueError:
        raise ValueError("Input must be numbers")
    return a + b

add("one", "two")

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 13
