# %% [markdown]
# # 04 — Range / 04 Range
#
# **Chapter 20 — File 4 of 13 / 第20章 — 第4个文件（共13个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Range**.
#
# 本脚本演示 **04 Range**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
def range(a, b=None, c=None):
    if c is None:
        c = 1
    if b is None:
        b = a
        a = 0
    values = []
    n = a
    while n < b:
        values.append(n)
        n = n + c
    return values

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Range 是机器学习中的常用技术。
#   *Range is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Range / 04 Range
# Complete Code / 完整代码
# ===============================

def range(a, b=None, c=None):
    if c is None:
        c = 1
    if b is None:
        b = a
        a = 0
    values = []
    n = a
    while n < b:
        values.append(n)
        n = n + c
    return values

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 13
