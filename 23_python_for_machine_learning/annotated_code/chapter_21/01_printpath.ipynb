# %% [markdown]
# # 01 — Printpath / 01 Printpath
#
# **Chapter 21 — File 1 of 1 / 第21章 — 第1个文件（共1个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Printpath**.
#
# 本脚本演示 **01 Printpath**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import sys
print(sys.path)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Printpath 是机器学习中的常用技术。
#   *Printpath is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Printpath / 01 Printpath
# Complete Code / 完整代码
# ===============================

import sys
print(sys.path)
