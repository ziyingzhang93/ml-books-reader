# %% [markdown]
# # 18 — Env / 18 Env
#
# **Chapter 16 — File 6 of 8 / 第16章 — 第6个文件（共8个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Env**.
#
# 本脚本演示 **18 Env**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import os
print(os.environ["MYVALUE"])

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Env 是机器学习中的常用技术。
#   *Env is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Env / 18 Env
# Complete Code / 完整代码
# ===============================

import os
print(os.environ["MYVALUE"])

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 7 of 8
