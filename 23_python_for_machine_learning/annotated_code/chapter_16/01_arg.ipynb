# %% [markdown]
# # 01 — Arg / 01 Arg
#
# **Chapter 16 — File 1 of 8 / 第16章 — 第1个文件（共8个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Arg**.
#
# 本脚本演示 **01 Arg**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import sys

n = int(sys.argv[1])
print(n+1)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Arg 是机器学习中的常用技术。
#   *Arg is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Arg / 01 Arg
# Complete Code / 完整代码
# ===============================

import sys

n = int(sys.argv[1])
print(n+1)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 8
