# %% [markdown]
# # 10 — Selenium / 10 Selenium
#
# **Chapter 22 — File 10 of 10 / 第22章 — 第10个文件（共10个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Launch Chrome browser in headless mode**.
#
# 本脚本演示 **Launch Chrome browser in headless mode**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import time
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By

# %% [markdown]
# ---
# ## Step 2 — Launch Chrome browser in headless mode

# %%
options = webdriver.ChromeOptions()
options.add_argument("headless")
browser = webdriver.Chrome(options=options)

# %% [markdown]
# ---
# ## Step 3 — Load web page

# %%
browser.get("https://www.yahoo.com")

# %% [markdown]
# ---
# ## Step 4 — Network transport takes time. Wait until the page is fully loaded

# %%
def is_ready(browser):
    return browser.execute_script(r"""
        return document.readyState === 'complete'
    """)
WebDriverWait(browser, 30).until(is_ready)

# %% [markdown]
# ---
# ## Step 5 — Scroll to bottom of the page to trigger JavaScript action

# %%
browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(1)
WebDriverWait(browser, 30).until(is_ready)

# %% [markdown]
# ---
# ## Step 6 — Search for news headlines and print

# %%
elements = browser.find_elements(By.XPATH, "//h3/a[u[@class='StretchedBox']]")
for elem in elements:
    print(elem.text)

# %% [markdown]
# ---
# ## Step 7 — Close the browser once finish

# %%
browser.close()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Launch Chrome browser in headless mode 是机器学习中的常用技术。
#   *Launch Chrome browser in headless mode is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Selenium / 10 Selenium
# Complete Code / 完整代码
# ===============================

import time
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By

# Launch Chrome browser in headless mode
options = webdriver.ChromeOptions()
options.add_argument("headless")
browser = webdriver.Chrome(options=options)

# Load web page
browser.get("https://www.yahoo.com")
# Network transport takes time. Wait until the page is fully loaded
def is_ready(browser):
    return browser.execute_script(r"""
        return document.readyState === 'complete'
    """)
WebDriverWait(browser, 30).until(is_ready)

# Scroll to bottom of the page to trigger JavaScript action
browser.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(1)
WebDriverWait(browser, 30).until(is_ready)

# Search for news headlines and print
elements = browser.find_elements(By.XPATH, "//h3/a[u[@class='StretchedBox']]")
for elem in elements:
    print(elem.text)

# Close the browser once finish
browser.close()
