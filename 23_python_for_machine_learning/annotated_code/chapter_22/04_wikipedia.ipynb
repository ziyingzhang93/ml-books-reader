# %% [markdown]
# # 04 — Wikipedia / 04 Wikipedia
#
# **Chapter 22 — File 4 of 10 / 第22章 — 第4个文件（共10个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Wikipedia**.
#
# 本脚本演示 **04 Wikipedia**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import requests

URL = "https://en.wikipedia.org/static/images/project-logos/enwiki.png"
wikilogo = requests.get(URL)
if wikilogo.status_code == 200:
    with open("enwiki.png", "wb") as fp:
        fp.write(wikilogo.content)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Wikipedia 是机器学习中的常用技术。
#   *Wikipedia is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Wikipedia / 04 Wikipedia
# Complete Code / 完整代码
# ===============================

import requests

URL = "https://en.wikipedia.org/static/images/project-logos/enwiki.png"
wikilogo = requests.get(URL)
if wikilogo.status_code == 200:
    with open("enwiki.png", "wb") as fp:
        fp.write(wikilogo.content)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 10
