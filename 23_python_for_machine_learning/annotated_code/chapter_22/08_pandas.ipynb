# %% [markdown]
# # 08 — Pandas / 08 Pandas
#
# **Chapter 22 — File 8 of 10 / 第22章 — 第8个文件（共10个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Pandas**.
#
# 本脚本演示 **08 Pandas**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import pandas as pd

tables = pd.read_html("https://www.federalreserve.gov/releases/h15/")
print(tables)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Pandas 是机器学习中的常用技术。
#   *Pandas is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Pandas / 08 Pandas
# Complete Code / 完整代码
# ===============================

import pandas as pd

tables = pd.read_html("https://www.federalreserve.gov/releases/h15/")
print(tables)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 9 of 10
