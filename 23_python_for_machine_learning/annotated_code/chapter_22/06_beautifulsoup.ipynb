# %% [markdown]
# # 06 — Beautifulsoup / 06 Beautifulsoup
#
# **Chapter 22 — File 6 of 10 / 第22章 — 第6个文件（共10个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **The numbers are lat-lon of New York**.
#
# 本脚本演示 **The numbers are lat-lon of New York**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import requests
from lxml import etree

# %% [markdown]
# ---
# ## Step 2 — The numbers are lat-lon of New York

# %%
URL = "https://weather.com/weather/today/l/40.75,-73.98"
resp = requests.get(URL)

# %% [markdown]
# ---
# ## Step 3 — Create DOM from HTML text

# %%
dom = etree.HTML(resp.text)

# %% [markdown]
# ---
# ## Step 4 — Search for the temperature element and get the content

# %%
elements = dom.xpath("//span[@data-testid='TemperatureValue' and contains(@class,'CurrentConditions')]")
print(elements[0].text)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: The numbers are lat-lon of New York 是机器学习中的常用技术。
#   *The numbers are lat-lon of New York is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Beautifulsoup / 06 Beautifulsoup
# Complete Code / 完整代码
# ===============================

import requests
from lxml import etree

# The numbers are lat-lon of New York
URL = "https://weather.com/weather/today/l/40.75,-73.98"
resp = requests.get(URL)
# Create DOM from HTML text
dom = etree.HTML(resp.text)
# Search for the temperature element and get the content
elements = dom.xpath("//span[@data-testid='TemperatureValue' and contains(@class,'CurrentConditions')]")
print(elements[0].text)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 7 of 10
