# %% [markdown]
# # 03 — Github / 03 Github
#
# **Chapter 22 — File 3 of 10 / 第22章 — 第3个文件（共10个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Github**.
#
# 本脚本演示 **03 Github**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import requests

URL = "https://api.github.com/users/jbrownlee"
resp = requests.get(URL)
if resp.status_code == 200:
    data = resp.json()
    print(data)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Github 是机器学习中的常用技术。
#   *Github is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Github / 03 Github
# Complete Code / 完整代码
# ===============================

import requests

URL = "https://api.github.com/users/jbrownlee"
resp = requests.get(URL)
if resp.status_code == 200:
    data = resp.json()
    print(data)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 10
