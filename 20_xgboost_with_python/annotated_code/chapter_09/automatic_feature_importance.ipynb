# %% [markdown]
# # 01 — Automatic Feature Importance / 特征工程
#
# **Chapter 09 — File 1 of 4 / 第09章 — 第1个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **plot feature importance using built-in function**.
#
# 本脚本演示 **plot feature importance using built-in function**。

# %% [markdown]
# ---
# ## Step 1 — plot feature importance using built-in function

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
from xgboost import plot_importance
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — load data

# %%
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=",")

# %% [markdown]
# ---
# ## Step 3 — split data into X and y

# %%
X = dataset[:,0:8]
y = dataset[:,8]

# %% [markdown]
# ---
# ## Step 4 — fit model on training data

# %%
model = XGBClassifier()
model.fit(X, y)

# %% [markdown]
# ---
# ## Step 5 — plot feature importance

# %%
plot_importance(model)
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: plot feature importance using built-in function 是机器学习中的常用技术。
#   *plot feature importance using built-in function is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Automatic Feature Importance / 特征工程
# Complete Code / 完整代码
# ===============================

# plot feature importance using built-in function
from numpy import loadtxt
from xgboost import XGBClassifier
from xgboost import plot_importance
from matplotlib import pyplot
# load data
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=",")
# split data into X and y
X = dataset[:,0:8]
y = dataset[:,8]
# fit model on training data
model = XGBClassifier()
model.fit(X, y)
# plot feature importance
plot_importance(model)
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 4
