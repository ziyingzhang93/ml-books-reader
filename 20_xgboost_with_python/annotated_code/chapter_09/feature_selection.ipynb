# %% [markdown]
# # 01 — Feature Selection / 特征工程
#
# **Chapter 09 — File 2 of 4 / 第09章 — 第2个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **use feature importance for feature selection**.
#
# 本脚本演示 **use feature importance for feature selection**。

# %% [markdown]
# ---
# ## Step 1 — use feature importance for feature selection

# %%
from numpy import loadtxt
from numpy import sort
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel

# %% [markdown]
# ---
# ## Step 2 — load data

# %%
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=",")

# %% [markdown]
# ---
# ## Step 3 — split data into X and y

# %%
X = dataset[:,0:8]
Y = dataset[:,8]

# %% [markdown]
# ---
# ## Step 4 — split data into train and test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=7)

# %% [markdown]
# ---
# ## Step 5 — fit model on all training data

# %%
model = XGBClassifier()
model.fit(X_train, y_train)

# %% [markdown]
# ---
# ## Step 6 — make predictions for test data and evaluate

# %%
predictions = model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %% [markdown]
# ---
# ## Step 7 — Fit model using each importance as a threshold

# %%
thresholds = sort(model.feature_importances_)
for thresh in thresholds:

# %% [markdown]
# ---
# ## Step 8 — select features using threshold

# %%
selection = SelectFromModel(model, threshold=thresh, prefit=True)
	select_X_train = selection.transform(X_train)

# %% [markdown]
# ---
# ## Step 9 — train model

# %%
selection_model = XGBClassifier()
	selection_model.fit(select_X_train, y_train)

# %% [markdown]
# ---
# ## Step 10 — eval model

# %%
select_X_test = selection.transform(X_test)
	predictions = selection_model.predict(select_X_test)
	accuracy = accuracy_score(y_test, predictions)
	print("Thresh=%.3f, n=%d, Accuracy: %.2f%%" % (thresh, select_X_train.shape[1], accuracy*100.0))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: use feature importance for feature selection 是机器学习中的常用技术。
#   *use feature importance for feature selection is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Feature Selection / 特征工程
# Complete Code / 完整代码
# ===============================

# use feature importance for feature selection
from numpy import loadtxt
from numpy import sort
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.feature_selection import SelectFromModel
# load data
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=",")
# split data into X and y
X = dataset[:,0:8]
Y = dataset[:,8]
# split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=7)
# fit model on all training data
model = XGBClassifier()
model.fit(X_train, y_train)
# make predictions for test data and evaluate
predictions = model.predict(X_test)
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# Fit model using each importance as a threshold
thresholds = sort(model.feature_importances_)
for thresh in thresholds:
	# select features using threshold
	selection = SelectFromModel(model, threshold=thresh, prefit=True)
	select_X_train = selection.transform(X_train)
	# train model
	selection_model = XGBClassifier()
	selection_model.fit(select_X_train, y_train)
	# eval model
	select_X_test = selection.transform(X_test)
	predictions = selection_model.predict(select_X_test)
	accuracy = accuracy_score(y_test, predictions)
	print("Thresh=%.3f, n=%d, Accuracy: %.2f%%" % (thresh, select_X_train.shape[1], accuracy*100.0))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 4
