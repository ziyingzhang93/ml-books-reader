# %% [markdown]
# # 01 — Cross Validation / 交叉验证
#
# **Chapter 06 — File 1 of 3 / 第06章 — 第1个文件（共3个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **k-fold cross validation evaluation of xgboost model**.
#
# 本脚本演示 **k-fold cross validation evaluation of xgboost model**。

# %% [markdown]
# ---
# ## Step 1 — k-fold cross validation evaluation of xgboost model

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

# %% [markdown]
# ---
# ## Step 2 — load data

# %%
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=",")

# %% [markdown]
# ---
# ## Step 3 — split data into X and y

# %%
X = dataset[:,0:8]
Y = dataset[:,8]

# %% [markdown]
# ---
# ## Step 4 — CV model

# %%
model = XGBClassifier()
kfold = KFold(n_splits=10)
results = cross_val_score(model, X, Y, cv=kfold)
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: k-fold cross validation evaluation of xgboost model 是机器学习中的常用技术。
#   *k-fold cross validation evaluation of xgboost model is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Cross Validation / 交叉验证
# Complete Code / 完整代码
# ===============================

# k-fold cross validation evaluation of xgboost model
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
# load data
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=",")
# split data into X and y
X = dataset[:,0:8]
Y = dataset[:,8]
# CV model
model = XGBClassifier()
kfold = KFold(n_splits=10)
results = cross_val_score(model, X, Y, cv=kfold)
print("Accuracy: %.2f%% (%.2f%%)" % (results.mean()*100, results.std()*100))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 3
