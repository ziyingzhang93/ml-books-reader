# %% [markdown]
# # 01 — Evaluate Validation Set / 模型评估
#
# **Chapter 10 — File 2 of 3 / 第10章 — 第2个文件（共3个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **monitor training performance**.
#
# 本脚本演示 **monitor training performance**。

# %% [markdown]
# ---
# ## Step 1 — monitor training performance

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ---
# ## Step 2 — load data

# %%
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=",")

# %% [markdown]
# ---
# ## Step 3 — split data into X and y

# %%
X = dataset[:,0:8]
Y = dataset[:,8]

# %% [markdown]
# ---
# ## Step 4 — split data into train and test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=7)

# %% [markdown]
# ---
# ## Step 5 — fit model on training data

# %%
model = XGBClassifier()
eval_set = [(X_test, y_test)]
model.fit(X_train, y_train, eval_metric="error", eval_set=eval_set, verbose=True)

# %% [markdown]
# ---
# ## Step 6 — make predictions for test data

# %%
predictions = model.predict(X_test)

# %% [markdown]
# ---
# ## Step 7 — evaluate predictions

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: monitor training performance 是机器学习中的常用技术。
#   *monitor training performance is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Evaluate Validation Set / 模型评估
# Complete Code / 完整代码
# ===============================

# monitor training performance
from numpy import loadtxt
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# load data
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=",")
# split data into X and y
X = dataset[:,0:8]
Y = dataset[:,8]
# split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.33, random_state=7)
# fit model on training data
model = XGBClassifier()
eval_set = [(X_test, y_test)]
model.fit(X_train, y_train, eval_metric="error", eval_set=eval_set, verbose=True)
# make predictions for test data
predictions = model.predict(X_test)
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 3
