# %% [markdown]
# # 01 — Iris Label Encode / 数据编码
#
# **Chapter 05 — File 4 of 4 / 第05章 — 第4个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **multiclass classification**.
#
# 本脚本演示 **multiclass classification**。

# %% [markdown]
# ---
# ## Step 1 — multiclass classification

# %%
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# ---
# ## Step 2 — load data

# %%
data = read_csv('iris.csv', header=None)
dataset = data.values

# %% [markdown]
# ---
# ## Step 3 — split data into X and y

# %%
X = dataset[:,0:4]
Y = dataset[:,4]

# %% [markdown]
# ---
# ## Step 4 — encode string class values as integers

# %%
label_encoder = LabelEncoder()
label_encoder = label_encoder.fit(Y)
label_encoded_y = label_encoder.transform(Y)
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X, label_encoded_y, test_size=test_size, random_state=seed)

# %% [markdown]
# ---
# ## Step 5 — fit model on training data

# %%
model = XGBClassifier()
model.fit(X_train, y_train)
print(model)

# %% [markdown]
# ---
# ## Step 6 — make predictions for test data

# %%
predictions = model.predict(X_test)

# %% [markdown]
# ---
# ## Step 7 — evaluate predictions

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: multiclass classification 是机器学习中的常用技术。
#   *multiclass classification is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Iris Label Encode / 数据编码
# Complete Code / 完整代码
# ===============================

# multiclass classification
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
# load data
data = read_csv('iris.csv', header=None)
dataset = data.values
# split data into X and y
X = dataset[:,0:4]
Y = dataset[:,4]
# encode string class values as integers
label_encoder = LabelEncoder()
label_encoder = label_encoder.fit(Y)
label_encoded_y = label_encoder.transform(Y)
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X, label_encoded_y, test_size=test_size, random_state=seed)
# fit model on training data
model = XGBClassifier()
model.fit(X_train, y_train)
print(model)
# make predictions for test data
predictions = model.predict(X_test)
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
