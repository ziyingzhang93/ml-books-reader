# %% [markdown]
# # 01 — Horse Colic Missing Imputer / 缺失值处理
#
# **Chapter 05 — File 3 of 4 / 第05章 — 第3个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **binary classification, missing data, impute with mean**.
#
# 本脚本演示 **binary classification, missing data, impute with mean**。

# %% [markdown]
# ---
# ## Step 1 — binary classification, missing data, impute with mean

# %%
import numpy
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer

# %% [markdown]
# ---
# ## Step 2 — load data

# %%
dataframe = read_csv("horse-colic.csv", delim_whitespace=True, header=None)
dataset = dataframe.values

# %% [markdown]
# ---
# ## Step 3 — split data into X and y

# %%
X = dataset[:,0:27]
Y = dataset[:,27]

# %% [markdown]
# ---
# ## Step 4 — set missing values to NaN

# %%
X[X == '?'] = numpy.nan

# %% [markdown]
# ---
# ## Step 5 — convert to numeric

# %%
X = X.astype('float32')

# %% [markdown]
# ---
# ## Step 6 — impute missing values as the mean

# %%
imputer = SimpleImputer()
imputed_x = imputer.fit_transform(X)

# %% [markdown]
# ---
# ## Step 7 — encode Y class values as integers

# %%
label_encoder = LabelEncoder()
label_encoder = label_encoder.fit(Y)
label_encoded_y = label_encoder.transform(Y)

# %% [markdown]
# ---
# ## Step 8 — split data into train and test sets

# %%
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(imputed_x, label_encoded_y, test_size=test_size, random_state=seed)

# %% [markdown]
# ---
# ## Step 9 — fit model on training data

# %%
model = XGBClassifier()
model.fit(X_train, y_train)
print(model)

# %% [markdown]
# ---
# ## Step 10 — make predictions for test data

# %%
predictions = model.predict(X_test)

# %% [markdown]
# ---
# ## Step 11 — evaluate predictions

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: binary classification, missing data, impute with mean 是机器学习中的常用技术。
#   *binary classification, missing data, impute with mean is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Horse Colic Missing Imputer / 缺失值处理
# Complete Code / 完整代码
# ===============================

# binary classification, missing data, impute with mean
import numpy
from pandas import read_csv
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.impute import SimpleImputer
# load data
dataframe = read_csv("horse-colic.csv", delim_whitespace=True, header=None)
dataset = dataframe.values
# split data into X and y
X = dataset[:,0:27]
Y = dataset[:,27]
# set missing values to NaN
X[X == '?'] = numpy.nan
# convert to numeric
X = X.astype('float32')
# impute missing values as the mean
imputer = SimpleImputer()
imputed_x = imputer.fit_transform(X)
# encode Y class values as integers
label_encoder = LabelEncoder()
label_encoder = label_encoder.fit(Y)
label_encoded_y = label_encoder.transform(Y)
# split data into train and test sets
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(imputed_x, label_encoded_y, test_size=test_size, random_state=seed)
# fit model on training data
model = XGBClassifier()
model.fit(X_train, y_train)
print(model)
# make predictions for test data
predictions = model.predict(X_test)
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 4
