# %% [markdown]
# # 01 — Serialize With Pickle / Serialize With Pickle
#
# **Chapter 08 — File 2 of 2 / 第08章 — 第2个文件（共2个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Train XGBoost model, save to file using pickle, load and make predictions**.
#
# 本脚本演示 **Train XGBoost model, save to file using pickle, load and make predictions**。

# %% [markdown]
# ---
# ## Step 1 — Train XGBoost model, save to file using pickle, load and make predictions

# %%
from numpy import loadtxt
from xgboost import XGBClassifier
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# ---
# ## Step 2 — load data

# %%
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=",")

# %% [markdown]
# ---
# ## Step 3 — split data into X and y

# %%
X = dataset[:,0:8]
Y = dataset[:,8]

# %% [markdown]
# ---
# ## Step 4 — split data into train and test sets

# %%
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)

# %% [markdown]
# ---
# ## Step 5 — fit model on training data

# %%
model = XGBClassifier()
model.fit(X_train, y_train)

# %% [markdown]
# ---
# ## Step 6 — save model to file

# %%
pickle.dump(model, open("pima.pickle.dat", "wb"))
print("Saved model to: pima.pickle.dat")

# %% [markdown]
# ---
# ## Step 7 — some time later...
# load model from file

# %%
loaded_model = pickle.load(open("pima.pickle.dat", "rb"))
print("Loaded model from: pima.pickle.dat")

# %% [markdown]
# ---
# ## Step 8 — make predictions for test data

# %%
predictions = loaded_model.predict(X_test)

# %% [markdown]
# ---
# ## Step 9 — evaluate predictions

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Train XGBoost model, save to file using pickle, load and make predictions 是机器学习中的常用技术。
#   *Train XGBoost model, save to file using pickle, load and make predictions is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Serialize With Pickle / Serialize With Pickle
# Complete Code / 完整代码
# ===============================

# Train XGBoost model, save to file using pickle, load and make predictions
from numpy import loadtxt
from xgboost import XGBClassifier
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
# load data
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=",")
# split data into X and y
X = dataset[:,0:8]
Y = dataset[:,8]
# split data into train and test sets
seed = 7
test_size = 0.33
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=test_size, random_state=seed)
# fit model on training data
model = XGBClassifier()
model.fit(X_train, y_train)
# save model to file
pickle.dump(model, open("pima.pickle.dat", "wb"))
print("Saved model to: pima.pickle.dat")

# some time later...

# load model from file
loaded_model = pickle.load(open("pima.pickle.dat", "rb"))
print("Loaded model from: pima.pickle.dat")
# make predictions for test data
predictions = loaded_model.predict(X_test)
# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
