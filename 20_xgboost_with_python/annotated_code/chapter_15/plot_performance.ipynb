# %% [markdown]
# # 01 — Plot Performance / Plot Performance
#
# **Chapter 15 — File 1 of 3 / 第15章 — 第1个文件（共3个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Plot performance for learning_rate=0.1**.
#
# 本脚本演示 **Plot performance for learning_rate=0.1**。

# %% [markdown]
# ---
# ## Step 1 — Plot performance for learning_rate=0.1

# %%
from matplotlib import pyplot
n_estimators = [100, 200, 300, 400, 500]
loss = [-0.001239, -0.001153, -0.001152, -0.001153, -0.001153]
pyplot.plot(n_estimators, loss)
pyplot.xlabel('n_estimators')
pyplot.ylabel('Log Loss')
pyplot.title('XGBoost learning_rate=0.1 n_estimators vs Log Loss')
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Plot performance for learning_rate=0.1 是机器学习中的常用技术。
#   *Plot performance for learning_rate=0.1 is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Plot Performance / Plot Performance
# Complete Code / 完整代码
# ===============================

# Plot performance for learning_rate=0.1
from matplotlib import pyplot
n_estimators = [100, 200, 300, 400, 500]
loss = [-0.001239, -0.001153, -0.001152, -0.001153, -0.001153]
pyplot.plot(n_estimators, loss)
pyplot.xlabel('n_estimators')
pyplot.ylabel('Log Loss')
pyplot.title('XGBoost learning_rate=0.1 n_estimators vs Log Loss')
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 3
