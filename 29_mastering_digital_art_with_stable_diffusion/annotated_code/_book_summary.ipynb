# %% [markdown]
# # Book Summary / 全书总结
# ## Mastering Digital Art with Stable Diffusion / Stable Diffusion 数字艺术
#
# ---
#
# This book contains **7 code files** across **2 chapters**.
#
# 本书包含 **2 个章节**，共 **7 个代码文件**。

# %% [markdown]
# ---
# ## Chapter Overview / 章节概览
#
# | Chapter | Topic / 主题 | Files |
# |:---:|:---|:---:|
# | 12 | Chapter 12 / Chapter 12 | 4 |
# | 15 | Chapter 15 / Chapter 15 | 3 |

# %% [markdown]
# ---
# ## Reading Path / 阅读路径
#
# Follow the chapters in order for a structured learning experience.
#
# 按章节顺序阅读，获得结构化的学习体验。
