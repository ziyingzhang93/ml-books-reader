# %% [markdown]
# # 27 — ROC and Precision-Recall / ROC与精确率-召回率
#
# **Chapter 27 — File 1 of 2**
#
# ## Summary / 汇总
#
# This notebook plots ROC curve with AUC for both no-skill and Logistic Regression classifiers. It compares a random baseline against a trained model.
#
# 本笔记本为无技能和逻辑回归分类器绘制带有AUC的ROC曲线。它将随机基线与训练模型进行比较。

# %% [markdown]
# ## Step 1 — Plot ROC Curve with Baselines and Model / 绘制带有基线和模型的ROC曲线

# %%
from sklearn.datasets import make_classificationfrom sklearn.linear_model import LogisticRegressionfrom sklearn.model_selection import train_test_splitfrom sklearn.metrics import roc_curve, roc_auc_scorefrom matplotlib import pyplot# generate 2 class datasetX, y = make_classification(n_samples=1000, n_classes=2, random_state=1)# split into train/test setstrainX, testX, trainy, testy = train_test_split(X, y, test_size=0.5, random_state=2)# generate a no skill prediction (majority class)ns_probs = [0 for _ in range(len(testy))]# fit a modelmodel = LogisticRegression(solver='lbfgs')model.fit(trainX, trainy)# predict probabilitieslr_probs = model.predict_proba(testX)# keep probabilities for the positive outcome onlylr_probs = lr_probs[:, 1]# calculate scoresns_auc = roc_auc_score(testy, ns_probs)lr_auc = roc_auc_score(testy, lr_probs)# summarize scoresprint('No Skill: ROC AUC=%.3f' % (ns_auc))print('Logistic: ROC AUC=%.3f' % (lr_auc))# calculate roc curvesns_fpr, ns_tpr, _ = roc_curve(testy, ns_probs)lr_fpr, lr_tpr, _ = roc_curve(testy, lr_probs)# plot the roc curve for the modelpyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')pyplot.plot(lr_fpr, lr_tpr, marker='.', label='Logistic')# axis labelspyplot.xlabel('False Positive Rate')pyplot.ylabel('True Positive Rate')# show the legendpyplot.legend()# show the plotpyplot.show()

# %% [markdown]
# ## Learning Notes / 学习笔记
#
# - **Concept**: Comparing classifiers via ROC curves shows discriminative power. No-skill classifier (constant predictions) produces the diagonal. Better models curve toward top-left. **概念**: 通过ROC曲线比较分类器显示了判别能力。无技能分类器(恒定预测)产生对角线。更好的模型向左上方弯曲。
#
# - **ML Application**: ROC curves provide a threshold-independent visualization for model comparison, especially useful for imbalanced problems where accuracy alone misleads. **机器学习应用**: ROC曲线为模型比较提供了与阈值无关的可视化，特别是对于准确率单独会误导的不平衡问题很有用。
#
# ➡️ **Next**: `02_precision_recall.ipynb`

# %% [markdown]
# ## Complete Code / 完整代码一览

# %%
from sklearn.datasets import make_classificationfrom sklearn.linear_model import LogisticRegressionfrom sklearn.model_selection import train_test_splitfrom sklearn.metrics import roc_curvefrom sklearn.metrics import roc_auc_scorefrom matplotlib import pyplotX, y = make_classification(n_samples=1000, n_classes=2, random_state=1)trainX, testX, trainy, testy = train_test_split(X, y, test_size=0.5, random_state=2)ns_probs = [0 for _ in range(len(testy))]model = LogisticRegression(solver='lbfgs')model.fit(trainX, trainy)lr_probs = model.predict_proba(testX)lr_probs = lr_probs[:, 1]ns_auc = roc_auc_score(testy, ns_probs)lr_auc = roc_auc_score(testy, lr_probs)print('No Skill: ROC AUC=%.3f' % (ns_auc))print('Logistic: ROC AUC=%.3f' % (lr_auc))ns_fpr, ns_tpr, _ = roc_curve(testy, ns_probs)lr_fpr, lr_tpr, _ = roc_curve(testy, lr_probs)pyplot.plot(ns_fpr, ns_tpr, linestyle='--', label='No Skill')pyplot.plot(lr_fpr, lr_tpr, marker='.', label='Logistic')pyplot.xlabel('False Positive Rate')pyplot.ylabel('True Positive Rate')pyplot.legend()pyplot.show()
