# %% [markdown]
# # 27 — ROC and Precision-Recall / ROC与精确率-召回率
#
# **Chapter 27 — File 2 of 2**
#
# ## Summary / 汇总
#
# This notebook plots Precision-Recall curve and calculates F1 score and PR-AUC. Precision-Recall is more informative than ROC for imbalanced problems.
#
# 本笔记本绘制精确率-召回率曲线并计算F1评分和PR-AUC。对于不平衡问题，精确率-召回率比ROC更有信息量。

# %% [markdown]
# ## Step 1 — Plot Precision-Recall Curve and Calculate Metrics / 绘制精确率-召回率曲线并计算指标

# %%
from sklearn.datasets import make_classificationfrom sklearn.linear_model import LogisticRegressionfrom sklearn.model_selection import train_test_splitfrom sklearn.metrics import precision_recall_curve, f1_score, aucfrom matplotlib import pyplot# generate 2 class datasetX, y = make_classification(n_samples=1000, n_classes=2, random_state=1)# split into train/test setstrainX, testX, trainy, testy = train_test_split(X, y, test_size=0.5, random_state=2)# fit a modelmodel = LogisticRegression(solver='lbfgs')model.fit(trainX, trainy)# predict probabilitieslr_probs = model.predict_proba(testX)# keep probabilities for the positive outcome onlylr_probs = lr_probs[:, 1]# predict class valuesyhat = model.predict(testX)# calculate precision-recall curvelr_precision, lr_recall, _ = precision_recall_curve(testy, lr_probs)# calculate F1 and PR-AUClr_f1, lr_auc = f1_score(testy, yhat), auc(lr_recall, lr_precision)# summarize scoresprint('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))# plot the precision-recall curvesno_skill = len(testy[testy==1]) / len(testy)pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')pyplot.plot(lr_recall, lr_precision, marker='.', label='Logistic')# axis labelspyplot.xlabel('Recall')pyplot.ylabel('Precision')# show the legendpyplot.legend()# show the plotpyplot.show()

# %% [markdown]
# ## Learning Notes / 学习笔记
#
# - **Concept**: Precision-Recall curves show precision (TP/(TP+FP)) vs recall (TP/(TP+FN)). For imbalanced data, PR curves are more informative than ROC because they focus on the positive class. **概念**: 精确率-召回率曲线显示精确率(TP/(TP+FP))对召回率(TP/(TP+FN))。对于不平衡数据，PR曲线比ROC更有信息量，因为它们关注正类。
#
# - **ML Application**: PR curves reveal how models handle the minority class. A model perfect on majority class but poor on minority class will have high ROC-AUC but low PR-AUC, making PR-AUC a better metric for imbalanced problems. **机器学习应用**: PR曲线揭示模型如何处理少数类。在多数类上完美但在少数类上表现差的模型将具有高ROC-AUC但低PR-AUC，使PR-AUC成为不平衡问题的更好指标。
#
# ➡️ **Next**: `../chapter_28/01_svm_reliability.ipynb`

# %% [markdown]
# ## Complete Code / 完整代码一览

# %%
from sklearn.datasets import make_classificationfrom sklearn.linear_model import LogisticRegressionfrom sklearn.model_selection import train_test_splitfrom sklearn.metrics import precision_recall_curvefrom sklearn.metrics import f1_scorefrom sklearn.metrics import aucfrom matplotlib import pyplotX, y = make_classification(n_samples=1000, n_classes=2, random_state=1)trainX, testX, trainy, testy = train_test_split(X, y, test_size=0.5, random_state=2)model = LogisticRegression(solver='lbfgs')model.fit(trainX, trainy)lr_probs = model.predict_proba(testX)lr_probs = lr_probs[:, 1]yhat = model.predict(testX)lr_precision, lr_recall, _ = precision_recall_curve(testy, lr_probs)lr_f1, lr_auc = f1_score(testy, yhat), auc(lr_recall, lr_precision)print('Logistic: f1=%.3f auc=%.3f' % (lr_f1, lr_auc))no_skill = len(testy[testy==1]) / len(testy)pyplot.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')pyplot.plot(lr_recall, lr_precision, marker='.', label='Logistic')pyplot.xlabel('Recall')pyplot.ylabel('Precision')pyplot.legend()pyplot.show()
