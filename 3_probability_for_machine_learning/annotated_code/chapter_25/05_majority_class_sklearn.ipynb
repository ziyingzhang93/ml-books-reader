# %% [markdown]
# # 25 — Baseline Classifiers / 基线分类器
#
# **Chapter 25 — File 5 of 5**
#
# ## Summary / 汇总
#
# This notebook uses scikit-learn's DummyClassifier with strategy='most_frequent' for majority class baseline. It integrates with sklearn pipelines.
#
# 本笔记本使用scikit-learn的DummyClassifier，其中strategy='most_frequent'为多数类基线。它与sklearn管道集成。

# %% [markdown]
# ## Step 1 — Majority Class with Scikit-Learn / 使用Scikit-Learn的多数类

# %%
from numpy import asarrayfrom sklearn.dummy import DummyClassifierfrom sklearn.metrics import accuracy_score# define datasetX = asarray([0 for _ in range(100)])class0 = [0 for _ in range(25)]class1 = [1 for _ in range(75)]y = asarray(class0 + class1)# reshape data for sklearnX = X.reshape((len(X), 1))# define model: DummyClassifier with most_frequent strategymodel = DummyClassifier(strategy='most_frequent')# fit model (learns the mode, no actual learning)model.fit(X, y)# make predictionsyhat = model.predict(X)# calculate accuracyaccuracy = accuracy_score(y, yhat)print('Accuracy: %.3f' % accuracy)

# %% [markdown]
# ## Learning Notes / 学习笔记
#
# - **Concept**: DummyClassifier is sklearn's built-in baseline. Different strategies ('most_frequent', 'stratified', 'uniform') provide different baselines for comparison. **概念**: DummyClassifier是sklearn的内置基线。不同的策略('most_frequent', 'stratified', 'uniform')为比较提供了不同的基线。
#
# - **ML Application**: Using DummyClassifier ensures consistency with sklearn conventions and integrates with cross-validation pipelines. It's industry best practice for establishing performance baselines. **机器学习应用**: 使用DummyClassifier确保与sklearn约定的一致性，并与交叉验证管道集成。这是建立性能基线的行业最佳实践。
#
# ➡️ **Next**: `../chapter_26/01_log_loss_each_class.ipynb`

# %% [markdown]
# ## Complete Code / 完整代码一览

# %%
from numpy import asarrayfrom sklearn.dummy import DummyClassifierfrom sklearn.metrics import accuracy_scoreX = asarray([0 for _ in range(100)])class0 = [0 for _ in range(25)]class1 = [1 for _ in range(75)]y = asarray(class0 + class1)X = X.reshape((len(X), 1))model = DummyClassifier(strategy='most_frequent')model.fit(X, y)yhat = model.predict(X)accuracy = accuracy_score(y, yhat)print('Accuracy: %.3f' % accuracy)
