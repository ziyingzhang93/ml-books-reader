# %% [markdown]
# # 23 — Plot Adadelta / 23 Plot Adadelta
#
# **Chapter 25 — File 4 of 4 / 第25章 — 第4个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of plotting the adadelta search on a contour plot of the test function**.
#
# 本脚本演示 **example of plotting the adadelta search on a contour plot of the test function**。

# %% [markdown]
# ---
# ## Step 1 — example of plotting the adadelta search on a contour plot of the test function

# %%
from math import sqrt
from numpy import asarray
from numpy import arange
from numpy.random import rand
from numpy.random import seed
from numpy import meshgrid
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ---
# ## Step 2 — objective function

# %%
def objective(x, y):
	return x**2.0 + y**2.0

# %% [markdown]
# ---
# ## Step 3 — derivative of objective function

# %%
def derivative(x, y):
	return asarray([x * 2.0, y * 2.0])

# %% [markdown]
# ---
# ## Step 4 — gradient descent algorithm with adadelta

# %%
def adadelta(objective, derivative, bounds, n_iter, rho, ep=1e-3):

# %% [markdown]
# ---
# ## Step 5 — track all solutions

# %%
solutions = list()

# %% [markdown]
# ---
# ## Step 6 — generate an initial point

# %%
solution = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])

# %% [markdown]
# ---
# ## Step 7 — list of the average square gradients for each variable

# %%
sq_grad_avg = [0.0 for _ in range(bounds.shape[0])]

# %% [markdown]
# ---
# ## Step 8 — list of the average parameter updates

# %%
sq_para_avg = [0.0 for _ in range(bounds.shape[0])]

# %% [markdown]
# ---
# ## Step 9 — run the gradient descent

# %%
for it in range(n_iter):

# %% [markdown]
# ---
# ## Step 10 — calculate gradient

# %%
gradient = derivative(solution[0], solution[1])

# %% [markdown]
# ---
# ## Step 11 — update the average of the squared partial derivatives

# %%
for i in range(gradient.shape[0]):

# %% [markdown]
# ---
# ## Step 12 — calculate the squared gradient

# %%
sg = gradient[i]**2.0

# %% [markdown]
# ---
# ## Step 13 — update the moving average of the squared gradient

# %%
sq_grad_avg[i] = (sq_grad_avg[i] * rho) + (sg * (1.0-rho))

# %% [markdown]
# ---
# ## Step 14 — build solution

# %%
new_solution = list()
		for i in range(solution.shape[0]):

# %% [markdown]
# ---
# ## Step 15 — calculate the step size for this variable

# %%
alpha = (ep + sqrt(sq_para_avg[i])) / (ep + sqrt(sq_grad_avg[i]))

# %% [markdown]
# ---
# ## Step 16 — calculate the change

# %%
change = alpha * gradient[i]

# %% [markdown]
# ---
# ## Step 17 — update the moving average of squared parameter changes

# %%
sq_para_avg[i] = (sq_para_avg[i] * rho) + (change**2.0 * (1.0-rho))

# %% [markdown]
# ---
# ## Step 18 — calculate the new position in this variable

# %%
value = solution[i] - change

# %% [markdown]
# ---
# ## Step 19 — store this variable

# %%
new_solution.append(value)

# %% [markdown]
# ---
# ## Step 20 — store the new solution

# %%
solution = asarray(new_solution)
		solutions.append(solution)

# %% [markdown]
# ---
# ## Step 21 — evaluate candidate point

# %%
solution_eval = objective(solution[0], solution[1])

# %% [markdown]
# ---
# ## Step 22 — report progress

# %%
print('>%d f(%s) = %.5f' % (it, solution, solution_eval))
	return solutions

# %% [markdown]
# ---
# ## Step 23 — seed the pseudo random number generator

# %%
seed(1)

# %% [markdown]
# ---
# ## Step 24 — define range for input

# %%
bounds = asarray([[-1.0, 1.0], [-1.0, 1.0]])

# %% [markdown]
# ---
# ## Step 25 — define the total iterations

# %%
n_iter = 120

# %% [markdown]
# ---
# ## Step 26 — rho for adadelta

# %%
rho = 0.99

# %% [markdown]
# ---
# ## Step 27 — perform the gradient descent search with adadelta

# %%
solutions = adadelta(objective, derivative, bounds, n_iter, rho)

# %% [markdown]
# ---
# ## Step 28 — sample input range uniformly at 0.1 increments

# %%
xaxis = arange(bounds[0,0], bounds[0,1], 0.1)
yaxis = arange(bounds[1,0], bounds[1,1], 0.1)

# %% [markdown]
# ---
# ## Step 29 — create a mesh from the axis

# %%
x, y = meshgrid(xaxis, yaxis)

# %% [markdown]
# ---
# ## Step 30 — compute targets

# %%
results = objective(x, y)

# %% [markdown]
# ---
# ## Step 31 — create a filled contour plot with 50 levels and jet color scheme

# %%
pyplot.contourf(x, y, results, levels=50, cmap='jet')

# %% [markdown]
# ---
# ## Step 32 — plot the sample as black circles

# %%
solutions = asarray(solutions)
pyplot.plot(solutions[:, 0], solutions[:, 1], '.-', color='w')

# %% [markdown]
# ---
# ## Step 33 — show the plot

# %%
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of plotting the adadelta search on a contour plot of the test function 是机器学习中的常用技术。
#   *example of plotting the adadelta search on a contour plot of the test function is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Plot Adadelta / 23 Plot Adadelta
# Complete Code / 完整代码
# ===============================

# example of plotting the adadelta search on a contour plot of the test function
from math import sqrt
from numpy import asarray
from numpy import arange
from numpy.random import rand
from numpy.random import seed
from numpy import meshgrid
from matplotlib import pyplot
from mpl_toolkits.mplot3d import Axes3D

# objective function
def objective(x, y):
	return x**2.0 + y**2.0

# derivative of objective function
def derivative(x, y):
	return asarray([x * 2.0, y * 2.0])

# gradient descent algorithm with adadelta
def adadelta(objective, derivative, bounds, n_iter, rho, ep=1e-3):
	# track all solutions
	solutions = list()
	# generate an initial point
	solution = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])
	# list of the average square gradients for each variable
	sq_grad_avg = [0.0 for _ in range(bounds.shape[0])]
	# list of the average parameter updates
	sq_para_avg = [0.0 for _ in range(bounds.shape[0])]
	# run the gradient descent
	for it in range(n_iter):
		# calculate gradient
		gradient = derivative(solution[0], solution[1])
		# update the average of the squared partial derivatives
		for i in range(gradient.shape[0]):
			# calculate the squared gradient
			sg = gradient[i]**2.0
			# update the moving average of the squared gradient
			sq_grad_avg[i] = (sq_grad_avg[i] * rho) + (sg * (1.0-rho))
		# build solution
		new_solution = list()
		for i in range(solution.shape[0]):
			# calculate the step size for this variable
			alpha = (ep + sqrt(sq_para_avg[i])) / (ep + sqrt(sq_grad_avg[i]))
			# calculate the change
			change = alpha * gradient[i]
			# update the moving average of squared parameter changes
			sq_para_avg[i] = (sq_para_avg[i] * rho) + (change**2.0 * (1.0-rho))
			# calculate the new position in this variable
			value = solution[i] - change
			# store this variable
			new_solution.append(value)
		# store the new solution
		solution = asarray(new_solution)
		solutions.append(solution)
		# evaluate candidate point
		solution_eval = objective(solution[0], solution[1])
		# report progress
		print('>%d f(%s) = %.5f' % (it, solution, solution_eval))
	return solutions

# seed the pseudo random number generator
seed(1)
# define range for input
bounds = asarray([[-1.0, 1.0], [-1.0, 1.0]])
# define the total iterations
n_iter = 120
# rho for adadelta
rho = 0.99
# perform the gradient descent search with adadelta
solutions = adadelta(objective, derivative, bounds, n_iter, rho)
# sample input range uniformly at 0.1 increments
xaxis = arange(bounds[0,0], bounds[0,1], 0.1)
yaxis = arange(bounds[1,0], bounds[1,1], 0.1)
# create a mesh from the axis
x, y = meshgrid(xaxis, yaxis)
# compute targets
results = objective(x, y)
# create a filled contour plot with 50 levels and jet color scheme
pyplot.contourf(x, y, results, levels=50, cmap='jet')
# plot the sample as black circles
solutions = asarray(solutions)
pyplot.plot(solutions[:, 0], solutions[:, 1], '.-', color='w')
# show the plot
pyplot.show()
