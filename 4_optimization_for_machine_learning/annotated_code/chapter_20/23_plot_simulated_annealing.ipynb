# %% [markdown]
# # 23 — Plot Simulated Annealing / 23 Plot Simulated Annealing
#
# **Chapter 20 — File 5 of 5 / 第20章 — 第5个文件（共5个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **simulated annealing search of a one-dimensional objective function**.
#
# 本脚本演示 **simulated annealing search of a one-dimensional objective function**。

# %% [markdown]
# ---
# ## Step 1 — simulated annealing search of a one-dimensional objective function

# %%
from numpy import asarray
from numpy import exp
from numpy.random import randn
from numpy.random import rand
from numpy.random import seed
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — objective function

# %%
def objective(x):
	return x[0]**2.0

# %% [markdown]
# ---
# ## Step 3 — simulated annealing algorithm

# %%
def simulated_annealing(objective, bounds, n_iterations, step_size, temp):

# %% [markdown]
# ---
# ## Step 4 — generate an initial point

# %%
best = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])

# %% [markdown]
# ---
# ## Step 5 — evaluate the initial point

# %%
best_eval = objective(best)

# %% [markdown]
# ---
# ## Step 6 — current working solution

# %%
curr, curr_eval = best, best_eval
	scores = list()

# %% [markdown]
# ---
# ## Step 7 — run the algorithm

# %%
for i in range(n_iterations):

# %% [markdown]
# ---
# ## Step 8 — take a step

# %%
candidate = curr + randn(len(bounds)) * step_size

# %% [markdown]
# ---
# ## Step 9 — evaluate candidate point

# %%
candidate_eval = objective(candidate)

# %% [markdown]
# ---
# ## Step 10 — check for new best solution

# %%
if candidate_eval < best_eval:

# %% [markdown]
# ---
# ## Step 11 — store new best point

# %%
best, best_eval = candidate, candidate_eval

# %% [markdown]
# ---
# ## Step 12 — keep track of scores

# %%
scores.append(best_eval)

# %% [markdown]
# ---
# ## Step 13 — report progress

# %%
print('>%d f(%s) = %.5f' % (i, best, best_eval))

# %% [markdown]
# ---
# ## Step 14 — difference between candidate and current point evaluation

# %%
diff = candidate_eval - curr_eval

# %% [markdown]
# ---
# ## Step 15 — calculate temperature for current epoch

# %%
t = temp / float(i + 1)

# %% [markdown]
# ---
# ## Step 16 — calculate metropolis acceptance criterion

# %%
metropolis = exp(-diff / t)

# %% [markdown]
# ---
# ## Step 17 — check if we should keep the new point

# %%
if diff < 0 or rand() < metropolis:

# %% [markdown]
# ---
# ## Step 18 — store the new current point

# %%
curr, curr_eval = candidate, candidate_eval
	return [best, best_eval, scores]

# %% [markdown]
# ---
# ## Step 19 — seed the pseudorandom number generator

# %%
seed(1)

# %% [markdown]
# ---
# ## Step 20 — define range for input

# %%
bounds = asarray([[-5.0, 5.0]])

# %% [markdown]
# ---
# ## Step 21 — define the total iterations

# %%
n_iterations = 1000

# %% [markdown]
# ---
# ## Step 22 — define the maximum step size

# %%
step_size = 0.1

# %% [markdown]
# ---
# ## Step 23 — initial temperature

# %%
temp = 10

# %% [markdown]
# ---
# ## Step 24 — perform the simulated annealing search

# %%
best, score, scores = simulated_annealing(objective, bounds, n_iterations, step_size, temp)
print('Done!')
print('f(%s) = %f' % (best, score))

# %% [markdown]
# ---
# ## Step 25 — line plot of best scores

# %%
pyplot.plot(scores, '.-')
pyplot.xlabel('Improvement Number')
pyplot.ylabel('Evaluation f(x)')
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: simulated annealing search of a one-dimensional objective function 是机器学习中的常用技术。
#   *simulated annealing search of a one-dimensional objective function is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Plot Simulated Annealing / 23 Plot Simulated Annealing
# Complete Code / 完整代码
# ===============================

# simulated annealing search of a one-dimensional objective function
from numpy import asarray
from numpy import exp
from numpy.random import randn
from numpy.random import rand
from numpy.random import seed
from matplotlib import pyplot

# objective function
def objective(x):
	return x[0]**2.0

# simulated annealing algorithm
def simulated_annealing(objective, bounds, n_iterations, step_size, temp):
	# generate an initial point
	best = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])
	# evaluate the initial point
	best_eval = objective(best)
	# current working solution
	curr, curr_eval = best, best_eval
	scores = list()
	# run the algorithm
	for i in range(n_iterations):
		# take a step
		candidate = curr + randn(len(bounds)) * step_size
		# evaluate candidate point
		candidate_eval = objective(candidate)
		# check for new best solution
		if candidate_eval < best_eval:
			# store new best point
			best, best_eval = candidate, candidate_eval
			# keep track of scores
			scores.append(best_eval)
			# report progress
			print('>%d f(%s) = %.5f' % (i, best, best_eval))
		# difference between candidate and current point evaluation
		diff = candidate_eval - curr_eval
		# calculate temperature for current epoch
		t = temp / float(i + 1)
		# calculate metropolis acceptance criterion
		metropolis = exp(-diff / t)
		# check if we should keep the new point
		if diff < 0 or rand() < metropolis:
			# store the new current point
			curr, curr_eval = candidate, candidate_eval
	return [best, best_eval, scores]

# seed the pseudorandom number generator
seed(1)
# define range for input
bounds = asarray([[-5.0, 5.0]])
# define the total iterations
n_iterations = 1000
# define the maximum step size
step_size = 0.1
# initial temperature
temp = 10
# perform the simulated annealing search
best, score, scores = simulated_annealing(objective, bounds, n_iterations, step_size, temp)
print('Done!')
print('f(%s) = %f' % (best, score))
# line plot of best scores
pyplot.plot(scores, '.-')
pyplot.xlabel('Improvement Number')
pyplot.ylabel('Evaluation f(x)')
pyplot.show()
