# %% [markdown]
# # 11 — Lbfgsb / 11 Lbfgsb
#
# **Chapter 13 — File 2 of 2 / 第13章 — 第2个文件（共2个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **l-bfgs-b algorithm local optimization of a convex function**.
#
# 本脚本演示 **l-bfgs-b algorithm local optimization of a convex function**。

# %% [markdown]
# ---
# ## Step 1 — l-bfgs-b algorithm local optimization of a convex function

# %%
from scipy.optimize import minimize
from numpy.random import rand

# %% [markdown]
# ---
# ## Step 2 — objective function

# %%
def objective(x):
	return x[0]**2.0 + x[1]**2.0

# %% [markdown]
# ---
# ## Step 3 — derivative of the objective function

# %%
def derivative(x):
	return [x[0] * 2, x[1] * 2]

# %% [markdown]
# ---
# ## Step 4 — define range for input

# %%
r_min, r_max = -5.0, 5.0

# %% [markdown]
# ---
# ## Step 5 — define the starting point as a random sample from the domain

# %%
pt = r_min + rand(2) * (r_max - r_min)

# %% [markdown]
# ---
# ## Step 6 — perform the l-bfgs-b algorithm search

# %%
result = minimize(objective, pt, method='L-BFGS-B', jac=derivative)

# %% [markdown]
# ---
# ## Step 7 — summarize the result

# %%
print('Status : %s' % result['message'])
print('Total Evaluations: %d' % result['nfev'])

# %% [markdown]
# ---
# ## Step 8 — evaluate solution

# %%
solution = result['x']
evaluation = objective(solution)
print('Solution: f(%s) = %.5f' % (solution, evaluation))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: l-bfgs-b algorithm local optimization of a convex function 是机器学习中的常用技术。
#   *l-bfgs-b algorithm local optimization of a convex function is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Lbfgsb / 11 Lbfgsb
# Complete Code / 完整代码
# ===============================

# l-bfgs-b algorithm local optimization of a convex function
from scipy.optimize import minimize
from numpy.random import rand

# objective function
def objective(x):
	return x[0]**2.0 + x[1]**2.0

# derivative of the objective function
def derivative(x):
	return [x[0] * 2, x[1] * 2]

# define range for input
r_min, r_max = -5.0, 5.0
# define the starting point as a random sample from the domain
pt = r_min + rand(2) * (r_max - r_min)
# perform the l-bfgs-b algorithm search
result = minimize(objective, pt, method='L-BFGS-B', jac=derivative)
# summarize the result
print('Status : %s' % result['message'])
print('Total Evaluations: %d' % result['nfev'])
# evaluate solution
solution = result['x']
evaluation = objective(solution)
print('Solution: f(%s) = %.5f' % (solution, evaluation))
