# %% [markdown]
# # 07 — Hillclimbing Ackley / 07 Hillclimbing Ackley
#
# **Chapter 16 — File 2 of 4 / 第16章 — 第2个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **hill climbing search of the ackley objective function**.
#
# 本脚本演示 **hill climbing search of the ackley objective function**。

# %% [markdown]
# ---
# ## Step 1 — hill climbing search of the ackley objective function

# %%
from numpy import asarray
from numpy import exp
from numpy import sqrt
from numpy import cos
from numpy import e
from numpy import pi
from numpy.random import randn
from numpy.random import rand
from numpy.random import seed

# %% [markdown]
# ---
# ## Step 2 — objective function

# %%
def objective(v):
	x, y = v
	return -20.0 * exp(-0.2 * sqrt(0.5 * (x**2 + y**2))) - exp(0.5 * (cos(2 * pi * x) + cos(2 * pi * y))) + e + 20

# %% [markdown]
# ---
# ## Step 3 — check if a point is within the bounds of the search

# %%
def in_bounds(point, bounds):

# %% [markdown]
# ---
# ## Step 4 — enumerate all dimensions of the point

# %%
for d in range(len(bounds)):

# %% [markdown]
# ---
# ## Step 5 — check if out of bounds for this dimension

# %%
if point[d] < bounds[d, 0] or point[d] > bounds[d, 1]:
			return False
	return True

# %% [markdown]
# ---
# ## Step 6 — hill climbing local search algorithm

# %%
def hillclimbing(objective, bounds, n_iterations, step_size):

# %% [markdown]
# ---
# ## Step 7 — generate an initial point

# %%
solution = None
	while solution is None or not in_bounds(solution, bounds):
		solution = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])

# %% [markdown]
# ---
# ## Step 8 — evaluate the initial point

# %%
solution_eval = objective(solution)

# %% [markdown]
# ---
# ## Step 9 — run the hill climb

# %%
for i in range(n_iterations):

# %% [markdown]
# ---
# ## Step 10 — take a step

# %%
candidate = None
		while candidate is None or not in_bounds(candidate, bounds):
			candidate = solution + randn(len(bounds)) * step_size

# %% [markdown]
# ---
# ## Step 11 — evaluate candidate point

# %%
candidte_eval = objective(candidate)

# %% [markdown]
# ---
# ## Step 12 — check if we should keep the new point

# %%
if candidte_eval <= solution_eval:

# %% [markdown]
# ---
# ## Step 13 — store the new point

# %%
solution, solution_eval = candidate, candidte_eval

# %% [markdown]
# ---
# ## Step 14 — report progress

# %%
print('>%d f(%s) = %.5f' % (i, solution, solution_eval))
	return [solution, solution_eval]

# %% [markdown]
# ---
# ## Step 15 — seed the pseudorandom number generator

# %%
seed(1)

# %% [markdown]
# ---
# ## Step 16 — define range for input

# %%
bounds = asarray([[-5.0, 5.0], [-5.0, 5.0]])

# %% [markdown]
# ---
# ## Step 17 — define the total iterations

# %%
n_iterations = 1000

# %% [markdown]
# ---
# ## Step 18 — define the maximum step size

# %%
step_size = 0.05

# %% [markdown]
# ---
# ## Step 19 — perform the hill climbing search

# %%
best, score = hillclimbing(objective, bounds, n_iterations, step_size)
print('Done!')
print('f(%s) = %f' % (best, score))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: hill climbing search of the ackley objective function 是机器学习中的常用技术。
#   *hill climbing search of the ackley objective function is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Hillclimbing Ackley / 07 Hillclimbing Ackley
# Complete Code / 完整代码
# ===============================

# hill climbing search of the ackley objective function
from numpy import asarray
from numpy import exp
from numpy import sqrt
from numpy import cos
from numpy import e
from numpy import pi
from numpy.random import randn
from numpy.random import rand
from numpy.random import seed

# objective function
def objective(v):
	x, y = v
	return -20.0 * exp(-0.2 * sqrt(0.5 * (x**2 + y**2))) - exp(0.5 * (cos(2 * pi * x) + cos(2 * pi * y))) + e + 20

# check if a point is within the bounds of the search
def in_bounds(point, bounds):
	# enumerate all dimensions of the point
	for d in range(len(bounds)):
		# check if out of bounds for this dimension
		if point[d] < bounds[d, 0] or point[d] > bounds[d, 1]:
			return False
	return True

# hill climbing local search algorithm
def hillclimbing(objective, bounds, n_iterations, step_size):
	# generate an initial point
	solution = None
	while solution is None or not in_bounds(solution, bounds):
		solution = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])
	# evaluate the initial point
	solution_eval = objective(solution)
	# run the hill climb
	for i in range(n_iterations):
		# take a step
		candidate = None
		while candidate is None or not in_bounds(candidate, bounds):
			candidate = solution + randn(len(bounds)) * step_size
		# evaluate candidate point
		candidte_eval = objective(candidate)
		# check if we should keep the new point
		if candidte_eval <= solution_eval:
			# store the new point
			solution, solution_eval = candidate, candidte_eval
			# report progress
			print('>%d f(%s) = %.5f' % (i, solution, solution_eval))
	return [solution, solution_eval]

# seed the pseudorandom number generator
seed(1)
# define range for input
bounds = asarray([[-5.0, 5.0], [-5.0, 5.0]])
# define the total iterations
n_iterations = 1000
# define the maximum step size
step_size = 0.05
# perform the hill climbing search
best, score = hillclimbing(objective, bounds, n_iterations, step_size)
print('Done!')
print('f(%s) = %f' % (best, score))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 4
