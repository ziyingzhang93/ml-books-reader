# %% [markdown]
# # 02 — Kfold Perceptron / 02 Kfold Perceptron
#
# **Chapter 30 — File 2 of 6 / 第30章 — 第2个文件（共6个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **perceptron default hyperparameters for binary classification**.
#
# 本脚本演示 **perceptron default hyperparameters for binary classification**。

# %% [markdown]
# ---
# ## Step 1 — perceptron default hyperparameters for binary classification

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import Perceptron

# %% [markdown]
# ---
# ## Step 2 — define dataset

# %%
X, y = make_classification(n_samples=1000, n_features=5, n_informative=2, n_redundant=1, random_state=1)

# %% [markdown]
# ---
# ## Step 3 — define model

# %%
model = Perceptron()

# %% [markdown]
# ---
# ## Step 4 — define evaluation procedure

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ---
# ## Step 5 — evaluate model

# %%
scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)

# %% [markdown]
# ---
# ## Step 6 — report result

# %%
print('Mean Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: perceptron default hyperparameters for binary classification 是机器学习中的常用技术。
#   *perceptron default hyperparameters for binary classification is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Kfold Perceptron / 02 Kfold Perceptron
# Complete Code / 完整代码
# ===============================

# perceptron default hyperparameters for binary classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import Perceptron
# define dataset
X, y = make_classification(n_samples=1000, n_features=5, n_informative=2, n_redundant=1, random_state=1)
# define model
model = Perceptron()
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# report result
print('Mean Accuracy: %.3f (%.3f)' % (mean(scores), std(scores)))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 6
