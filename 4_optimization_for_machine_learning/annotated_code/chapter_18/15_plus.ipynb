# %% [markdown]
# # 15 — Plus / 15 Plus
#
# **Chapter 18 — File 3 of 3 / 第18章 — 第3个文件（共3个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **evolution strategy (mu + lambda) of the ackley objective function**.
#
# 本脚本演示 **evolution strategy (mu + lambda) of the ackley objective function**。

# %% [markdown]
# ---
# ## Step 1 — evolution strategy (mu + lambda) of the ackley objective function

# %%
from numpy import asarray
from numpy import exp
from numpy import sqrt
from numpy import cos
from numpy import e
from numpy import pi
from numpy import argsort
from numpy.random import randn
from numpy.random import rand
from numpy.random import seed

# %% [markdown]
# ---
# ## Step 2 — objective function

# %%
def objective(v):
	x, y = v
	return -20.0 * exp(-0.2 * sqrt(0.5 * (x**2 + y**2))) - exp(0.5 * (cos(2 * pi * x) + cos(2 * pi * y))) + e + 20

# %% [markdown]
# ---
# ## Step 3 — check if a point is within the bounds of the search

# %%
def in_bounds(point, bounds):

# %% [markdown]
# ---
# ## Step 4 — enumerate all dimensions of the point

# %%
for d in range(len(bounds)):

# %% [markdown]
# ---
# ## Step 5 — check if out of bounds for this dimension

# %%
if point[d] < bounds[d, 0] or point[d] > bounds[d, 1]:
			return False
	return True

# %% [markdown]
# ---
# ## Step 6 — evolution strategy (mu + lambda) algorithm

# %%
def es_plus(objective, bounds, n_iter, step_size, mu, lam):
	best, best_eval = None, 1e+10

# %% [markdown]
# ---
# ## Step 7 — calculate the number of children per parent

# %%
n_children = int(lam / mu)

# %% [markdown]
# ---
# ## Step 8 — initial population

# %%
population = list()
	for _ in range(lam):
		candidate = None
		while candidate is None or not in_bounds(candidate, bounds):
			candidate = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])
		population.append(candidate)

# %% [markdown]
# ---
# ## Step 9 — perform the search

# %%
for epoch in range(n_iter):

# %% [markdown]
# ---
# ## Step 10 — evaluate fitness for the population

# %%
scores = [objective(c) for c in population]

# %% [markdown]
# ---
# ## Step 11 — rank scores in ascending order

# %%
ranks = argsort(argsort(scores))

# %% [markdown]
# ---
# ## Step 12 — select the indexes for the top mu ranked solutions

# %%
selected = [i for i,_ in enumerate(ranks) if ranks[i] < mu]

# %% [markdown]
# ---
# ## Step 13 — create children from parents

# %%
children = list()
		for i in selected:

# %% [markdown]
# ---
# ## Step 14 — check if this parent is the best solution ever seen

# %%
if scores[i] < best_eval:
				best, best_eval = population[i], scores[i]
				print('%d, Best: f(%s) = %.5f' % (epoch, best, best_eval))

# %% [markdown]
# ---
# ## Step 15 — keep the parent

# %%
children.append(population[i])

# %% [markdown]
# ---
# ## Step 16 — create children for parent

# %%
for _ in range(n_children):
				child = None
				while child is None or not in_bounds(child, bounds):
					child = population[i] + randn(len(bounds)) * step_size
				children.append(child)

# %% [markdown]
# ---
# ## Step 17 — replace population with children

# %%
population = children
	return [best, best_eval]

# %% [markdown]
# ---
# ## Step 18 — seed the pseudorandom number generator

# %%
seed(1)

# %% [markdown]
# ---
# ## Step 19 — define range for input

# %%
bounds = asarray([[-5.0, 5.0], [-5.0, 5.0]])

# %% [markdown]
# ---
# ## Step 20 — define the total iterations

# %%
n_iter = 5000

# %% [markdown]
# ---
# ## Step 21 — define the maximum step size

# %%
step_size = 0.15

# %% [markdown]
# ---
# ## Step 22 — number of parents selected

# %%
mu = 20

# %% [markdown]
# ---
# ## Step 23 — the number of children generated by parents

# %%
lam = 100

# %% [markdown]
# ---
# ## Step 24 — perform the evolution strategy (mu + lambda) search

# %%
best, score = es_plus(objective, bounds, n_iter, step_size, mu, lam)
print('Done!')
print('f(%s) = %f' % (best, score))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: evolution strategy (mu + lambda) of the ackley objective function 是机器学习中的常用技术。
#   *evolution strategy (mu + lambda) of the ackley objective function is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Plus / 15 Plus
# Complete Code / 完整代码
# ===============================

# evolution strategy (mu + lambda) of the ackley objective function
from numpy import asarray
from numpy import exp
from numpy import sqrt
from numpy import cos
from numpy import e
from numpy import pi
from numpy import argsort
from numpy.random import randn
from numpy.random import rand
from numpy.random import seed

# objective function
def objective(v):
	x, y = v
	return -20.0 * exp(-0.2 * sqrt(0.5 * (x**2 + y**2))) - exp(0.5 * (cos(2 * pi * x) + cos(2 * pi * y))) + e + 20

# check if a point is within the bounds of the search
def in_bounds(point, bounds):
	# enumerate all dimensions of the point
	for d in range(len(bounds)):
		# check if out of bounds for this dimension
		if point[d] < bounds[d, 0] or point[d] > bounds[d, 1]:
			return False
	return True

# evolution strategy (mu + lambda) algorithm
def es_plus(objective, bounds, n_iter, step_size, mu, lam):
	best, best_eval = None, 1e+10
	# calculate the number of children per parent
	n_children = int(lam / mu)
	# initial population
	population = list()
	for _ in range(lam):
		candidate = None
		while candidate is None or not in_bounds(candidate, bounds):
			candidate = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])
		population.append(candidate)
	# perform the search
	for epoch in range(n_iter):
		# evaluate fitness for the population
		scores = [objective(c) for c in population]
		# rank scores in ascending order
		ranks = argsort(argsort(scores))
		# select the indexes for the top mu ranked solutions
		selected = [i for i,_ in enumerate(ranks) if ranks[i] < mu]
		# create children from parents
		children = list()
		for i in selected:
			# check if this parent is the best solution ever seen
			if scores[i] < best_eval:
				best, best_eval = population[i], scores[i]
				print('%d, Best: f(%s) = %.5f' % (epoch, best, best_eval))
			# keep the parent
			children.append(population[i])
			# create children for parent
			for _ in range(n_children):
				child = None
				while child is None or not in_bounds(child, bounds):
					child = population[i] + randn(len(bounds)) * step_size
				children.append(child)
		# replace population with children
		population = children
	return [best, best_eval]

# seed the pseudorandom number generator
seed(1)
# define range for input
bounds = asarray([[-5.0, 5.0], [-5.0, 5.0]])
# define the total iterations
n_iter = 5000
# define the maximum step size
step_size = 0.15
# number of parents selected
mu = 20
# the number of children generated by parents
lam = 100
# perform the evolution strategy (mu + lambda) search
best, score = es_plus(objective, bounds, n_iter, step_size, mu, lam)
print('Done!')
print('f(%s) = %f' % (best, score))
