# %% [markdown]
# # 19 — Plot Momentum / 19 Plot Momentum
#
# **Chapter 22 — File 5 of 5 / 第22章 — 第5个文件（共5个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of plotting gradient descent with momentum for a one-dimensional function**.
#
# 本脚本演示 **example of plotting gradient descent with momentum for a one-dimensional function**。

# %% [markdown]
# ---
# ## Step 1 — example of plotting gradient descent with momentum for a one-dimensional function

# %%
from numpy import asarray
from numpy import arange
from numpy.random import rand
from numpy.random import seed
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — objective function

# %%
def objective(x):
	return x**2.0

# %% [markdown]
# ---
# ## Step 3 — derivative of objective function

# %%
def derivative(x):
	return x * 2.0

# %% [markdown]
# ---
# ## Step 4 — gradient descent algorithm

# %%
def gradient_descent(objective, derivative, bounds, n_iter, step_size, momentum):

# %% [markdown]
# ---
# ## Step 5 — track all solutions

# %%
solutions, scores = list(), list()

# %% [markdown]
# ---
# ## Step 6 — generate an initial point

# %%
solution = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])

# %% [markdown]
# ---
# ## Step 7 — keep track of the change

# %%
change = 0.0

# %% [markdown]
# ---
# ## Step 8 — run the gradient descent

# %%
for i in range(n_iter):

# %% [markdown]
# ---
# ## Step 9 — calculate gradient

# %%
gradient = derivative(solution)

# %% [markdown]
# ---
# ## Step 10 — calculate update

# %%
new_change = step_size * gradient + momentum * change

# %% [markdown]
# ---
# ## Step 11 — take a step

# %%
solution = solution - new_change

# %% [markdown]
# ---
# ## Step 12 — save the change

# %%
change = new_change

# %% [markdown]
# ---
# ## Step 13 — evaluate candidate point

# %%
solution_eval = objective(solution)

# %% [markdown]
# ---
# ## Step 14 — store solution

# %%
solutions.append(solution)
		scores.append(solution_eval)

# %% [markdown]
# ---
# ## Step 15 — report progress

# %%
print('>%d f(%s) = %.5f' % (i, solution, solution_eval))
	return [solutions, scores]

# %% [markdown]
# ---
# ## Step 16 — seed the pseudo random number generator

# %%
seed(4)

# %% [markdown]
# ---
# ## Step 17 — define range for input

# %%
bounds = asarray([[-1.0, 1.0]])

# %% [markdown]
# ---
# ## Step 18 — define the total iterations

# %%
n_iter = 30

# %% [markdown]
# ---
# ## Step 19 — define the step size

# %%
step_size = 0.1

# %% [markdown]
# ---
# ## Step 20 — define momentum

# %%
momentum = 0.3

# %% [markdown]
# ---
# ## Step 21 — perform the gradient descent search with momentum

# %%
solutions, scores = gradient_descent(objective, derivative, bounds, n_iter, step_size, momentum)

# %% [markdown]
# ---
# ## Step 22 — sample input range uniformly at 0.1 increments

# %%
inputs = arange(bounds[0,0], bounds[0,1]+0.1, 0.1)

# %% [markdown]
# ---
# ## Step 23 — compute targets

# %%
results = objective(inputs)

# %% [markdown]
# ---
# ## Step 24 — create a line plot of input vs result

# %%
pyplot.plot(inputs, results)

# %% [markdown]
# ---
# ## Step 25 — plot the solutions found

# %%
pyplot.plot(solutions, scores, '.-', color='red')

# %% [markdown]
# ---
# ## Step 26 — show the plot

# %%
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of plotting gradient descent with momentum for a one-dimensional function 是机器学习中的常用技术。
#   *example of plotting gradient descent with momentum for a one-dimensional function is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Plot Momentum / 19 Plot Momentum
# Complete Code / 完整代码
# ===============================

# example of plotting gradient descent with momentum for a one-dimensional function
from numpy import asarray
from numpy import arange
from numpy.random import rand
from numpy.random import seed
from matplotlib import pyplot

# objective function
def objective(x):
	return x**2.0

# derivative of objective function
def derivative(x):
	return x * 2.0

# gradient descent algorithm
def gradient_descent(objective, derivative, bounds, n_iter, step_size, momentum):
	# track all solutions
	solutions, scores = list(), list()
	# generate an initial point
	solution = bounds[:, 0] + rand(len(bounds)) * (bounds[:, 1] - bounds[:, 0])
	# keep track of the change
	change = 0.0
	# run the gradient descent
	for i in range(n_iter):
		# calculate gradient
		gradient = derivative(solution)
		# calculate update
		new_change = step_size * gradient + momentum * change
		# take a step
		solution = solution - new_change
		# save the change
		change = new_change
		# evaluate candidate point
		solution_eval = objective(solution)
		# store solution
		solutions.append(solution)
		scores.append(solution_eval)
		# report progress
		print('>%d f(%s) = %.5f' % (i, solution, solution_eval))
	return [solutions, scores]

# seed the pseudo random number generator
seed(4)
# define range for input
bounds = asarray([[-1.0, 1.0]])
# define the total iterations
n_iter = 30
# define the step size
step_size = 0.1
# define momentum
momentum = 0.3
# perform the gradient descent search with momentum
solutions, scores = gradient_descent(objective, derivative, bounds, n_iter, step_size, momentum)
# sample input range uniformly at 0.1 increments
inputs = arange(bounds[0,0], bounds[0,1]+0.1, 0.1)
# compute targets
results = objective(inputs)
# create a line plot of input vs result
pyplot.plot(inputs, results)
# plot the solutions found
pyplot.plot(solutions, scores, '.-', color='red')
# show the plot
pyplot.show()
