# %% [markdown]
# # 01 — Python Crash Course / Python Crash Course
#
# **Chapter 03 — File 4 of 4 / 第03章 — 第4个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Python Crash Course**.
#
# 本脚本演示 **Python Crash Course**。

# %% [markdown]
# ---
# ## Step 1 — Python Crash Course
# Assignment
# ==========
# Strings

# %%
data = 'hello world'
print(data[0])
print(len(data))
print(data)

# %% [markdown]
# ---
# ## Step 2 — Numbers

# %%
value = 123.1
print(value)
value = 10
print(value)

# %% [markdown]
# ---
# ## Step 3 — Boolean

# %%
a = True
b = False
print(a, b)

# %% [markdown]
# ---
# ## Step 4 — Multiple Assignment

# %%
a, b, c = 1, 2, 3
print(a, b, c)

# %% [markdown]
# ---
# ## Step 5 — No value

# %%
a = None
print(a)

# %% [markdown]
# ---
# ## Step 6 — Flow Control
# ============
# If-Then-Else

# %%
value = 99
if value >= 99:
	print('That is fast')
elif value > 200:
	print('That is too fast')
else:
	print('That that is safe')

# %% [markdown]
# ---
# ## Step 7 — For-Loop

# %%
for i in range(10):
	print(i)

# %% [markdown]
# ---
# ## Step 8 — While-Loop

# %%
i = 0
while i < 10:
	print(i)
	i += 1

# %% [markdown]
# ---
# ## Step 9 — Data Structures
# ===============
# Tuple (cannot change)

# %%
a = (1, 2, 3)
print(a)

# %% [markdown]
# ---
# ## Step 10 — Lists

# %%
mylist = [1, 2, 3]
print("Zeroth Value: %d" % mylist[0])
mylist.append(4)
print("List Length: %d" % len(mylist))
for value in mylist:
	print(value)

# %% [markdown]
# ---
# ## Step 11 — Dictionaries

# %%
mydict = {'a': 1, 'b': 2, 'c': 3}
print("A value: %d" % mydict['a'])
mydict['a'] = 11
print("A value: %d" % mydict['a'])
print("Keys: %s" % mydict.keys())
print("Values: %s" % mydict.values())
for key in mydict.keys():
	print(mydict[key])

# %% [markdown]
# ---
# ## Step 12 — Functions
# ===========
# Sum function

# %%
def mysum(x, y):
	return x + y

# %% [markdown]
# ---
# ## Step 13 — Test sum function

# %%
mysum(1, 3)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Python Crash Course 是机器学习中的常用技术。
#   *Python Crash Course is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Python Crash Course / Python Crash Course
# Complete Code / 完整代码
# ===============================

# Python Crash Course


# Assignment
# ==========

# Strings
data = 'hello world'
print(data[0])
print(len(data))
print(data)

# Numbers
value = 123.1
print(value)
value = 10
print(value)

# Boolean
a = True
b = False
print(a, b)

# Multiple Assignment
a, b, c = 1, 2, 3
print(a, b, c)

# No value
a = None
print(a)



# Flow Control
# ============

# If-Then-Else

value = 99
if value >= 99:
	print('That is fast')
elif value > 200:
	print('That is too fast')
else:
	print('That that is safe')

# For-Loop
for i in range(10):
	print(i)

# While-Loop
i = 0
while i < 10:
	print(i)
	i += 1


# Data Structures
# ===============

# Tuple (cannot change)
a = (1, 2, 3)
print(a)


# Lists
mylist = [1, 2, 3]
print("Zeroth Value: %d" % mylist[0])
mylist.append(4)
print("List Length: %d" % len(mylist))
for value in mylist:
	print(value)



# Dictionaries

mydict = {'a': 1, 'b': 2, 'c': 3}
print("A value: %d" % mydict['a'])
mydict['a'] = 11
print("A value: %d" % mydict['a'])
print("Keys: %s" % mydict.keys())
print("Values: %s" % mydict.values())
for key in mydict.keys():
	print(mydict[key])


# Functions
# ===========

# Sum function
def mysum(x, y):
	return x + y

# Test sum function
mysum(1, 3)
