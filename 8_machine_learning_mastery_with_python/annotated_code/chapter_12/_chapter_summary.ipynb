# %% [markdown]
# # Chapter 12 Summary / 第12章总结
#
# ## Theme / 主题: Chapter 12 / Chapter 12
#
# This chapter contains **7 code files** demonstrating chapter 12.
#
# 本章包含 **7 个代码文件**，演示Chapter 12。

# %% [markdown]
# ---
# ## Evolution / 演化路线
#
#   1. `classification_and_regression_trees_regression.ipynb` — Classification And Regression Trees Regression
#   2. `elastic_net.ipynb` — Elastic Net
#   3. `k_nearest_neighbors_regression.ipynb` — K Nearest Neighbors Regression
#   4. `lasso_regression.ipynb` — Lasso Regression
#   5. `linear_regression.ipynb` — Linear Regression
#   6. `ridge_regression.ipynb` — Ridge Regression
#   7. `support_vector_machines_regression.ipynb` — Support Vector Machines Regression

# %% [markdown]
# ---
# ## ML Relevance / ML 关联
#
# The techniques in this chapter (Chapter 12) are fundamental building blocks in machine learning pipelines.
#
# 本章技术（Chapter 12）是机器学习流水线中的基础构建块。
