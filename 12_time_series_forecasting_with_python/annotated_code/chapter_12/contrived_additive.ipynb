# %% [markdown]
# # 01 — Contrived Additive / Contrived Additive
#
# **Chapter 12 — File 2 of 3 / 第12章 — 第2个文件（共3个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **additive decompose a contrived additive time series**.
#
# 本脚本演示 **additive decompose a contrived additive time series**。

# %% [markdown]
# ---
# ## Step 1 — additive decompose a contrived additive time series

# %%
from random import randrange
from matplotlib import pyplot
from statsmodels.tsa.seasonal import seasonal_decompose
series = [i+randrange(10) for i in range(1,100)]
result = seasonal_decompose(series, model='additive', period=1)
result.plot()
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: additive decompose a contrived additive time series 是机器学习中的常用技术。
#   *additive decompose a contrived additive time series is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Contrived Additive / Contrived Additive
# Complete Code / 完整代码
# ===============================

# additive decompose a contrived additive time series
from random import randrange
from matplotlib import pyplot
from statsmodels.tsa.seasonal import seasonal_decompose
series = [i+randrange(10) for i in range(1,100)]
result = seasonal_decompose(series, model='additive', period=1)
result.plot()
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 3
