# %% [markdown]
# # 01 — Airline Multiplicative / Airline Multiplicative
#
# **Chapter 12 — File 1 of 3 / 第12章 — 第1个文件（共3个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **multiplicative decompose time series**.
#
# 本脚本演示 **multiplicative decompose time series**。

# %% [markdown]
# ---
# ## Step 1 — multiplicative decompose time series

# %%
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.seasonal import seasonal_decompose
series = read_csv('airline-passengers.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
result = seasonal_decompose(series, model='multiplicative')
result.plot()
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: multiplicative decompose time series 是机器学习中的常用技术。
#   *multiplicative decompose time series is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Airline Multiplicative / Airline Multiplicative
# Complete Code / 完整代码
# ===============================

# multiplicative decompose time series
from pandas import read_csv
from matplotlib import pyplot
from statsmodels.tsa.seasonal import seasonal_decompose
series = read_csv('airline-passengers.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
result = seasonal_decompose(series, model='multiplicative')
result.plot()
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 3
