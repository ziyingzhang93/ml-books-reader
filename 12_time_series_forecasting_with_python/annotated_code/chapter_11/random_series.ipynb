# %% [markdown]
# # 01 — Random Series / Random Series
#
# **Chapter 11 — File 1 of 8 / 第11章 — 第1个文件（共8个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **create and plot a random series**.
#
# 本脚本演示 **create and plot a random series**。

# %% [markdown]
# ---
# ## Step 1 — create and plot a random series

# %%
from random import seed
from random import randrange
from matplotlib import pyplot
seed(1)
series = [randrange(10) for i in range(1000)]
pyplot.plot(series)
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: create and plot a random series 是机器学习中的常用技术。
#   *create and plot a random series is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Random Series / Random Series
# Complete Code / 完整代码
# ===============================

# create and plot a random series
from random import seed
from random import randrange
from matplotlib import pyplot
seed(1)
series = [randrange(10) for i in range(1000)]
pyplot.plot(series)
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 8
