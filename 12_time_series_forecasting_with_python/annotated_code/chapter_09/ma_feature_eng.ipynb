# %% [markdown]
# # 01 — Ma Feature Eng / 特征工程
#
# **Chapter 09 — File 2 of 3 / 第09章 — 第2个文件（共3个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **moving average smoothing as feature engineering**.
#
# 本脚本演示 **moving average smoothing as feature engineering**。

# %% [markdown]
# ---
# ## Step 1 — moving average smoothing as feature engineering

# %%
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
series = read_csv('daily-total-female-births.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
df = DataFrame(series.values)
width = 3
lag1 = df.shift(1)
lag3 = df.shift(width - 1)
window = lag3.rolling(window=width)
means = window.mean()
dataframe = concat([means, lag1, df], axis=1)
dataframe.columns = ['mean', 't', 't+1']
print(dataframe.head(10))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: moving average smoothing as feature engineering 是机器学习中的常用技术。
#   *moving average smoothing as feature engineering is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Ma Feature Eng / 特征工程
# Complete Code / 完整代码
# ===============================

# moving average smoothing as feature engineering
from pandas import read_csv
from pandas import DataFrame
from pandas import concat
series = read_csv('daily-total-female-births.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
df = DataFrame(series.values)
width = 3
lag1 = df.shift(1)
lag3 = df.shift(width - 1)
window = lag3.rolling(window=width)
means = window.mean()
dataframe = concat([means, lag1, df], axis=1)
dataframe.columns = ['mean', 't', 't+1']
print(dataframe.head(10))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 3
