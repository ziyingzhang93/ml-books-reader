# %% [markdown]
# # Chapter 05 Summary / 第05章总结
#
# ## Theme / 主题: Chapter 05 / Chapter 05
#
# This chapter contains **6 code files** demonstrating chapter 05.
#
# 本章包含 **6 个代码文件**，演示Chapter 05。

# %% [markdown]
# ---
# ## Evolution / 演化路线
#
#   1. `features_date_time.ipynb` — Features Date Time
#   2. `features_expanding.ipynb` — Features Expanding
#   3. `features_lag1.ipynb` — Features Lag1
#   4. `features_lag3.ipynb` — Features Lag3
#   5. `features_rolling_mean.ipynb` — Features Rolling Mean
#   6. `features_rolling_stats.ipynb` — Features Rolling Stats

# %% [markdown]
# ---
# ## ML Relevance / ML 关联
#
# The techniques in this chapter (Chapter 05) are fundamental building blocks in machine learning pipelines.
#
# 本章技术（Chapter 05）是机器学习流水线中的基础构建块。
