# %% [markdown]
# # 01 — Series Quadratic / Series Quadratic
#
# **Chapter 08 — File 8 of 9 / 第08章 — 第8个文件（共9个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **contrive a quadratic time series**.
#
# 本脚本演示 **contrive a quadratic time series**。

# %% [markdown]
# ---
# ## Step 1 — contrive a quadratic time series

# %%
from matplotlib import pyplot
series = [i**2 for i in range(1,100)]
pyplot.figure(1)

# %% [markdown]
# ---
# ## Step 2 — line plot

# %%
pyplot.subplot(211)
pyplot.plot(series)

# %% [markdown]
# ---
# ## Step 3 — histogram

# %%
pyplot.subplot(212)
pyplot.hist(series)
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: contrive a quadratic time series 是机器学习中的常用技术。
#   *contrive a quadratic time series is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Series Quadratic / Series Quadratic
# Complete Code / 完整代码
# ===============================

# contrive a quadratic time series
from matplotlib import pyplot
series = [i**2 for i in range(1,100)]
pyplot.figure(1)
# line plot
pyplot.subplot(211)
pyplot.plot(series)
# histogram
pyplot.subplot(212)
pyplot.hist(series)
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 9 of 9
