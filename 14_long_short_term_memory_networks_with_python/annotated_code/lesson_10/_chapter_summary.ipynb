# %% [markdown]
# # Chapter 10 Summary / 第10章总结
#
# ## Theme / 主题: Lesson 10 / Lesson 10
#
# This chapter contains **2 code files** demonstrating lesson 10.
#
# 本章包含 **2 个代码文件**，演示Lesson 10。

# %% [markdown]
# ---
# ## Evolution / 演化路线
#
#   1. `bidirectional_lstm.ipynb` — Bidirectional Lstm
#   2. `problem_sequence.ipynb` — Problem Sequence

# %% [markdown]
# ---
# ## ML Relevance / ML 关联
#
# The techniques in this chapter (Lesson 10) are fundamental building blocks in machine learning pipelines.
#
# 本章技术（Lesson 10）是机器学习流水线中的基础构建块。
