# %% [markdown]
# # 01 — Lstm Single Layer / LSTM 网络
#
# **Chapter 07 — File 4 of 6 / 第07章 — 第4个文件（共6个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Example of one output for whole sequence**.
#
# 本脚本演示 **Example of one output for whole sequence**。

# %% [markdown]
# ---
# ## Step 1 — Example of one output for whole sequence

# %%
from keras.models import Sequential
from keras.layers import LSTM
from numpy import array

# %% [markdown]
# ---
# ## Step 2 — define model where LSTM is also output layer

# %%
model = Sequential()
model.add(LSTM(1, input_shape=(3,1)))
model.compile(optimizer='adam', loss='mse')

# %% [markdown]
# ---
# ## Step 3 — input time steps

# %%
data = array([0.1, 0.2, 0.3]).reshape((1,3,1))

# %% [markdown]
# ---
# ## Step 4 — make and show prediction

# %%
print(model.predict(data))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Example of one output for whole sequence 是机器学习中的常用技术。
#   *Example of one output for whole sequence is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Lstm Single Layer / LSTM 网络
# Complete Code / 完整代码
# ===============================

# Example of one output for whole sequence
from keras.models import Sequential
from keras.layers import LSTM
from numpy import array
# define model where LSTM is also output layer
model = Sequential()
model.add(LSTM(1, input_shape=(3,1)))
model.compile(optimizer='adam', loss='mse')
# input time steps
data = array([0.1, 0.2, 0.3]).reshape((1,3,1))
# make and show prediction
print(model.predict(data))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 6
