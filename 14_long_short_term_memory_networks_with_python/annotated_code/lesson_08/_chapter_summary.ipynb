# %% [markdown]
# # Chapter 08 Summary / 第08章总结
#
# ## Theme / 主题: Lesson 08 / Lesson 08
#
# This chapter contains **2 code files** demonstrating lesson 08.
#
# 本章包含 **2 个代码文件**，演示Lesson 08。

# %% [markdown]
# ---
# ## Evolution / 演化路线
#
#   1. `cnn_lstm.ipynb` — Cnn Lstm
#   2. `problem.ipynb` — Problem

# %% [markdown]
# ---
# ## ML Relevance / ML 关联
#
# The techniques in this chapter (Lesson 08) are fundamental building blocks in machine learning pipelines.
#
# 本章技术（Lesson 08）是机器学习流水线中的基础构建块。
