# %% [markdown]
# # 01 — Normalize / Normalize
#
# **Chapter 03 — File 1 of 10 / 第03章 — 第1个文件（共10个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **define contrived series**.
#
# 本脚本演示 **define contrived series**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
from pandas import Series
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ---
# ## Step 2 — define contrived series

# %%
data = [10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0]
series = Series(data)
print(series)

# %% [markdown]
# ---
# ## Step 3 — prepare data for normalization

# %%
values = series.values
values = values.reshape((len(values), 1))

# %% [markdown]
# ---
# ## Step 4 — train the normalization

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(values)
print('Min: %f, Max: %f' % (scaler.data_min_, scaler.data_max_))

# %% [markdown]
# ---
# ## Step 5 — normalize the dataset and print

# %%
normalized = scaler.transform(values)
print(normalized)

# %% [markdown]
# ---
# ## Step 6 — inverse transform and print

# %%
inversed = scaler.inverse_transform(normalized)
print(inversed)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: define contrived series 是机器学习中的常用技术。
#   *define contrived series is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Normalize / Normalize
# Complete Code / 完整代码
# ===============================

from pandas import Series
from sklearn.preprocessing import MinMaxScaler
# define contrived series
data = [10.0, 20.0, 30.0, 40.0, 50.0, 60.0, 70.0, 80.0, 90.0, 100.0]
series = Series(data)
print(series)
# prepare data for normalization
values = series.values
values = values.reshape((len(values), 1))
# train the normalization
scaler = MinMaxScaler(feature_range=(0, 1))
scaler = scaler.fit(values)
print('Min: %f, Max: %f' % (scaler.data_min_, scaler.data_max_))
# normalize the dataset and print
normalized = scaler.transform(values)
print(normalized)
# inverse transform and print
inversed = scaler.inverse_transform(normalized)
print(inversed)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 10
