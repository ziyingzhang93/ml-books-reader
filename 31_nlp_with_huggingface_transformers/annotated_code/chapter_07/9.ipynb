# %% [markdown]
# # 9 —  / 9
#
# **Chapter 07 — File 11 of 11 / 第07章 — 第11个文件（共11个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Example of sampling effects**.
#
# 本脚本演示 **Example of sampling effects**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
...
generator = TextGenerator()

# %% [markdown]
# ---
# ## Step 2 — Example of sampling effects

# %%
prompt = "The scientist discovered"

# %% [markdown]
# ---
# ## Step 3 — Using top-k sampling

# %%
top_k_text = generator.generate_text(
    prompt,
    top_k=10,
    top_p=1.0,
    max_length=50
)
print(f"Top-k sampling (k=10):\n{top_k_text}\n")

# %% [markdown]
# ---
# ## Step 4 — Using nucleus (top-p) sampling

# %%
nucleus_text = generator.generate_text(
    prompt,
    top_k=0,
    top_p=0.9,
    max_length=50
)
print(f"Nucleus sampling (p=0.9):\n{nucleus_text}\n")

# %% [markdown]
# ---
# ## Step 5 — Combining both

# %%
combined_text = generator.generate_text(
    prompt,
    top_k=50,
    top_p=0.95,
    max_length=50
)
print(f"Combined sampling:\n{combined_text}\n")

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Example of sampling effects 是机器学习中的常用技术。
#   *Example of sampling effects is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
#  / 9
# Complete Code / 完整代码
# ===============================

...
generator = TextGenerator()

# Example of sampling effects
prompt = "The scientist discovered"

# Using top-k sampling
top_k_text = generator.generate_text(
    prompt,
    top_k=10,
    top_p=1.0,
    max_length=50
)
print(f"Top-k sampling (k=10):\n{top_k_text}\n")

# Using nucleus (top-p) sampling
nucleus_text = generator.generate_text(
    prompt,
    top_k=0,
    top_p=0.9,
    max_length=50
)
print(f"Nucleus sampling (p=0.9):\n{nucleus_text}\n")

# Combining both
combined_text = generator.generate_text(
    prompt,
    top_k=50,
    top_p=0.95,
    max_length=50
)
print(f"Combined sampling:\n{combined_text}\n")
