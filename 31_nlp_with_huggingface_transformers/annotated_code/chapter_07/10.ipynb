# %% [markdown]
# # 10 —  / 10
#
# **Chapter 07 — File 7 of 11 / 第07章 — 第7个文件（共11个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Example of temperature effects**.
#
# 本脚本演示 **Example of temperature effects**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
...
generator = TextGenerator()

# %% [markdown]
# ---
# ## Step 2 — Example of temperature effects

# %%
prompt = "The robot carefully"

# %% [markdown]
# ---
# ## Step 3 — Low temperature (more focused)

# %%
focused = generator.generate_text(
    prompt,
    temperature=0.3,
    max_length=50
)
print(f"Low temperature (0.3):\n{focused}\n")

# %% [markdown]
# ---
# ## Step 4 — Medium temperature (balanced)

# %%
balanced = generator.generate_text(
    prompt,
    temperature=0.7,
    max_length=50
)
print(f"Medium temperature (0.7):\n{balanced}\n")

# %% [markdown]
# ---
# ## Step 5 — High temperature (more creative)

# %%
creative = generator.generate_text(
    prompt,
    temperature=1.0,
    max_length=50
)
print(f"High temperature (1.0):\n{creative}\n")

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Example of temperature effects 是机器学习中的常用技术。
#   *Example of temperature effects is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
#  / 10
# Complete Code / 完整代码
# ===============================

...
generator = TextGenerator()

# Example of temperature effects
prompt = "The robot carefully"

# Low temperature (more focused)
focused = generator.generate_text(
    prompt,
    temperature=0.3,
    max_length=50
)
print(f"Low temperature (0.3):\n{focused}\n")

# Medium temperature (balanced)
balanced = generator.generate_text(
    prompt,
    temperature=0.7,
    max_length=50
)
print(f"Medium temperature (0.7):\n{balanced}\n")

# High temperature (more creative)
creative = generator.generate_text(
    prompt,
    temperature=1.0,
    max_length=50
)
print(f"High temperature (1.0):\n{creative}\n")

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 8 of 11
