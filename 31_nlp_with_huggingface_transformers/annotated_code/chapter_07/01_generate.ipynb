# %% [markdown]
# # 01 — Generate / 01 Generate
#
# **Chapter 07 — File 1 of 11 / 第07章 — 第1个文件（共11个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **create model and tokenizer**.
#
# 本脚本演示 **create model and tokenizer**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %% [markdown]
# ---
# ## Step 2 — create model and tokenizer

# %%
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# %% [markdown]
# ---
# ## Step 3 — tokenize input prompt to sequence of ids

# %%
prompt = "Artificial intelligence is"
inputs = tokenizer(prompt, return_tensors="pt")

# %% [markdown]
# ---
# ## Step 4 — generate output as a sequence of token ids

# %%
output = model.generate(
    **inputs,
    max_length=50,
    num_return_sequences=1,
    temperature=1.0,
    top_k=50,
    top_p=1.0,
    repetition_penalty=1.0,
    do_sample=True,
    pad_token_id=tokenizer.eos_token_id,
)

# %% [markdown]
# ---
# ## Step 5 — convert token ids into text strings

# %%
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

print(f"Prompt: {prompt}")
print("Generated Text:")
print(generated_text)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: create model and tokenizer 是机器学习中的常用技术。
#   *create model and tokenizer is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Generate / 01 Generate
# Complete Code / 完整代码
# ===============================

from transformers import GPT2LMHeadModel, GPT2Tokenizer

# create model and tokenizer
tokenizer = GPT2Tokenizer.from_pretrained("gpt2")
model = GPT2LMHeadModel.from_pretrained("gpt2")

# tokenize input prompt to sequence of ids
prompt = "Artificial intelligence is"
inputs = tokenizer(prompt, return_tensors="pt")
# generate output as a sequence of token ids
output = model.generate(
    **inputs,
    max_length=50,
    num_return_sequences=1,
    temperature=1.0,
    top_k=50,
    top_p=1.0,
    repetition_penalty=1.0,
    do_sample=True,
    pad_token_id=tokenizer.eos_token_id,
)
# convert token ids into text strings
generated_text = tokenizer.decode(output[0], skip_special_tokens=True)

print(f"Prompt: {prompt}")
print("Generated Text:")
print(generated_text)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 11
