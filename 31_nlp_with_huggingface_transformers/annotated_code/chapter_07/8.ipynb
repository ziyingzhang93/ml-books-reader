# %% [markdown]
# # 8 —  / 8
#
# **Chapter 07 — File 10 of 11 / 第07章 — 第10个文件（共11个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Create a text generator instance**.
#
# 本脚本演示 **Create a text generator instance**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
...

# %% [markdown]
# ---
# ## Step 2 — Create a text generator instance

# %%
generator = TextGenerator()

# %% [markdown]
# ---
# ## Step 3 — Example 1: Basic text generation

# %%
prompt = "The future of artificial intelligence will"
generated_text = generator.generate_text(prompt)
print(f"Generated text:\n{generated_text}\n")

# %% [markdown]
# ---
# ## Step 4 — Example 2: More creative generation with higher temperature

# %%
creative_text = generator.generate_text(
    prompt="Once upon a time",
    temperature=0.9,
    max_length=200
)
print(f"Creative generation:\n{creative_text}\n")

# %% [markdown]
# ---
# ## Step 5 — Example 3: More focused generation with lower temperature

# %%
focused_text = generator.generate_text(
    prompt="The benefits of machine learning include",
    temperature=0.5,
    max_length=150
)
print(f"Focused generation:\n{focused_text}\n")

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Create a text generator instance 是机器学习中的常用技术。
#   *Create a text generator instance is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
#  / 8
# Complete Code / 完整代码
# ===============================

...
# Create a text generator instance
generator = TextGenerator()

# Example 1: Basic text generation
prompt = "The future of artificial intelligence will"
generated_text = generator.generate_text(prompt)
print(f"Generated text:\n{generated_text}\n")

# Example 2: More creative generation with higher temperature
creative_text = generator.generate_text(
    prompt="Once upon a time",
    temperature=0.9,
    max_length=200
)
print(f"Creative generation:\n{creative_text}\n")

# Example 3: More focused generation with lower temperature
focused_text = generator.generate_text(
    prompt="The benefits of machine learning include",
    temperature=0.5,
    max_length=150
)
print(f"Focused generation:\n{focused_text}\n")

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 11 of 11
