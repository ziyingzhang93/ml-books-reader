# %% [markdown]
# # 02 — Othermodel / 02 Othermodel
#
# **Chapter 02 — File 2 of 6 / 第02章 — 第2个文件（共6个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Othermodel**.
#
# 本脚本演示 **02 Othermodel**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import torch
from transformers import GPT2Tokenizer, OPTForSequenceClassification

model_name = "ArthurZ/opt-350m-dummy-sc"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = OPTForSequenceClassification.from_pretrained(model_name)

text = "Machine Learning Mastery is a nice website."
inputs = tokenizer(text, return_tensors="pt")
with torch.no_grad():
    logits = model(**inputs).logits
predicted_class_id = logits.argmax().item()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Othermodel 是机器学习中的常用技术。
#   *Othermodel is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Othermodel / 02 Othermodel
# Complete Code / 完整代码
# ===============================

import torch
from transformers import GPT2Tokenizer, OPTForSequenceClassification

model_name = "ArthurZ/opt-350m-dummy-sc"
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
model = OPTForSequenceClassification.from_pretrained(model_name)

text = "Machine Learning Mastery is a nice website."
inputs = tokenizer(text, return_tensors="pt")
with torch.no_grad():
    logits = model(**inputs).logits
predicted_class_id = logits.argmax().item()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 6
