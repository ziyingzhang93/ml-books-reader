# %% [markdown]
# # 04 — Sentiment / 情感分析
#
# **Chapter 03 — File 3 of 7 / 第03章 — 第3个文件（共7个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Create a sentiment analysis pipeline**.
#
# 本脚本演示 **Create a sentiment analysis pipeline**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import torch
from transformers import pipeline

# %% [markdown]
# ---
# ## Step 2 — Create a sentiment analysis pipeline

# %%
sentiment_analyzer = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english"
)

# %% [markdown]
# ---
# ## Step 3 — Test text

# %%
text = "I absolutely love this product! Would buy again."

# %% [markdown]
# ---
# ## Step 4 — Get the sentiment

# %%
result = sentiment_analyzer(text)
print(f"Sentiment: {result[0]['label']}")
print(f"Confidence: {result[0]['score']:.4f}")

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Create a sentiment analysis pipeline 是机器学习中的常用技术。
#   *Create a sentiment analysis pipeline is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Sentiment / 情感分析
# Complete Code / 完整代码
# ===============================

import torch
from transformers import pipeline

# Create a sentiment analysis pipeline
sentiment_analyzer = pipeline(
    "sentiment-analysis",
    model="distilbert-base-uncased-finetuned-sst-2-english"
)

# Test text
text = "I absolutely love this product! Would buy again."

# Get the sentiment
result = sentiment_analyzer(text)
print(f"Sentiment: {result[0]['label']}")
print(f"Confidence: {result[0]['score']:.4f}")

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 7
