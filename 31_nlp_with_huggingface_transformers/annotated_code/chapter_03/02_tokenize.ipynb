# %% [markdown]
# # 02 — Tokenize / 分词
#
# **Chapter 03 — File 1 of 7 / 第03章 — 第1个文件（共7个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Initialize the tokenizer**.
#
# 本脚本演示 **Initialize the tokenizer**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
from transformers import BertTokenizer

# %% [markdown]
# ---
# ## Step 2 — Initialize the tokenizer

# %%
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# %% [markdown]
# ---
# ## Step 3 — Text example

# %%
text = "I love machine learning!"

# %% [markdown]
# ---
# ## Step 4 — Tokenize the text

# %%
tokens = tokenizer.tokenize(text)
print(f"Original text: {text}")
print(f"Tokenized text: {tokens}")

# %% [markdown]
# ---
# ## Step 5 — Convert tokens to IDs

# %%
input_ids = tokenizer.convert_tokens_to_ids(tokens)
print(f"Token IDs: {input_ids}")

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Initialize the tokenizer 是机器学习中的常用技术。
#   *Initialize the tokenizer is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Tokenize / 分词
# Complete Code / 完整代码
# ===============================

from transformers import BertTokenizer

# Initialize the tokenizer
tokenizer = BertTokenizer.from_pretrained("bert-base-uncased")

# Text example
text = "I love machine learning!"

# Tokenize the text
tokens = tokenizer.tokenize(text)
print(f"Original text: {text}")
print(f"Tokenized text: {tokens}")

# Convert tokens to IDs
input_ids = tokenizer.convert_tokens_to_ids(tokens)
print(f"Token IDs: {input_ids}")

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 7
