# %% [markdown]
# # 02 — Inception Model / 02 Inception Model
#
# **Chapter 18 — File 2 of 6 / 第18章 — 第2个文件（共6个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of loading the inception v3 model**.
#
# 本脚本演示 **example of loading the inception v3 model**。

# %% [markdown]
# ---
# ## Step 1 — example of loading the inception v3 model

# %%
from keras.applications.inception_v3 import InceptionV3

# %% [markdown]
# ---
# ## Step 2 — load model

# %%
model = InceptionV3()

# %% [markdown]
# ---
# ## Step 3 — summarize the model

# %%
model.summary()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of loading the inception v3 model 是机器学习中的常用技术。
#   *example of loading the inception v3 model is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Inception Model / 02 Inception Model
# Complete Code / 完整代码
# ===============================

# example of loading the inception v3 model
from keras.applications.inception_v3 import InceptionV3
# load model
model = InceptionV3()
# summarize the model
model.summary()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 6
