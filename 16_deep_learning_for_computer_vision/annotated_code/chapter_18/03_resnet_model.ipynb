# %% [markdown]
# # 03 — Resnet Model / 03 Resnet Model
#
# **Chapter 18 — File 3 of 6 / 第18章 — 第3个文件（共6个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of loading the resnet50 model**.
#
# 本脚本演示 **example of loading the resnet50 model**。

# %% [markdown]
# ---
# ## Step 1 — example of loading the resnet50 model

# %%
from keras.applications.resnet50 import ResNet50

# %% [markdown]
# ---
# ## Step 2 — load model

# %%
model = ResNet50()

# %% [markdown]
# ---
# ## Step 3 — summarize the model

# %%
model.summary()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of loading the resnet50 model 是机器学习中的常用技术。
#   *example of loading the resnet50 model is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Resnet Model / 03 Resnet Model
# Complete Code / 完整代码
# ===============================

# example of loading the resnet50 model
from keras.applications.resnet50 import ResNet50
# load model
model = ResNet50()
# summarize the model
model.summary()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 6
