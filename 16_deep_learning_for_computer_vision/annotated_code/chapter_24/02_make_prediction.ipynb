# %% [markdown]
# # 02 — Make Prediction / 02 Make Prediction
#
# **Chapter 24 — File 2 of 3 / 第24章 — 第2个文件（共3个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **load yolov3 model and perform object detection**.
#
# 本脚本演示 **load yolov3 model and perform object detection**。

# %% [markdown]
# ---
# ## Step 1 — load yolov3 model and perform object detection
# based on https://github.com/experiencor/keras-yolo3

# %%
from numpy import expand_dims
from keras.models import load_model
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array

# %% [markdown]
# ---
# ## Step 2 — load and prepare an image

# %%
def load_image_pixels(filename, shape):

# %% [markdown]
# ---
# ## Step 3 — load the image to get its shape

# %%
image = load_img(filename)
    width, height = image.size

# %% [markdown]
# ---
# ## Step 4 — load the image with the required size

# %%
image = load_img(filename, target_size=shape)

# %% [markdown]
# ---
# ## Step 5 — convert to numpy array

# %%
image = img_to_array(image)

# %% [markdown]
# ---
# ## Step 6 — scale pixel values to [0, 1]

# %%
image = image.astype('float32')
    image /= 255.0

# %% [markdown]
# ---
# ## Step 7 — add a dimension so that we have one sample

# %%
image = expand_dims(image, 0)
    return image, width, height

# %% [markdown]
# ---
# ## Step 8 — load yolov3 model

# %%
model = load_model('model.h5')

# %% [markdown]
# ---
# ## Step 9 — define the expected input shape for the model

# %%
input_w, input_h = 416, 416

# %% [markdown]
# ---
# ## Step 10 — define our new photo

# %%
photo_filename = 'zebra.jpg'

# %% [markdown]
# ---
# ## Step 11 — load and prepare image

# %%
image, image_w, image_h = load_image_pixels(photo_filename, (input_w, input_h))

# %% [markdown]
# ---
# ## Step 12 — make prediction

# %%
yhat = model.predict(image)

# %% [markdown]
# ---
# ## Step 13 — summarize the shape of the list of arrays

# %%
print([a.shape for a in yhat])

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: load yolov3 model and perform object detection 是机器学习中的常用技术。
#   *load yolov3 model and perform object detection is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Make Prediction / 02 Make Prediction
# Complete Code / 完整代码
# ===============================

# load yolov3 model and perform object detection
# based on https://github.com/experiencor/keras-yolo3
from numpy import expand_dims
from keras.models import load_model
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array

# load and prepare an image
def load_image_pixels(filename, shape):
    # load the image to get its shape
    image = load_img(filename)
    width, height = image.size
    # load the image with the required size
    image = load_img(filename, target_size=shape)
    # convert to numpy array
    image = img_to_array(image)
    # scale pixel values to [0, 1]
    image = image.astype('float32')
    image /= 255.0
    # add a dimension so that we have one sample
    image = expand_dims(image, 0)
    return image, width, height

# load yolov3 model
model = load_model('model.h5')
# define the expected input shape for the model
input_w, input_h = 416, 416
# define our new photo
photo_filename = 'zebra.jpg'
# load and prepare image
image, image_w, image_h = load_image_pixels(photo_filename, (input_w, input_h))
# make prediction
yhat = model.predict(image)
# summarize the shape of the list of arrays
print([a.shape for a in yhat])

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 3
