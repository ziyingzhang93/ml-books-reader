# %% [markdown]
# # 01 — Load Dataset / 01 Load Dataset
#
# **Chapter 19 — File 1 of 7 / 第19章 — 第1个文件（共7个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of loading the fashion mnist dataset**.
#
# 本脚本演示 **example of loading the fashion mnist dataset**。

# %% [markdown]
# ---
# ## Step 1 — example of loading the fashion mnist dataset

# %%
from matplotlib import pyplot
from keras.datasets import fashion_mnist

# %% [markdown]
# ---
# ## Step 2 — load dataset

# %%
(trainX, trainy), (testX, testy) = fashion_mnist.load_data()

# %% [markdown]
# ---
# ## Step 3 — summarize loaded dataset

# %%
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))

# %% [markdown]
# ---
# ## Step 4 — plot first few images

# %%
for i in range(9):

# %% [markdown]
# ---
# ## Step 5 — define subplot

# %%
pyplot.subplot(330 + 1 + i)

# %% [markdown]
# ---
# ## Step 6 — plot raw pixel data

# %%
pyplot.imshow(trainX[i], cmap=pyplot.get_cmap('gray'))

# %% [markdown]
# ---
# ## Step 7 — show the figure

# %%
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of loading the fashion mnist dataset 是机器学习中的常用技术。
#   *example of loading the fashion mnist dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Load Dataset / 01 Load Dataset
# Complete Code / 完整代码
# ===============================

# example of loading the fashion mnist dataset
from matplotlib import pyplot
from keras.datasets import fashion_mnist
# load dataset
(trainX, trainy), (testX, testy) = fashion_mnist.load_data()
# summarize loaded dataset
print('Train: X=%s, y=%s' % (trainX.shape, trainy.shape))
print('Test: X=%s, y=%s' % (testX.shape, testy.shape))
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# plot raw pixel data
	pyplot.imshow(trainX[i], cmap=pyplot.get_cmap('gray'))
# show the figure
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 7
