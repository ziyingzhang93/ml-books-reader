# %% [markdown]
# # 01 — Plot Dataset / 01 Plot Dataset
#
# **Chapter 22 — File 1 of 15 / 第22章 — 第1个文件（共15个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **plot the first 9 images in the planet dataset**.
#
# 本脚本演示 **plot the first 9 images in the planet dataset**。

# %% [markdown]
# ---
# ## Step 1 — plot the first 9 images in the planet dataset

# %%
from matplotlib import pyplot
from matplotlib.image import imread

# %% [markdown]
# ---
# ## Step 2 — define location of dataset

# %%
folder = 'train-jpg/'

# %% [markdown]
# ---
# ## Step 3 — plot first few images

# %%
for i in range(9):

# %% [markdown]
# ---
# ## Step 4 — define subplot

# %%
pyplot.subplot(330 + 1 + i)

# %% [markdown]
# ---
# ## Step 5 — define filename

# %%
filename = folder + 'train_' + str(i) + '.jpg'

# %% [markdown]
# ---
# ## Step 6 — load image pixels

# %%
image = imread(filename)

# %% [markdown]
# ---
# ## Step 7 — plot raw pixel data

# %%
pyplot.imshow(image)

# %% [markdown]
# ---
# ## Step 8 — show the figure

# %%
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: plot the first 9 images in the planet dataset 是机器学习中的常用技术。
#   *plot the first 9 images in the planet dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Plot Dataset / 01 Plot Dataset
# Complete Code / 完整代码
# ===============================

# plot the first 9 images in the planet dataset
from matplotlib import pyplot
from matplotlib.image import imread
# define location of dataset
folder = 'train-jpg/'
# plot first few images
for i in range(9):
	# define subplot
	pyplot.subplot(330 + 1 + i)
	# define filename
	filename = folder + 'train_' + str(i) + '.jpg'
	# load image pixels
	image = imread(filename)
	# plot raw pixel data
	pyplot.imshow(image)
# show the figure
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 15
