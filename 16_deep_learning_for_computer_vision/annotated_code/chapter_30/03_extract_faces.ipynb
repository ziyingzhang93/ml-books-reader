# %% [markdown]
# # 03 — Extract Faces / 人脸识别
#
# **Chapter 30 — File 3 of 7 / 第30章 — 第3个文件（共7个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **demonstrate face detection on 5 Celebrity Faces Dataset**.
#
# 本脚本演示 **demonstrate face detection on 5 Celebrity Faces Dataset**。

# %% [markdown]
# ---
# ## Step 1 — demonstrate face detection on 5 Celebrity Faces Dataset

# %%
from os import listdir
from PIL import Image
from numpy import asarray
from matplotlib import pyplot
from mtcnn.mtcnn import MTCNN

# %% [markdown]
# ---
# ## Step 2 — extract a single face from a given photograph

# %%
def extract_face(filename, required_size=(160, 160)):

# %% [markdown]
# ---
# ## Step 3 — load image from file

# %%
image = Image.open(filename)

# %% [markdown]
# ---
# ## Step 4 — convert to RGB, if needed

# %%
image = image.convert('RGB')

# %% [markdown]
# ---
# ## Step 5 — convert to array

# %%
pixels = asarray(image)

# %% [markdown]
# ---
# ## Step 6 — create the detector, using default weights

# %%
detector = MTCNN()

# %% [markdown]
# ---
# ## Step 7 — detect faces in the image

# %%
results = detector.detect_faces(pixels)

# %% [markdown]
# ---
# ## Step 8 — extract the bounding box from the first face

# %%
x1, y1, width, height = results[0]['box']

# %% [markdown]
# ---
# ## Step 9 — bug fix

# %%
x1, y1 = abs(x1), abs(y1)
	x2, y2 = x1 + width, y1 + height

# %% [markdown]
# ---
# ## Step 10 — extract the face

# %%
face = pixels[y1:y2, x1:x2]

# %% [markdown]
# ---
# ## Step 11 — resize pixels to the model size

# %%
image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
	return face_array

# %% [markdown]
# ---
# ## Step 12 — specify folder to plot

# %%
folder = '5-celebrity-faces-dataset/train/ben_afflek/'
i = 1

# %% [markdown]
# ---
# ## Step 13 — enumerate files

# %%
for filename in listdir(folder):

# %% [markdown]
# ---
# ## Step 14 — path

# %%
path = folder + filename

# %% [markdown]
# ---
# ## Step 15 — get face

# %%
face = extract_face(path)
	print(i, face.shape)

# %% [markdown]
# ---
# ## Step 16 — plot

# %%
pyplot.subplot(2, 7, i)
	pyplot.axis('off')
	pyplot.imshow(face)
	i += 1
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: demonstrate face detection on 5 Celebrity Faces Dataset 是机器学习中的常用技术。
#   *demonstrate face detection on 5 Celebrity Faces Dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Extract Faces / 人脸识别
# Complete Code / 完整代码
# ===============================

# demonstrate face detection on 5 Celebrity Faces Dataset
from os import listdir
from PIL import Image
from numpy import asarray
from matplotlib import pyplot
from mtcnn.mtcnn import MTCNN

# extract a single face from a given photograph
def extract_face(filename, required_size=(160, 160)):
	# load image from file
	image = Image.open(filename)
	# convert to RGB, if needed
	image = image.convert('RGB')
	# convert to array
	pixels = asarray(image)
	# create the detector, using default weights
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	# bug fix
	x1, y1 = abs(x1), abs(y1)
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
	return face_array

# specify folder to plot
folder = '5-celebrity-faces-dataset/train/ben_afflek/'
i = 1
# enumerate files
for filename in listdir(folder):
	# path
	path = folder + filename
	# get face
	face = extract_face(path)
	print(i, face.shape)
	# plot
	pyplot.subplot(2, 7, i)
	pyplot.axis('off')
	pyplot.imshow(face)
	i += 1
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 7
