# %% [markdown]
# # 03 — Preprocess Photo Sizes / 03 Preprocess Photo Sizes
#
# **Chapter 21 — File 3 of 14 / 第21章 — 第3个文件（共14个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **load dogs vs cats dataset, reshape and save to a new file**.
#
# 本脚本演示 **load dogs vs cats dataset, reshape and save to a new file**。

# %% [markdown]
# ---
# ## Step 1 — load dogs vs cats dataset, reshape and save to a new file

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array

# %% [markdown]
# ---
# ## Step 2 — define location of dataset

# %%
folder = 'train/'
photos, labels = list(), list()

# %% [markdown]
# ---
# ## Step 3 — enumerate files in the directory

# %%
for file in listdir(folder):

# %% [markdown]
# ---
# ## Step 4 — determine class

# %%
output = 0.0
	if file.startswith('cat'):
		output = 1.0

# %% [markdown]
# ---
# ## Step 5 — load image

# %%
photo = load_img(folder + file, target_size=(200, 200))

# %% [markdown]
# ---
# ## Step 6 — convert to numpy array

# %%
photo = img_to_array(photo)

# %% [markdown]
# ---
# ## Step 7 — store

# %%
photos.append(photo)
	labels.append(output)

# %% [markdown]
# ---
# ## Step 8 — convert to numpy arrays

# %%
photos = asarray(photos)
labels = asarray(labels)
print(photos.shape, labels.shape)

# %% [markdown]
# ---
# ## Step 9 — save the reshaped photos

# %%
save('dogs_vs_cats_photos.npy', photos)
save('dogs_vs_cats_labels.npy', labels)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: load dogs vs cats dataset, reshape and save to a new file 是机器学习中的常用技术。
#   *load dogs vs cats dataset, reshape and save to a new file is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Preprocess Photo Sizes / 03 Preprocess Photo Sizes
# Complete Code / 完整代码
# ===============================

# load dogs vs cats dataset, reshape and save to a new file
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img
from keras.preprocessing.image import img_to_array
# define location of dataset
folder = 'train/'
photos, labels = list(), list()
# enumerate files in the directory
for file in listdir(folder):
	# determine class
	output = 0.0
	if file.startswith('cat'):
		output = 1.0
	# load image
	photo = load_img(folder + file, target_size=(200, 200))
	# convert to numpy array
	photo = img_to_array(photo)
	# store
	photos.append(photo)
	labels.append(output)
# convert to numpy arrays
photos = asarray(photos)
labels = asarray(labels)
print(photos.shape, labels.shape)
# save the reshaped photos
save('dogs_vs_cats_photos.npy', photos)
save('dogs_vs_cats_labels.npy', labels)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 14
