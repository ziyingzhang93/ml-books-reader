# %% [markdown]
# # 06 — Vggface Face Identification Tatum / 人脸识别
#
# **Chapter 29 — File 6 of 7 / 第29章 — 第6个文件（共7个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Example of face detection with a vggface2 model (Channing Tatum)**.
#
# 本脚本演示 **Example of face detection with a vggface2 model (Channing Tatum)**。

# %% [markdown]
# ---
# ## Step 1 — Example of face detection with a vggface2 model (Channing Tatum)

# %%
from numpy import expand_dims
from matplotlib import pyplot
from PIL import Image
from numpy import asarray
from mtcnn.mtcnn import MTCNN
from keras_vggface.vggface import VGGFace
from keras_vggface.utils import preprocess_input
from keras_vggface.utils import decode_predictions

# %% [markdown]
# ---
# ## Step 2 — extract a single face from a given photograph

# %%
def extract_face(filename, required_size=(224, 224)):

# %% [markdown]
# ---
# ## Step 3 — load image from file

# %%
pixels = pyplot.imread(filename)

# %% [markdown]
# ---
# ## Step 4 — create the detector, using default weights

# %%
detector = MTCNN()

# %% [markdown]
# ---
# ## Step 5 — detect faces in the image

# %%
results = detector.detect_faces(pixels)

# %% [markdown]
# ---
# ## Step 6 — extract the bounding box from the first face

# %%
x1, y1, width, height = results[0]['box']
	x2, y2 = x1 + width, y1 + height

# %% [markdown]
# ---
# ## Step 7 — extract the face

# %%
face = pixels[y1:y2, x1:x2]

# %% [markdown]
# ---
# ## Step 8 — resize pixels to the model size

# %%
image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
	return face_array

# %% [markdown]
# ---
# ## Step 9 — load the photo and extract the face

# %%
pixels = extract_face('channing_tatum.jpg')

# %% [markdown]
# ---
# ## Step 10 — convert one face into samples

# %%
pixels = pixels.astype('float32')
samples = expand_dims(pixels, axis=0)

# %% [markdown]
# ---
# ## Step 11 — prepare the face for the model, e.g. center pixels

# %%
samples = preprocess_input(samples, version=2)

# %% [markdown]
# ---
# ## Step 12 — create a vggface model

# %%
model = VGGFace(model='resnet50')

# %% [markdown]
# ---
# ## Step 13 — perform prediction

# %%
yhat = model.predict(samples)

# %% [markdown]
# ---
# ## Step 14 — convert prediction into names

# %%
results = decode_predictions(yhat)

# %% [markdown]
# ---
# ## Step 15 — display most likely results

# %%
for result in results[0]:
	print('%s: %.3f%%' % (result[0][3:-1], result[1]*100))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Example of face detection with a vggface2 model (Channing Tatum) 是机器学习中的常用技术。
#   *Example of face detection with a vggface2 model (Channing Tatum) is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Vggface Face Identification Tatum / 人脸识别
# Complete Code / 完整代码
# ===============================

# Example of face detection with a vggface2 model (Channing Tatum)
from numpy import expand_dims
from matplotlib import pyplot
from PIL import Image
from numpy import asarray
from mtcnn.mtcnn import MTCNN
from keras_vggface.vggface import VGGFace
from keras_vggface.utils import preprocess_input
from keras_vggface.utils import decode_predictions

# extract a single face from a given photograph
def extract_face(filename, required_size=(224, 224)):
	# load image from file
	pixels = pyplot.imread(filename)
	# create the detector, using default weights
	detector = MTCNN()
	# detect faces in the image
	results = detector.detect_faces(pixels)
	# extract the bounding box from the first face
	x1, y1, width, height = results[0]['box']
	x2, y2 = x1 + width, y1 + height
	# extract the face
	face = pixels[y1:y2, x1:x2]
	# resize pixels to the model size
	image = Image.fromarray(face)
	image = image.resize(required_size)
	face_array = asarray(image)
	return face_array

# load the photo and extract the face
pixels = extract_face('channing_tatum.jpg')
# convert one face into samples
pixels = pixels.astype('float32')
samples = expand_dims(pixels, axis=0)
# prepare the face for the model, e.g. center pixels
samples = preprocess_input(samples, version=2)
# create a vggface model
model = VGGFace(model='resnet50')
# perform prediction
yhat = model.predict(samples)
# convert prediction into names
results = decode_predictions(yhat)
# display most likely results
for result in results[0]:
	print('%s: %.3f%%' % (result[0][3:-1], result[1]*100))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 7 of 7
