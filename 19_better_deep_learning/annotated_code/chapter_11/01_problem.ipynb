# %% [markdown]
# # 01 — Problem / 01 Problem
#
# **Chapter 11 — File 1 of 5 / 第11章 — 第1个文件（共5个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **plot of blobs multiclass classification problems 1 and 2**.
#
# 本脚本演示 **plot of blobs multiclass classification problems 1 and 2**。

# %% [markdown]
# ---
# ## Step 1 — plot of blobs multiclass classification problems 1 and 2

# %%
from sklearn.datasets import make_blobs
from numpy import where
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — generate samples for blobs problem with a given random seed

# %%
def samples_for_seed(seed):

# %% [markdown]
# ---
# ## Step 3 — generate samples

# %%
X, y = make_blobs(n_samples=1000, centers=3, n_features=2, cluster_std=2, random_state=seed)
	return X, y

# %% [markdown]
# ---
# ## Step 4 — create a scatter plot of points colored by class value

# %%
def plot_samples(X, y, classes=3):

# %% [markdown]
# ---
# ## Step 5 — plot points for each class

# %%
for i in range(classes):

# %% [markdown]
# ---
# ## Step 6 — select indices of points with each class label

# %%
samples_ix = where(y == i)

# %% [markdown]
# ---
# ## Step 7 — plot points for this class with a given color

# %%
pyplot.scatter(X[samples_ix, 0], X[samples_ix, 1])

# %% [markdown]
# ---
# ## Step 8 — generate multiple problems

# %%
n_problems = 2
for i in range(1, n_problems+1):

# %% [markdown]
# ---
# ## Step 9 — specify subplot

# %%
pyplot.subplot(210 + i)

# %% [markdown]
# ---
# ## Step 10 — generate samples

# %%
X, y = samples_for_seed(i)

# %% [markdown]
# ---
# ## Step 11 — scatter plot of samples

# %%
plot_samples(X, y)

# %% [markdown]
# ---
# ## Step 12 — plot figure

# %%
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: plot of blobs multiclass classification problems 1 and 2 是机器学习中的常用技术。
#   *plot of blobs multiclass classification problems 1 and 2 is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Problem / 01 Problem
# Complete Code / 完整代码
# ===============================

# plot of blobs multiclass classification problems 1 and 2
from sklearn.datasets import make_blobs
from numpy import where
from matplotlib import pyplot

# generate samples for blobs problem with a given random seed
def samples_for_seed(seed):
	# generate samples
	X, y = make_blobs(n_samples=1000, centers=3, n_features=2, cluster_std=2, random_state=seed)
	return X, y

# create a scatter plot of points colored by class value
def plot_samples(X, y, classes=3):
	# plot points for each class
	for i in range(classes):
		# select indices of points with each class label
		samples_ix = where(y == i)
		# plot points for this class with a given color
		pyplot.scatter(X[samples_ix, 0], X[samples_ix, 1])

# generate multiple problems
n_problems = 2
for i in range(1, n_problems+1):
	# specify subplot
	pyplot.subplot(210 + i)
	# generate samples
	X, y = samples_for_seed(i)
	# scatter plot of samples
	plot_samples(X, y)
# plot figure
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 5
