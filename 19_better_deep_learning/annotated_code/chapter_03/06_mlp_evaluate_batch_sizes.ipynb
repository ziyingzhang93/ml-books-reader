# %% [markdown]
# # 06 — Mlp Evaluate Batch Sizes / 模型评估
#
# **Chapter 03 — File 6 of 6 / 第03章 — 第6个文件（共6个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **mlp for the blobs problem with minibatch gradient descent with varied batch size**.
#
# 本脚本演示 **mlp for the blobs problem with minibatch gradient descent with varied batch size**。

# %% [markdown]
# ---
# ## Step 1 — mlp for the blobs problem with minibatch gradient descent with varied batch size

# %%
from sklearn.datasets import make_blobs
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import SGD
from keras.utils import to_categorical
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — prepare train and test dataset

# %%
def prepare_data():

# %% [markdown]
# ---
# ## Step 3 — generate 2d classification dataset

# %%
X, y = make_blobs(n_samples=1000, centers=3, n_features=2, cluster_std=2, random_state=2)

# %% [markdown]
# ---
# ## Step 4 — one hot encode output variable

# %%
y = to_categorical(y)

# %% [markdown]
# ---
# ## Step 5 — split into train and test

# %%
n_train = 500
	trainX, testX = X[:n_train, :], X[n_train:, :]
	trainy, testy = y[:n_train], y[n_train:]
	return trainX, trainy, testX, testy

# %% [markdown]
# ---
# ## Step 6 — fit a model and plot learning curve

# %%
def fit_model(trainX, trainy, testX, testy, n_batch):

# %% [markdown]
# ---
# ## Step 7 — define model

# %%
model = Sequential()
	model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(3, activation='softmax'))

# %% [markdown]
# ---
# ## Step 8 — compile model

# %%
opt = SGD(lr=0.01, momentum=0.9)
	model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# %% [markdown]
# ---
# ## Step 9 — fit model

# %%
history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=200, verbose=0, batch_size=n_batch)

# %% [markdown]
# ---
# ## Step 10 — plot learning curves

# %%
pyplot.plot(history.history['accuracy'], label='train')
	pyplot.plot(history.history['val_accuracy'], label='test')
	pyplot.title('batch='+str(n_batch), pad=-40)

# %% [markdown]
# ---
# ## Step 11 — prepare dataset

# %%
trainX, trainy, testX, testy = prepare_data()

# %% [markdown]
# ---
# ## Step 12 — create learning curves for different batch sizes

# %%
batch_sizes = [4, 8, 16, 32, 64, 128, 256, 450]
for i in range(len(batch_sizes)):

# %% [markdown]
# ---
# ## Step 13 — determine the plot number

# %%
plot_no = 420 + (i+1)
	pyplot.subplot(plot_no)

# %% [markdown]
# ---
# ## Step 14 — fit model and plot learning curves for a batch size

# %%
fit_model(trainX, trainy, testX, testy, batch_sizes[i])

# %% [markdown]
# ---
# ## Step 15 — show learning curves

# %%
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: mlp for the blobs problem with minibatch gradient descent with varied batch size 是机器学习中的常用技术。
#   *mlp for the blobs problem with minibatch gradient descent with varied batch size is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Mlp Evaluate Batch Sizes / 模型评估
# Complete Code / 完整代码
# ===============================

# mlp for the blobs problem with minibatch gradient descent with varied batch size
from sklearn.datasets import make_blobs
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import SGD
from keras.utils import to_categorical
from matplotlib import pyplot

# prepare train and test dataset
def prepare_data():
	# generate 2d classification dataset
	X, y = make_blobs(n_samples=1000, centers=3, n_features=2, cluster_std=2, random_state=2)
	# one hot encode output variable
	y = to_categorical(y)
	# split into train and test
	n_train = 500
	trainX, testX = X[:n_train, :], X[n_train:, :]
	trainy, testy = y[:n_train], y[n_train:]
	return trainX, trainy, testX, testy

# fit a model and plot learning curve
def fit_model(trainX, trainy, testX, testy, n_batch):
	# define model
	model = Sequential()
	model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(3, activation='softmax'))
	# compile model
	opt = SGD(lr=0.01, momentum=0.9)
	model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
	# fit model
	history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=200, verbose=0, batch_size=n_batch)
	# plot learning curves
	pyplot.plot(history.history['accuracy'], label='train')
	pyplot.plot(history.history['val_accuracy'], label='test')
	pyplot.title('batch='+str(n_batch), pad=-40)

# prepare dataset
trainX, trainy, testX, testy = prepare_data()
# create learning curves for different batch sizes
batch_sizes = [4, 8, 16, 32, 64, 128, 256, 450]
for i in range(len(batch_sizes)):
	# determine the plot number
	plot_no = 420 + (i+1)
	pyplot.subplot(plot_no)
	# fit model and plot learning curves for a batch size
	fit_model(trainX, trainy, testX, testy, batch_sizes[i])
# show learning curves
pyplot.show()
