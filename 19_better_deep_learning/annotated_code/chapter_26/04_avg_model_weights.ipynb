# %% [markdown]
# # 04 — Avg Model Weights / 04 Avg Model Weights
#
# **Chapter 26 — File 4 of 7 / 第26章 — 第4个文件（共7个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **average the weights of multiple loaded models**.
#
# 本脚本演示 **average the weights of multiple loaded models**。

# %% [markdown]
# ---
# ## Step 1 — average the weights of multiple loaded models

# %%
from keras.models import load_model
from keras.models import clone_model
from numpy import average
from numpy import array

# %% [markdown]
# ---
# ## Step 2 — load models from file

# %%
def load_all_models(n_start, n_end):
	all_models = list()
	for epoch in range(n_start, n_end):

# %% [markdown]
# ---
# ## Step 3 — define filename for this ensemble

# %%
filename = 'model_' + str(epoch) + '.h5'

# %% [markdown]
# ---
# ## Step 4 — load model from file

# %%
model = load_model(filename)

# %% [markdown]
# ---
# ## Step 5 — add to list of members

# %%
all_models.append(model)
		print('>loaded %s' % filename)
	return all_models

# %% [markdown]
# ---
# ## Step 6 — create a model from the weights of multiple models

# %%
def model_weight_ensemble(members, weights):

# %% [markdown]
# ---
# ## Step 7 — determine how many layers need to be averaged

# %%
n_layers = len(members[0].get_weights())

# %% [markdown]
# ---
# ## Step 8 — create an set of average model weights

# %%
avg_model_weights = list()
	for layer in range(n_layers):

# %% [markdown]
# ---
# ## Step 9 — collect this layer from each model

# %%
layer_weights = array([model.get_weights()[layer] for model in members])

# %% [markdown]
# ---
# ## Step 10 — weighted average of weights for this layer

# %%
avg_layer_weights = average(layer_weights, axis=0, weights=weights)

# %% [markdown]
# ---
# ## Step 11 — store average layer weights

# %%
avg_model_weights.append(avg_layer_weights)

# %% [markdown]
# ---
# ## Step 12 — create a new model with the same structure

# %%
model = clone_model(members[0])

# %% [markdown]
# ---
# ## Step 13 — set the weights in the new

# %%
model.set_weights(avg_model_weights)
	model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model

# %% [markdown]
# ---
# ## Step 14 — load all models into memory

# %%
members = load_all_models(490, 500)
print('Loaded %d models' % len(members))

# %% [markdown]
# ---
# ## Step 15 — prepare an array of equal weights

# %%
n_models = len(members)
weights = [1/n_models for i in range(1, n_models+1)]

# %% [markdown]
# ---
# ## Step 16 — create a new model with the weighted average of all model weights

# %%
model = model_weight_ensemble(members, weights)

# %% [markdown]
# ---
# ## Step 17 — summarize the created model

# %%
model.summary()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: average the weights of multiple loaded models 是机器学习中的常用技术。
#   *average the weights of multiple loaded models is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Avg Model Weights / 04 Avg Model Weights
# Complete Code / 完整代码
# ===============================

# average the weights of multiple loaded models
from keras.models import load_model
from keras.models import clone_model
from numpy import average
from numpy import array

# load models from file
def load_all_models(n_start, n_end):
	all_models = list()
	for epoch in range(n_start, n_end):
		# define filename for this ensemble
		filename = 'model_' + str(epoch) + '.h5'
		# load model from file
		model = load_model(filename)
		# add to list of members
		all_models.append(model)
		print('>loaded %s' % filename)
	return all_models

# create a model from the weights of multiple models
def model_weight_ensemble(members, weights):
	# determine how many layers need to be averaged
	n_layers = len(members[0].get_weights())
	# create an set of average model weights
	avg_model_weights = list()
	for layer in range(n_layers):
		# collect this layer from each model
		layer_weights = array([model.get_weights()[layer] for model in members])
		# weighted average of weights for this layer
		avg_layer_weights = average(layer_weights, axis=0, weights=weights)
		# store average layer weights
		avg_model_weights.append(avg_layer_weights)
	# create a new model with the same structure
	model = clone_model(members[0])
	# set the weights in the new
	model.set_weights(avg_model_weights)
	model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model

# load all models into memory
members = load_all_models(490, 500)
print('Loaded %d models' % len(members))
# prepare an array of equal weights
n_models = len(members)
weights = [1/n_models for i in range(1, n_models+1)]
# create a new model with the weighted average of all model weights
model = model_weight_ensemble(members, weights)
# summarize the created model
model.summary()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 7
