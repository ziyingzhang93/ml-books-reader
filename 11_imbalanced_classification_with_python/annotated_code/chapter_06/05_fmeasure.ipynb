# %% [markdown]
# # 05 — Fmeasure / 05 Fmeasure
#
# **Chapter 06 — File 5 of 5 / 第06章 — 第5个文件（共5个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **calculates f1 for 1:100 dataset with 95tp, 5fn, 55fp**.
#
# 本脚本演示 **calculates f1 for 1:100 dataset with 95tp, 5fn, 55fp**。

# %% [markdown]
# ---
# ## Step 1 — calculates f1 for 1:100 dataset with 95tp, 5fn, 55fp

# %%
from sklearn.metrics import f1_score

# %% [markdown]
# ---
# ## Step 2 — define actual

# %%
act_pos = [1 for _ in range(100)]
act_neg = [0 for _ in range(10000)]
y_true = act_pos + act_neg

# %% [markdown]
# ---
# ## Step 3 — define predictions

# %%
pred_pos = [0 for _ in range(5)] + [1 for _ in range(95)]
pred_neg = [1 for _ in range(55)] + [0 for _ in range(9945)]
y_pred = pred_pos + pred_neg

# %% [markdown]
# ---
# ## Step 4 — calculate score

# %%
score = f1_score(y_true, y_pred, average='binary')
print('F-measure: %.3f' % score)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: calculates f1 for 1:100 dataset with 95tp, 5fn, 55fp 是机器学习中的常用技术。
#   *calculates f1 for 1:100 dataset with 95tp, 5fn, 55fp is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Fmeasure / 05 Fmeasure
# Complete Code / 完整代码
# ===============================

# calculates f1 for 1:100 dataset with 95tp, 5fn, 55fp
from sklearn.metrics import f1_score
# define actual
act_pos = [1 for _ in range(100)]
act_neg = [0 for _ in range(10000)]
y_true = act_pos + act_neg
# define predictions
pred_pos = [0 for _ in range(5)] + [1 for _ in range(95)]
pred_neg = [1 for _ in range(55)] + [0 for _ in range(9945)]
y_pred = pred_pos + pred_neg
# calculate score
score = f1_score(y_true, y_pred, average='binary')
print('F-measure: %.3f' % score)
