# %% [markdown]
# # Chapter 06 Summary / 第06章总结
#
# ## Theme / 主题: Chapter 06 / Chapter 06
#
# This chapter contains **5 code files** demonstrating chapter 06.
#
# 本章包含 **5 个代码文件**，演示Chapter 06。

# %% [markdown]
# ---
# ## Evolution / 演化路线
#
#   1. `01_precision_binary.ipynb` — Precision Binary
#   2. `02_precision_multiclass.ipynb` — Precision Multiclass
#   3. `03_recall_binary.ipynb` — Recall Binary
#   4. `04_recall_multiclass.ipynb` — Recall Multiclass
#   5. `05_fmeasure.ipynb` — Fmeasure

# %% [markdown]
# ---
# ## ML Relevance / ML 关联
#
# The techniques in this chapter (Chapter 06) are fundamental building blocks in machine learning pipelines.
#
# 本章技术（Chapter 06）是机器学习流水线中的基础构建块。
