# %% [markdown]
# # 06 — Cost Sensitive Models / 代价敏感学习
#
# **Chapter 29 — File 6 of 7 / 第29章 — 第6个文件（共7个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **cost-sensitive machine learning algorithms on the mammography dataset**.
#
# 本脚本演示 **cost-sensitive machine learning algorithms on the mammography dataset**。

# %% [markdown]
# ---
# ## Step 1 — cost-sensitive machine learning algorithms on the mammography dataset

# %%
from numpy import mean
from numpy import std
from pandas import read_csv
from matplotlib import pyplot
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import PowerTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ---
# ## Step 2 — load the dataset

# %%
def load_dataset(full_path):

# %% [markdown]
# ---
# ## Step 3 — load the dataset as a numpy array

# %%
data = read_csv(full_path, header=None)

# %% [markdown]
# ---
# ## Step 4 — retrieve numpy array

# %%
data = data.values

# %% [markdown]
# ---
# ## Step 5 — split into input and output elements

# %%
X, y = data[:, :-1], data[:, -1]

# %% [markdown]
# ---
# ## Step 6 — label encode the target variable to have the classes 0 and 1

# %%
y = LabelEncoder().fit_transform(y)
	return X, y

# %% [markdown]
# ---
# ## Step 7 — evaluate a model

# %%
def evaluate_model(X, y, model):

# %% [markdown]
# ---
# ## Step 8 — define evaluation procedure

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ---
# ## Step 9 — evaluate model

# %%
scores = cross_val_score(model, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
	return scores

# %% [markdown]
# ---
# ## Step 10 — define models to test

# %%
def get_models():
	models, names = list(), list()

# %% [markdown]
# ---
# ## Step 11 — LR

# %%
models.append(LogisticRegression(solver='lbfgs', class_weight='balanced'))
	names.append('LR')

# %% [markdown]
# ---
# ## Step 12 — SVM

# %%
models.append(SVC(gamma='scale', class_weight='balanced'))
	names.append('SVM')

# %% [markdown]
# ---
# ## Step 13 — RF

# %%
models.append(RandomForestClassifier(n_estimators=1000))
	names.append('RF')
	return models, names

# %% [markdown]
# ---
# ## Step 14 — define the location of the dataset

# %%
full_path = 'mammography.csv'

# %% [markdown]
# ---
# ## Step 15 — load the dataset

# %%
X, y = load_dataset(full_path)

# %% [markdown]
# ---
# ## Step 16 — define models

# %%
models, names = get_models()
results = list()

# %% [markdown]
# ---
# ## Step 17 — evaluate each model

# %%
for i in range(len(models)):

# %% [markdown]
# ---
# ## Step 18 — defines pipeline steps

# %%
steps = [('p', PowerTransformer()), ('m',models[i])]

# %% [markdown]
# ---
# ## Step 19 — define pipeline

# %%
pipeline = Pipeline(steps=steps)

# %% [markdown]
# ---
# ## Step 20 — evaluate the pipeline and store results

# %%
scores = evaluate_model(X, y, pipeline)
	results.append(scores)

# %% [markdown]
# ---
# ## Step 21 — summarize and store

# %%
print('>%s %.3f (%.3f)' % (names[i], mean(scores), std(scores)))

# %% [markdown]
# ---
# ## Step 22 — plot the results

# %%
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: cost-sensitive machine learning algorithms on the mammography dataset 是机器学习中的常用技术。
#   *cost-sensitive machine learning algorithms on the mammography dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Cost Sensitive Models / 代价敏感学习
# Complete Code / 完整代码
# ===============================

# cost-sensitive machine learning algorithms on the mammography dataset
from numpy import mean
from numpy import std
from pandas import read_csv
from matplotlib import pyplot
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import PowerTransformer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

# load the dataset
def load_dataset(full_path):
	# load the dataset as a numpy array
	data = read_csv(full_path, header=None)
	# retrieve numpy array
	data = data.values
	# split into input and output elements
	X, y = data[:, :-1], data[:, -1]
	# label encode the target variable to have the classes 0 and 1
	y = LabelEncoder().fit_transform(y)
	return X, y

# evaluate a model
def evaluate_model(X, y, model):
	# define evaluation procedure
	cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
	# evaluate model
	scores = cross_val_score(model, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
	return scores

# define models to test
def get_models():
	models, names = list(), list()
	# LR
	models.append(LogisticRegression(solver='lbfgs', class_weight='balanced'))
	names.append('LR')
	# SVM
	models.append(SVC(gamma='scale', class_weight='balanced'))
	names.append('SVM')
	# RF
	models.append(RandomForestClassifier(n_estimators=1000))
	names.append('RF')
	return models, names

# define the location of the dataset
full_path = 'mammography.csv'
# load the dataset
X, y = load_dataset(full_path)
# define models
models, names = get_models()
results = list()
# evaluate each model
for i in range(len(models)):
	# defines pipeline steps
	steps = [('p', PowerTransformer()), ('m',models[i])]
	# define pipeline
	pipeline = Pipeline(steps=steps)
	# evaluate the pipeline and store results
	scores = evaluate_model(X, y, pipeline)
	results.append(scores)
	# summarize and store
	print('>%s %.3f (%.3f)' % (names[i], mean(scores), std(scores)))
# plot the results
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 7 of 7
