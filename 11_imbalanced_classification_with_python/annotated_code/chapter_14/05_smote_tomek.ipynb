# %% [markdown]
# # 05 — Smote Tomek / SMOTE 过采样
#
# **Chapter 14 — File 5 of 6 / 第14章 — 第5个文件（共6个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **combined SMOTE and Tomek Links sampling for imbalanced classification**.
#
# 本脚本演示 **combined SMOTE and Tomek Links sampling for imbalanced classification**。

# %% [markdown]
# ---
# ## Step 1 — combined SMOTE and Tomek Links sampling for imbalanced classification

# %%
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from imblearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import TomekLinks

# %% [markdown]
# ---
# ## Step 2 — generate dataset

# %%
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0, n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)

# %% [markdown]
# ---
# ## Step 3 — define model

# %%
model = DecisionTreeClassifier()

# %% [markdown]
# ---
# ## Step 4 — define sampling

# %%
resample = SMOTETomek(tomek=TomekLinks(sampling_strategy='majority'))

# %% [markdown]
# ---
# ## Step 5 — define pipeline

# %%
pipeline = Pipeline(steps=[('r', resample), ('m', model)])

# %% [markdown]
# ---
# ## Step 6 — define evaluation procedure

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ---
# ## Step 7 — evaluate model

# %%
scores = cross_val_score(pipeline, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)

# %% [markdown]
# ---
# ## Step 8 — summarize performance

# %%
print('Mean ROC AUC: %.3f' % mean(scores))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: combined SMOTE and Tomek Links sampling for imbalanced classification 是机器学习中的常用技术。
#   *combined SMOTE and Tomek Links sampling for imbalanced classification is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Smote Tomek / SMOTE 过采样
# Complete Code / 完整代码
# ===============================

# combined SMOTE and Tomek Links sampling for imbalanced classification
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from imblearn.pipeline import Pipeline
from sklearn.tree import DecisionTreeClassifier
from imblearn.combine import SMOTETomek
from imblearn.under_sampling import TomekLinks
# generate dataset
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0, n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)
# define model
model = DecisionTreeClassifier()
# define sampling
resample = SMOTETomek(tomek=TomekLinks(sampling_strategy='majority'))
# define pipeline
pipeline = Pipeline(steps=[('r', resample), ('m', model)])
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(pipeline, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: %.3f' % mean(scores))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 6 of 6
