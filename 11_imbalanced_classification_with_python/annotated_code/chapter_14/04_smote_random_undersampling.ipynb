# %% [markdown]
# # 04 — Smote Random Undersampling / 欠采样
#
# **Chapter 14 — File 4 of 6 / 第14章 — 第4个文件（共6个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **combination of SMOTE and random undersampling for imbalanced classification**.
#
# 本脚本演示 **combination of SMOTE and random undersampling for imbalanced classification**。

# %% [markdown]
# ---
# ## Step 1 — combination of SMOTE and random undersampling for imbalanced classification

# %%
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler

# %% [markdown]
# ---
# ## Step 2 — generate dataset

# %%
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0, n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)

# %% [markdown]
# ---
# ## Step 3 — define model

# %%
model = DecisionTreeClassifier()

# %% [markdown]
# ---
# ## Step 4 — define pipeline

# %%
over = SMOTE(sampling_strategy=0.1)
under = RandomUnderSampler(sampling_strategy=0.5)
steps = [('o', over), ('u', under), ('m', model)]
pipeline = Pipeline(steps=steps)

# %% [markdown]
# ---
# ## Step 5 — define evaluation procedure

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ---
# ## Step 6 — evaluate model

# %%
scores = cross_val_score(pipeline, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)

# %% [markdown]
# ---
# ## Step 7 — summarize performance

# %%
print('Mean ROC AUC: %.3f' % mean(scores))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: combination of SMOTE and random undersampling for imbalanced classification 是机器学习中的常用技术。
#   *combination of SMOTE and random undersampling for imbalanced classification is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Smote Random Undersampling / 欠采样
# Complete Code / 完整代码
# ===============================

# combination of SMOTE and random undersampling for imbalanced classification
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.tree import DecisionTreeClassifier
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
# generate dataset
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0, n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)
# define model
model = DecisionTreeClassifier()
# define pipeline
over = SMOTE(sampling_strategy=0.1)
under = RandomUnderSampler(sampling_strategy=0.5)
steps = [('o', over), ('u', under), ('m', model)]
pipeline = Pipeline(steps=steps)
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(pipeline, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: %.3f' % mean(scores))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 6
