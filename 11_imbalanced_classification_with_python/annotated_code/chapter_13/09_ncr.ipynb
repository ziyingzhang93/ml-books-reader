# %% [markdown]
# # 09 — Ncr / 09 Ncr
#
# **Chapter 13 — File 9 of 9 / 第13章 — 第9个文件（共9个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **undersample and plot imbalanced dataset with the neighborhood cleaning rule**.
#
# 本脚本演示 **undersample and plot imbalanced dataset with the neighborhood cleaning rule**。

# %% [markdown]
# ---
# ## Step 1 — undersample and plot imbalanced dataset with the neighborhood cleaning rule

# %%
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.under_sampling import NeighbourhoodCleaningRule
from matplotlib import pyplot
from numpy import where

# %% [markdown]
# ---
# ## Step 2 — define dataset

# %%
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0, n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)

# %% [markdown]
# ---
# ## Step 3 — summarize class distribution

# %%
counter = Counter(y)
print(counter)

# %% [markdown]
# ---
# ## Step 4 — define the undersampling method

# %%
undersample = NeighbourhoodCleaningRule(n_neighbors=3, threshold_cleaning=0.5)

# %% [markdown]
# ---
# ## Step 5 — transform the dataset

# %%
X, y = undersample.fit_resample(X, y)

# %% [markdown]
# ---
# ## Step 6 — summarize the new class distribution

# %%
counter = Counter(y)
print(counter)

# %% [markdown]
# ---
# ## Step 7 — scatter plot of examples by class label

# %%
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: undersample and plot imbalanced dataset with the neighborhood cleaning rule 是机器学习中的常用技术。
#   *undersample and plot imbalanced dataset with the neighborhood cleaning rule is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Ncr / 09 Ncr
# Complete Code / 完整代码
# ===============================

# undersample and plot imbalanced dataset with the neighborhood cleaning rule
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.under_sampling import NeighbourhoodCleaningRule
from matplotlib import pyplot
from numpy import where
# define dataset
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0, n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)
# summarize class distribution
counter = Counter(y)
print(counter)
# define the undersampling method
undersample = NeighbourhoodCleaningRule(n_neighbors=3, threshold_cleaning=0.5)
# transform the dataset
X, y = undersample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
