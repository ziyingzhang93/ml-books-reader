# %% [markdown]
# # 08 — Adasyn / 08 Adasyn
#
# **Chapter 12 — File 8 of 8 / 第12章 — 第8个文件（共8个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Oversample and plot imbalanced dataset with ADASYN**.
#
# 本脚本演示 **Oversample and plot imbalanced dataset with ADASYN**。

# %% [markdown]
# ---
# ## Step 1 — Oversample and plot imbalanced dataset with ADASYN

# %%
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import ADASYN
from matplotlib import pyplot
from numpy import where

# %% [markdown]
# ---
# ## Step 2 — define dataset

# %%
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0, n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)

# %% [markdown]
# ---
# ## Step 3 — summarize class distribution

# %%
counter = Counter(y)
print(counter)

# %% [markdown]
# ---
# ## Step 4 — transform the dataset

# %%
oversample = ADASYN()
X, y = oversample.fit_resample(X, y)

# %% [markdown]
# ---
# ## Step 5 — summarize the new class distribution

# %%
counter = Counter(y)
print(counter)

# %% [markdown]
# ---
# ## Step 6 — scatter plot of examples by class label

# %%
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Oversample and plot imbalanced dataset with ADASYN 是机器学习中的常用技术。
#   *Oversample and plot imbalanced dataset with ADASYN is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Adasyn / 08 Adasyn
# Complete Code / 完整代码
# ===============================

# Oversample and plot imbalanced dataset with ADASYN
from collections import Counter
from sklearn.datasets import make_classification
from imblearn.over_sampling import ADASYN
from matplotlib import pyplot
from numpy import where
# define dataset
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0, n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=1)
# summarize class distribution
counter = Counter(y)
print(counter)
# transform the dataset
oversample = ADASYN()
X, y = oversample.fit_resample(X, y)
# summarize the new class distribution
counter = Counter(y)
print(counter)
# scatter plot of examples by class label
for label, _ in counter.items():
	row_ix = where(y == label)[0]
	pyplot.scatter(X[row_ix, 0], X[row_ix, 1], label=str(label))
pyplot.legend()
pyplot.show()
