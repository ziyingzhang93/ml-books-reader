# %% [markdown]
# # 05 — Evaluate Models / 模型评估
#
# **Chapter 30 — File 5 of 7 / 第30章 — 第5个文件（共7个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **spot check machine learning algorithms on the phoneme dataset**.
#
# 本脚本演示 **spot check machine learning algorithms on the phoneme dataset**。

# %% [markdown]
# ---
# ## Step 1 — spot check machine learning algorithms on the phoneme dataset

# %%
from numpy import mean
from numpy import std
from pandas import read_csv
from matplotlib import pyplot
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from imblearn.metrics import geometric_mean_score
from sklearn.metrics import make_scorer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier

# %% [markdown]
# ---
# ## Step 2 — load the dataset

# %%
def load_dataset(full_path):

# %% [markdown]
# ---
# ## Step 3 — load the dataset as a numpy array

# %%
data = read_csv(full_path, header=None)

# %% [markdown]
# ---
# ## Step 4 — retrieve numpy array

# %%
data = data.values

# %% [markdown]
# ---
# ## Step 5 — split into input and output elements

# %%
X, y = data[:, :-1], data[:, -1]
	return X, y

# %% [markdown]
# ---
# ## Step 6 — evaluate a model

# %%
def evaluate_model(X, y, model):

# %% [markdown]
# ---
# ## Step 7 — define evaluation procedure

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ---
# ## Step 8 — define the model evaluation metric

# %%
metric = make_scorer(geometric_mean_score)

# %% [markdown]
# ---
# ## Step 9 — evaluate model

# %%
scores = cross_val_score(model, X, y, scoring=metric, cv=cv, n_jobs=-1)
	return scores

# %% [markdown]
# ---
# ## Step 10 — define models to test

# %%
def get_models():
	models, names = list(), list()

# %% [markdown]
# ---
# ## Step 11 — LR

# %%
models.append(LogisticRegression(solver='lbfgs'))
	names.append('LR')

# %% [markdown]
# ---
# ## Step 12 — SVM

# %%
models.append(SVC(gamma='scale'))
	names.append('SVM')

# %% [markdown]
# ---
# ## Step 13 — Bagging

# %%
models.append(BaggingClassifier(n_estimators=1000))
	names.append('BAG')

# %% [markdown]
# ---
# ## Step 14 — RF

# %%
models.append(RandomForestClassifier(n_estimators=1000))
	names.append('RF')

# %% [markdown]
# ---
# ## Step 15 — ET

# %%
models.append(ExtraTreesClassifier(n_estimators=1000))
	names.append('ET')
	return models, names

# %% [markdown]
# ---
# ## Step 16 — define the location of the dataset

# %%
full_path = 'phoneme.csv'

# %% [markdown]
# ---
# ## Step 17 — load the dataset

# %%
X, y = load_dataset(full_path)

# %% [markdown]
# ---
# ## Step 18 — define models

# %%
models, names = get_models()
results = list()

# %% [markdown]
# ---
# ## Step 19 — evaluate each model

# %%
for i in range(len(models)):

# %% [markdown]
# ---
# ## Step 20 — evaluate the model and store results

# %%
scores = evaluate_model(X, y, models[i])
	results.append(scores)

# %% [markdown]
# ---
# ## Step 21 — summarize and store

# %%
print('>%s %.3f (%.3f)' % (names[i], mean(scores), std(scores)))

# %% [markdown]
# ---
# ## Step 22 — plot the results

# %%
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: spot check machine learning algorithms on the phoneme dataset 是机器学习中的常用技术。
#   *spot check machine learning algorithms on the phoneme dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Evaluate Models / 模型评估
# Complete Code / 完整代码
# ===============================

# spot check machine learning algorithms on the phoneme dataset
from numpy import mean
from numpy import std
from pandas import read_csv
from matplotlib import pyplot
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from imblearn.metrics import geometric_mean_score
from sklearn.metrics import make_scorer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import BaggingClassifier

# load the dataset
def load_dataset(full_path):
	# load the dataset as a numpy array
	data = read_csv(full_path, header=None)
	# retrieve numpy array
	data = data.values
	# split into input and output elements
	X, y = data[:, :-1], data[:, -1]
	return X, y

# evaluate a model
def evaluate_model(X, y, model):
	# define evaluation procedure
	cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
	# define the model evaluation metric
	metric = make_scorer(geometric_mean_score)
	# evaluate model
	scores = cross_val_score(model, X, y, scoring=metric, cv=cv, n_jobs=-1)
	return scores

# define models to test
def get_models():
	models, names = list(), list()
	# LR
	models.append(LogisticRegression(solver='lbfgs'))
	names.append('LR')
	# SVM
	models.append(SVC(gamma='scale'))
	names.append('SVM')
	# Bagging
	models.append(BaggingClassifier(n_estimators=1000))
	names.append('BAG')
	# RF
	models.append(RandomForestClassifier(n_estimators=1000))
	names.append('RF')
	# ET
	models.append(ExtraTreesClassifier(n_estimators=1000))
	names.append('ET')
	return models, names

# define the location of the dataset
full_path = 'phoneme.csv'
# load the dataset
X, y = load_dataset(full_path)
# define models
models, names = get_models()
results = list()
# evaluate each model
for i in range(len(models)):
	# evaluate the model and store results
	scores = evaluate_model(X, y, models[i])
	results.append(scores)
	# summarize and store
	print('>%s %.3f (%.3f)' % (names[i], mean(scores), std(scores)))
# plot the results
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 6 of 7
