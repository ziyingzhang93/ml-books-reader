# %% [markdown]
# # 06 — Data Sampling Models / 06 Data Sampling Models
#
# **Chapter 30 — File 6 of 7 / 第30章 — 第6个文件（共7个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **data oversampling algorithms on the phoneme imbalanced dataset**.
#
# 本脚本演示 **data oversampling algorithms on the phoneme imbalanced dataset**。

# %% [markdown]
# ---
# ## Step 1 — data oversampling algorithms on the phoneme imbalanced dataset

# %%
from numpy import mean
from numpy import std
from pandas import read_csv
from matplotlib import pyplot
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from imblearn.metrics import geometric_mean_score
from sklearn.metrics import make_scorer
from sklearn.ensemble import ExtraTreesClassifier
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import SVMSMOTE
from imblearn.over_sampling import ADASYN
from imblearn.pipeline import Pipeline

# %% [markdown]
# ---
# ## Step 2 — load the dataset

# %%
def load_dataset(full_path):

# %% [markdown]
# ---
# ## Step 3 — load the dataset as a numpy array

# %%
data = read_csv(full_path, header=None)

# %% [markdown]
# ---
# ## Step 4 — retrieve numpy array

# %%
data = data.values

# %% [markdown]
# ---
# ## Step 5 — split into input and output elements

# %%
X, y = data[:, :-1], data[:, -1]
	return X, y

# %% [markdown]
# ---
# ## Step 6 — evaluate a model

# %%
def evaluate_model(X, y, model):

# %% [markdown]
# ---
# ## Step 7 — define evaluation procedure

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ---
# ## Step 8 — define the model evaluation metric

# %%
metric = make_scorer(geometric_mean_score)

# %% [markdown]
# ---
# ## Step 9 — evaluate model

# %%
scores = cross_val_score(model, X, y, scoring=metric, cv=cv, n_jobs=-1)
	return scores

# %% [markdown]
# ---
# ## Step 10 — define oversampling models to test

# %%
def get_models():
	models, names = list(), list()

# %% [markdown]
# ---
# ## Step 11 — RandomOverSampler

# %%
models.append(RandomOverSampler())
	names.append('ROS')

# %% [markdown]
# ---
# ## Step 12 — SMOTE

# %%
models.append(SMOTE())
	names.append('SMOTE')

# %% [markdown]
# ---
# ## Step 13 — BorderlineSMOTE

# %%
models.append(BorderlineSMOTE())
	names.append('BLSMOTE')

# %% [markdown]
# ---
# ## Step 14 — SVMSMOTE

# %%
models.append(SVMSMOTE())
	names.append('SVMSMOTE')

# %% [markdown]
# ---
# ## Step 15 — ADASYN

# %%
models.append(ADASYN())
	names.append('ADASYN')
	return models, names

# %% [markdown]
# ---
# ## Step 16 — define the location of the dataset

# %%
full_path = 'phoneme.csv'

# %% [markdown]
# ---
# ## Step 17 — load the dataset

# %%
X, y = load_dataset(full_path)

# %% [markdown]
# ---
# ## Step 18 — define models

# %%
models, names = get_models()
results = list()

# %% [markdown]
# ---
# ## Step 19 — evaluate each model

# %%
for i in range(len(models)):

# %% [markdown]
# ---
# ## Step 20 — define the model

# %%
model = ExtraTreesClassifier(n_estimators=1000)

# %% [markdown]
# ---
# ## Step 21 — define the pipeline steps

# %%
steps = [('s', MinMaxScaler()), ('o', models[i]), ('m', model)]

# %% [markdown]
# ---
# ## Step 22 — define the pipeline

# %%
pipeline = Pipeline(steps=steps)

# %% [markdown]
# ---
# ## Step 23 — evaluate the model and store results

# %%
scores = evaluate_model(X, y, pipeline)
	results.append(scores)

# %% [markdown]
# ---
# ## Step 24 — summarize and store

# %%
print('>%s %.3f (%.3f)' % (names[i], mean(scores), std(scores)))

# %% [markdown]
# ---
# ## Step 25 — plot the results

# %%
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: data oversampling algorithms on the phoneme imbalanced dataset 是机器学习中的常用技术。
#   *data oversampling algorithms on the phoneme imbalanced dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Data Sampling Models / 06 Data Sampling Models
# Complete Code / 完整代码
# ===============================

# data oversampling algorithms on the phoneme imbalanced dataset
from numpy import mean
from numpy import std
from pandas import read_csv
from matplotlib import pyplot
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from imblearn.metrics import geometric_mean_score
from sklearn.metrics import make_scorer
from sklearn.ensemble import ExtraTreesClassifier
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import BorderlineSMOTE
from imblearn.over_sampling import SVMSMOTE
from imblearn.over_sampling import ADASYN
from imblearn.pipeline import Pipeline

# load the dataset
def load_dataset(full_path):
	# load the dataset as a numpy array
	data = read_csv(full_path, header=None)
	# retrieve numpy array
	data = data.values
	# split into input and output elements
	X, y = data[:, :-1], data[:, -1]
	return X, y

# evaluate a model
def evaluate_model(X, y, model):
	# define evaluation procedure
	cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
	# define the model evaluation metric
	metric = make_scorer(geometric_mean_score)
	# evaluate model
	scores = cross_val_score(model, X, y, scoring=metric, cv=cv, n_jobs=-1)
	return scores

# define oversampling models to test
def get_models():
	models, names = list(), list()
	# RandomOverSampler
	models.append(RandomOverSampler())
	names.append('ROS')
	# SMOTE
	models.append(SMOTE())
	names.append('SMOTE')
	# BorderlineSMOTE
	models.append(BorderlineSMOTE())
	names.append('BLSMOTE')
	# SVMSMOTE
	models.append(SVMSMOTE())
	names.append('SVMSMOTE')
	# ADASYN
	models.append(ADASYN())
	names.append('ADASYN')
	return models, names

# define the location of the dataset
full_path = 'phoneme.csv'
# load the dataset
X, y = load_dataset(full_path)
# define models
models, names = get_models()
results = list()
# evaluate each model
for i in range(len(models)):
	# define the model
	model = ExtraTreesClassifier(n_estimators=1000)
	# define the pipeline steps
	steps = [('s', MinMaxScaler()), ('o', models[i]), ('m', model)]
	# define the pipeline
	pipeline = Pipeline(steps=steps)
	# evaluate the model and store results
	scores = evaluate_model(X, y, pipeline)
	results.append(scores)
	# summarize and store
	print('>%s %.3f (%.3f)' % (names[i], mean(scores), std(scores)))
# plot the results
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 7 of 7
