# %% [markdown]
# # Chapter 21 Summary / 第21章总结
#
# ## Theme / 主题: Chapter 21 / Chapter 21
#
# This chapter contains **7 code files** demonstrating chapter 21.
#
# 本章包含 **7 个代码文件**，演示Chapter 21。

# %% [markdown]
# ---
# ## Evolution / 演化路线
#
#   1. `01_roc_curve.ipynb` — Roc Curve
#   2. `02_roc_optimal_threshold.ipynb` — Roc Optimal Threshold
#   3. `03_roc_optimal_threshold_j_stat.ipynb` — Roc Optimal Threshold J Stat
#   4. `04_pr_curve.ipynb` — Pr Curve
#   5. `05_pr_optimal_threshold.ipynb` — Pr Optimal Threshold
#   6. `06_logistic_f1.ipynb` — Logistic F1
#   7. `07_grid_search.ipynb` — Grid Search

# %% [markdown]
# ---
# ## ML Relevance / ML 关联
#
# The techniques in this chapter (Chapter 21) are fundamental building blocks in machine learning pipelines.
#
# 本章技术（Chapter 21）是机器学习流水线中的基础构建块。
