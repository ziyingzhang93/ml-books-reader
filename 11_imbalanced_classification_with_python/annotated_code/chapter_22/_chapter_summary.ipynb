# %% [markdown]
# # Chapter 22 Summary / 第22章总结
#
# ## Theme / 主题: Chapter 22 / Chapter 22
#
# This chapter contains **7 code files** demonstrating chapter 22.
#
# 本章包含 **7 个代码文件**，演示Chapter 22。

# %% [markdown]
# ---
# ## Evolution / 演化路线
#
#   1. `01_svm_uncalibrated.ipynb` — Svm Uncalibrated
#   2. `02_svm_calibrated.ipynb` — Svm Calibrated
#   3. `03_svm_balanced_calibrated.ipynb` — Svm Balanced Calibrated
#   4. `04_decision_tree_uncalibrated.ipynb` — Decision Tree Uncalibrated
#   5. `05_decision_tree_calibrated.ipynb` — Decision Tree Calibrated
#   6. `06_knn_uncalibrated.ipynb` — Knn Uncalibrated
#   7. `07_knn_grid_search.ipynb` — Knn Grid Search

# %% [markdown]
# ---
# ## ML Relevance / ML 关联
#
# The techniques in this chapter (Chapter 22) are fundamental building blocks in machine learning pipelines.
#
# 本章技术（Chapter 22）是机器学习流水线中的基础构建块。
