# %% [markdown]
# # 05 — Decision Tree Calibrated / 决策树
#
# **Chapter 22 — File 5 of 7 / 第22章 — 第5个文件（共7个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **decision tree with calibrated probabilities for imbalanced classification**.
#
# 本脚本演示 **decision tree with calibrated probabilities for imbalanced classification**。

# %% [markdown]
# ---
# ## Step 1 — decision tree with calibrated probabilities for imbalanced classification

# %%
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.calibration import CalibratedClassifierCV
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ---
# ## Step 2 — generate dataset

# %%
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0, n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=4)

# %% [markdown]
# ---
# ## Step 3 — define model

# %%
model = DecisionTreeClassifier()

# %% [markdown]
# ---
# ## Step 4 — wrap the model

# %%
calibrated = CalibratedClassifierCV(model, method='sigmoid', cv=3)

# %% [markdown]
# ---
# ## Step 5 — define evaluation procedure

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ---
# ## Step 6 — evaluate model

# %%
scores = cross_val_score(calibrated, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)

# %% [markdown]
# ---
# ## Step 7 — summarize performance

# %%
print('Mean ROC AUC: %.3f' % mean(scores))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: decision tree with calibrated probabilities for imbalanced classification 是机器学习中的常用技术。
#   *decision tree with calibrated probabilities for imbalanced classification is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Decision Tree Calibrated / 决策树
# Complete Code / 完整代码
# ===============================

# decision tree with calibrated probabilities for imbalanced classification
from numpy import mean
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.calibration import CalibratedClassifierCV
from sklearn.tree import DecisionTreeClassifier
# generate dataset
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0, n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=4)
# define model
model = DecisionTreeClassifier()
# wrap the model
calibrated = CalibratedClassifierCV(model, method='sigmoid', cv=3)
# define evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate model
scores = cross_val_score(calibrated, X, y, scoring='roc_auc', cv=cv, n_jobs=-1)
# summarize performance
print('Mean ROC AUC: %.3f' % mean(scores))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 6 of 7
