# %% [markdown]
# # 01 — Dataset / 01 Dataset
#
# **Chapter 09 — File 1 of 5 / 第09章 — 第1个文件（共5个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **create a binary classification dataset**.
#
# 本脚本演示 **create a binary classification dataset**。

# %% [markdown]
# ---
# ## Step 1 — create a binary classification dataset

# %%
from numpy import unique
from sklearn.datasets import make_classification

# %% [markdown]
# ---
# ## Step 2 — generate 2 class dataset

# %%
X, y = make_classification(n_samples=1000, n_classes=2, weights=[0.99, 0.01], flip_y=0, random_state=1)

# %% [markdown]
# ---
# ## Step 3 — summarize dataset

# %%
classes = unique(y)
total = len(y)
for c in classes:
	n_examples = len(y[y==c])
	percent = n_examples / total * 100
	print('> Class=%d : %d/%d (%.1f%%)' % (c, n_examples, total, percent))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: create a binary classification dataset 是机器学习中的常用技术。
#   *create a binary classification dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Dataset / 01 Dataset
# Complete Code / 完整代码
# ===============================

# create a binary classification dataset
from numpy import unique
from sklearn.datasets import make_classification
# generate 2 class dataset
X, y = make_classification(n_samples=1000, n_classes=2, weights=[0.99, 0.01], flip_y=0, random_state=1)
# summarize dataset
classes = unique(y)
total = len(y)
for c in classes:
	n_examples = len(y[y==c])
	percent = n_examples / total * 100
	print('> Class=%d : %d/%d (%.1f%%)' % (c, n_examples, total, percent))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 5
