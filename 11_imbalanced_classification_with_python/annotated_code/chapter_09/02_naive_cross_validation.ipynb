# %% [markdown]
# # 02 — Naive Cross Validation / 交叉验证
#
# **Chapter 09 — File 2 of 5 / 第09章 — 第2个文件（共5个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of k-fold cross-validation with an imbalanced dataset**.
#
# 本脚本演示 **example of k-fold cross-validation with an imbalanced dataset**。

# %% [markdown]
# ---
# ## Step 1 — example of k-fold cross-validation with an imbalanced dataset

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold

# %% [markdown]
# ---
# ## Step 2 — generate 2 class dataset

# %%
X, y = make_classification(n_samples=1000, n_classes=2, weights=[0.99, 0.01], flip_y=0, random_state=1)
kfold = KFold(n_splits=5, shuffle=True, random_state=1)

# %% [markdown]
# ---
# ## Step 3 — enumerate the splits and summarize the distributions

# %%
for train_ix, test_ix in kfold.split(X):

# %% [markdown]
# ---
# ## Step 4 — select rows

# %%
train_X, test_X = X[train_ix], X[test_ix]
	train_y, test_y = y[train_ix], y[test_ix]

# %% [markdown]
# ---
# ## Step 5 — summarize train and test composition

# %%
train_0, train_1 = len(train_y[train_y==0]), len(train_y[train_y==1])
	test_0, test_1 = len(test_y[test_y==0]), len(test_y[test_y==1])
	print('>Train: 0=%d, 1=%d, Test: 0=%d, 1=%d' % (train_0, train_1, test_0, test_1))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of k-fold cross-validation with an imbalanced dataset 是机器学习中的常用技术。
#   *example of k-fold cross-validation with an imbalanced dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Naive Cross Validation / 交叉验证
# Complete Code / 完整代码
# ===============================

# example of k-fold cross-validation with an imbalanced dataset
from sklearn.datasets import make_classification
from sklearn.model_selection import KFold
# generate 2 class dataset
X, y = make_classification(n_samples=1000, n_classes=2, weights=[0.99, 0.01], flip_y=0, random_state=1)
kfold = KFold(n_splits=5, shuffle=True, random_state=1)
# enumerate the splits and summarize the distributions
for train_ix, test_ix in kfold.split(X):
	# select rows
	train_X, test_X = X[train_ix], X[test_ix]
	train_y, test_y = y[train_ix], y[test_ix]
	# summarize train and test composition
	train_0, train_1 = len(train_y[train_y==0]), len(train_y[train_y==1])
	test_0, test_1 = len(test_y[test_y==0]), len(test_y[test_y==1])
	print('>Train: 0=%d, 1=%d, Test: 0=%d, 1=%d' % (train_0, train_1, test_0, test_1))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 5
