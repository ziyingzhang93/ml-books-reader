# %% [markdown]
# # 04 — Balanced / 04 Balanced
#
# **Chapter 16 — File 4 of 6 / 第16章 — 第4个文件（共6个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **calculate heuristic class weighting**.
#
# 本脚本演示 **calculate heuristic class weighting**。

# %% [markdown]
# ---
# ## Step 1 — calculate heuristic class weighting

# %%
from sklearn.utils.class_weight import compute_class_weight
from sklearn.datasets import make_classification

# %% [markdown]
# ---
# ## Step 2 — generate 2 class dataset

# %%
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0, n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=2)

# %% [markdown]
# ---
# ## Step 3 — calculate class weighting

# %%
weighting = compute_class_weight('balanced', [0,1], y)
print(weighting)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: calculate heuristic class weighting 是机器学习中的常用技术。
#   *calculate heuristic class weighting is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Balanced / 04 Balanced
# Complete Code / 完整代码
# ===============================

# calculate heuristic class weighting
from sklearn.utils.class_weight import compute_class_weight
from sklearn.datasets import make_classification
# generate 2 class dataset
X, y = make_classification(n_samples=10000, n_features=2, n_redundant=0, n_clusters_per_class=1, weights=[0.99], flip_y=0, random_state=2)
# calculate class weighting
weighting = compute_class_weight('balanced', [0,1], y)
print(weighting)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 6
