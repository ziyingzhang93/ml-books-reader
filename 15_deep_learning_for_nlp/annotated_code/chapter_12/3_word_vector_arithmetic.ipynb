# %% [markdown]
# # 3 — Word Vector Arithmetic / 3 Word Vector Arithmetic
#
# **Chapter 12 — File 3 of 4 / 第12章 — 第3个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **load the google word2vec model**.
#
# 本脚本演示 **load the google word2vec model**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
from gensim.models import KeyedVectors

# %% [markdown]
# ---
# ## Step 2 — load the google word2vec model

# %%
filename = 'GoogleNews-vectors-negative300.bin'
model = KeyedVectors.load_word2vec_format(filename, binary=True)

# %% [markdown]
# ---
# ## Step 3 — calculate: (king - man) + woman = ?

# %%
result = model.most_similar(positive=['woman', 'king'], negative=['man'], topn=1)
print(result)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: load the google word2vec model 是机器学习中的常用技术。
#   *load the google word2vec model is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Word Vector Arithmetic / 3 Word Vector Arithmetic
# Complete Code / 完整代码
# ===============================

from gensim.models import KeyedVectors
# load the google word2vec model
filename = 'GoogleNews-vectors-negative300.bin'
model = KeyedVectors.load_word2vec_format(filename, binary=True)
# calculate: (king - man) + woman = ?
result = model.most_similar(positive=['woman', 'king'], negative=['man'], topn=1)
print(result)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 4
