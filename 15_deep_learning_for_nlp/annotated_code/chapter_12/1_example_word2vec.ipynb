# %% [markdown]
# # 1 — Example Word2Vec / 1 Example Word2Vec
#
# **Chapter 12 — File 1 of 4 / 第12章 — 第1个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **define training data**.
#
# 本脚本演示 **define training data**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
from gensim.models import Word2Vec

# %% [markdown]
# ---
# ## Step 2 — define training data

# %%
sentences = [['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec'],
			['this', 'is', 'the', 'second', 'sentence'],
			['yet', 'another', 'sentence'],
			['one', 'more', 'sentence'],
			['and', 'the', 'final', 'sentence']]

# %% [markdown]
# ---
# ## Step 3 — train model

# %%
model = Word2Vec(sentences, min_count=1)

# %% [markdown]
# ---
# ## Step 4 — summarize the loaded model

# %%
print(model)

# %% [markdown]
# ---
# ## Step 5 — summarize vocabulary

# %%
words = list(model.wv.vocab)
print(words)

# %% [markdown]
# ---
# ## Step 6 — access vector for one word

# %%
print(model['sentence'])

# %% [markdown]
# ---
# ## Step 7 — save model

# %%
model.save('model.bin')

# %% [markdown]
# ---
# ## Step 8 — load model

# %%
new_model = Word2Vec.load('model.bin')
print(new_model)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: define training data 是机器学习中的常用技术。
#   *define training data is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Example Word2Vec / 1 Example Word2Vec
# Complete Code / 完整代码
# ===============================

from gensim.models import Word2Vec
# define training data
sentences = [['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec'],
			['this', 'is', 'the', 'second', 'sentence'],
			['yet', 'another', 'sentence'],
			['one', 'more', 'sentence'],
			['and', 'the', 'final', 'sentence']]
# train model
model = Word2Vec(sentences, min_count=1)
# summarize the loaded model
print(model)
# summarize vocabulary
words = list(model.wv.vocab)
print(words)
# access vector for one word
print(model['sentence'])
# save model
model.save('model.bin')
# load model
new_model = Word2Vec.load('model.bin')
print(new_model)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 4
