# %% [markdown]
# # 2 — Plot Model / 2 Plot Model
#
# **Chapter 12 — File 2 of 4 / 第12章 — 第2个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **define training data**.
#
# 本脚本演示 **define training data**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — define training data

# %%
sentences = [['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec'],
			['this', 'is', 'the', 'second', 'sentence'],
			['yet', 'another', 'sentence'],
			['one', 'more', 'sentence'],
			['and', 'the', 'final', 'sentence']]

# %% [markdown]
# ---
# ## Step 3 — train model

# %%
model = Word2Vec(sentences, min_count=1)

# %% [markdown]
# ---
# ## Step 4 — fit a 2d PCA model to the vectors

# %%
X = model[model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)

# %% [markdown]
# ---
# ## Step 5 — create a scatter plot of the projection

# %%
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
for i, word in enumerate(words):
	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: define training data 是机器学习中的常用技术。
#   *define training data is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Plot Model / 2 Plot Model
# Complete Code / 完整代码
# ===============================

from gensim.models import Word2Vec
from sklearn.decomposition import PCA
from matplotlib import pyplot
# define training data
sentences = [['this', 'is', 'the', 'first', 'sentence', 'for', 'word2vec'],
			['this', 'is', 'the', 'second', 'sentence'],
			['yet', 'another', 'sentence'],
			['one', 'more', 'sentence'],
			['and', 'the', 'final', 'sentence']]
# train model
model = Word2Vec(sentences, min_count=1)
# fit a 2d PCA model to the vectors
X = model[model.wv.vocab]
pca = PCA(n_components=2)
result = pca.fit_transform(X)
# create a scatter plot of the projection
pyplot.scatter(result[:, 0], result[:, 1])
words = list(model.wv.vocab)
for i, word in enumerate(words):
	pyplot.annotate(word, xy=(result[i, 0], result[i, 1]))
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 4
