# %% [markdown]
# # 04 — Load And Split / 04 Load And Split
#
# **Chapter 09 — File 4 of 10 / 第09章 — 第4个文件（共10个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **load doc into memory**.
#
# 本脚本演示 **load doc into memory**。

# %% [markdown]
# ---
# ## Step 1 — load doc into memory

# %%
def load_doc(filename):

# %% [markdown]
# ---
# ## Step 2 — open the file as read only

# %%
file = open(filename, 'r')

# %% [markdown]
# ---
# ## Step 3 — read all text

# %%
text = file.read()

# %% [markdown]
# ---
# ## Step 4 — close the file

# %%
file.close()
	return text

# %% [markdown]
# ---
# ## Step 5 — load the document

# %%
filename = 'txt_sentoken/neg/cv000_29416.txt'
text = load_doc(filename)

# %% [markdown]
# ---
# ## Step 6 — split into tokens by white space

# %%
tokens = text.split()
print(tokens)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: load doc into memory 是机器学习中的常用技术。
#   *load doc into memory is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Load And Split / 04 Load And Split
# Complete Code / 完整代码
# ===============================

# load doc into memory
def load_doc(filename):
	# open the file as read only
	file = open(filename, 'r')
	# read all text
	text = file.read()
	# close the file
	file.close()
	return text

# load the document
filename = 'txt_sentoken/neg/cv000_29416.txt'
text = load_doc(filename)
# split into tokens by white space
tokens = text.split()
print(tokens)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 10
