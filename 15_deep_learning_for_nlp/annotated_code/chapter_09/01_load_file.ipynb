# %% [markdown]
# # 01 — Load File / 01 Load File
#
# **Chapter 09 — File 1 of 10 / 第09章 — 第1个文件（共10个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **load one file**.
#
# 本脚本演示 **load one file**。

# %% [markdown]
# ---
# ## Step 1 — load one file

# %%
filename = 'txt_sentoken/neg/cv000_29416.txt'

# %% [markdown]
# ---
# ## Step 2 — open the file as read only

# %%
file = open(filename, 'r')

# %% [markdown]
# ---
# ## Step 3 — read all text

# %%
text = file.read()

# %% [markdown]
# ---
# ## Step 4 — close the file

# %%
file.close()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: load one file 是机器学习中的常用技术。
#   *load one file is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Load File / 01 Load File
# Complete Code / 完整代码
# ===============================

# load one file
filename = 'txt_sentoken/neg/cv000_29416.txt'
# open the file as read only
file = open(filename, 'r')
# read all text
text = file.read()
# close the file
file.close()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 10
