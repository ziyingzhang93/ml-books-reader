# %% [markdown]
# # 5 — Example Tokenizer / 分词
#
# **Chapter 07 — File 5 of 5 / 第07章 — 第5个文件（共5个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **define 5 documents**.
#
# 本脚本演示 **define 5 documents**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
from keras.preprocessing.text import Tokenizer

# %% [markdown]
# ---
# ## Step 2 — define 5 documents

# %%
docs = ['Well done!',
		'Good work',
		'Great effort',
		'nice work',
		'Excellent!']

# %% [markdown]
# ---
# ## Step 3 — create the tokenizer

# %%
t = Tokenizer()

# %% [markdown]
# ---
# ## Step 4 — fit the tokenizer on the documents

# %%
t.fit_on_texts(docs)

# %% [markdown]
# ---
# ## Step 5 — summarize what was learned

# %%
print(t.word_counts)
print(t.document_count)
print(t.word_index)
print(t.word_docs)

# %% [markdown]
# ---
# ## Step 6 — integer encode documents

# %%
encoded_docs = t.texts_to_matrix(docs, mode='count')
print(encoded_docs)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: define 5 documents 是机器学习中的常用技术。
#   *define 5 documents is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Example Tokenizer / 分词
# Complete Code / 完整代码
# ===============================

from keras.preprocessing.text import Tokenizer
# define 5 documents
docs = ['Well done!',
		'Good work',
		'Great effort',
		'nice work',
		'Excellent!']
# create the tokenizer
t = Tokenizer()
# fit the tokenizer on the documents
t.fit_on_texts(docs)
# summarize what was learned
print(t.word_counts)
print(t.document_count)
print(t.word_index)
print(t.word_docs)
# integer encode documents
encoded_docs = t.texts_to_matrix(docs, mode='count')
print(encoded_docs)
