# %% [markdown]
# # Chapter 21 Summary / 第21章总结
#
# ## Theme / 主题: Chapter 21 / Chapter 21
#
# This chapter contains **2 code files** demonstrating chapter 21.
#
# 本章包含 **2 个代码文件**，演示Chapter 21。

# %% [markdown]
# ---
# ## Evolution / 演化路线
#
#   1. `01_time_based_decay.ipynb` — Time Based Decay
#   2. `02_drop_based_decay.ipynb` — Drop Based Decay

# %% [markdown]
# ---
# ## ML Relevance / ML 关联
#
# The techniques in this chapter (Chapter 21) are fundamental building blocks in machine learning pipelines.
#
# 本章技术（Chapter 21）是机器学习流水线中的基础构建块。
