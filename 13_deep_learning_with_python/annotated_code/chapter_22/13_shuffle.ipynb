# %% [markdown]
# # 13 — Shuffle / 13 Shuffle
#
# **Chapter 22 — File 5 of 5 / 第22章 — 第5个文件（共5个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Shuffle**.
#
# 本脚本演示 **13 Shuffle**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import tensorflow as tf
import numpy as np

n_dataset = tf.data.Dataset.from_tensor_slices(np.arange(10000))
shuffled = []
for n in n_dataset.shuffle(10).take(20):
    shuffled.append(n.numpy())
print(shuffled)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Shuffle 是机器学习中的常用技术。
#   *Shuffle is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Shuffle / 13 Shuffle
# Complete Code / 完整代码
# ===============================

import tensorflow as tf
import numpy as np

n_dataset = tf.data.Dataset.from_tensor_slices(np.arange(10000))
shuffled = []
for n in n_dataset.shuffle(10).take(20):
    shuffled.append(n.numpy())
print(shuffled)
