# %% [markdown]
# # 01 — Version / 库版本信息
#
# **Chapter 04 — File 1 of 1 / 第04章 — 第1个文件（共1个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Version**.
#
# 本脚本演示 **库版本信息**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import tensorflow
print(tensorflow.__version__)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Version 是机器学习中的常用技术。
#   *Version is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Version / 库版本信息
# Complete Code / 完整代码
# ===============================

import tensorflow
print(tensorflow.__version__)
