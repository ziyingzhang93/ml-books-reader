# %% [markdown]
# # 08 — Regression / 回归
#
# **Chapter 03 — File 5 of 6 / 第03章 — 第5个文件（共6个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Generate random samples between -10 to +10**.
#
# 本脚本演示 **Generate random samples between -10 to +10**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import numpy as np
import tensorflow as tf

N = 20   # number of samples

# %% [markdown]
# ---
# ## Step 2 — Generate random samples between -10 to +10

# %%
polynomial = np.poly1d([1, 2, 3])
X = np.random.uniform(-10, 10, size=(N,1))
Y = polynomial(X)

# %% [markdown]
# ---
# ## Step 3 — Prepare input as an array of shape (N,3)

# %%
XX = np.hstack([X*X, X, np.ones_like(X)])

# %% [markdown]
# ---
# ## Step 4 — Prepare TensorFlow objects

# %%
w = tf.Variable(tf.random.normal((3,1)))  # the 3 coefficients
x = tf.constant(XX, dtype=tf.float32)     # input sample
y = tf.constant(Y, dtype=tf.float32)      # output sample
optimizer = tf.keras.optimizers.Nadam(learning_rate=0.01)
print(w)

# %% [markdown]
# ---
# ## Step 5 — Run optimizer

# %%
for _ in range(1000):
    with tf.GradientTape() as tape:
        y_pred = x @ w
        mse = tf.reduce_sum(tf.square(y - y_pred))
    grad = tape.gradient(mse, w)
    optimizer.apply_gradients([(grad, w)])

print(w)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Generate random samples between -10 to +10 是机器学习中的常用技术。
#   *Generate random samples between -10 to +10 is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Regression / 回归
# Complete Code / 完整代码
# ===============================

import numpy as np
import tensorflow as tf

N = 20   # number of samples

# Generate random samples between -10 to +10
polynomial = np.poly1d([1, 2, 3])
X = np.random.uniform(-10, 10, size=(N,1))
Y = polynomial(X)

# Prepare input as an array of shape (N,3)
XX = np.hstack([X*X, X, np.ones_like(X)])

# Prepare TensorFlow objects
w = tf.Variable(tf.random.normal((3,1)))  # the 3 coefficients
x = tf.constant(XX, dtype=tf.float32)     # input sample
y = tf.constant(Y, dtype=tf.float32)      # output sample
optimizer = tf.keras.optimizers.Nadam(learning_rate=0.01)
print(w)

# Run optimizer
for _ in range(1000):
    with tf.GradientTape() as tape:
        y_pred = x @ w
        mse = tf.reduce_sum(tf.square(y - y_pred))
    grad = tape.gradient(mse, w)
    optimizer.apply_gradients([(grad, w)])

print(w)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 6 of 6
