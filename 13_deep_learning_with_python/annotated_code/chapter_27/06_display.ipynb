# %% [markdown]
# # 06 — Display / 06 Display
#
# **Chapter 27 — File 2 of 5 / 第27章 — 第2个文件（共5个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **use tfds.load() or image_dataset_from_directory() to load images**.
#
# 本脚本演示 **use tfds.load() or image_dataset_from_directory() to load images**。

# %% [markdown]
# ---
# ## Step 1 — Step 1

# %%
import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

# %% [markdown]
# ---
# ## Step 2 — use tfds.load() or image_dataset_from_directory() to load images

# %%
ds, meta = tfds.load('citrus_leaves', with_info=True, split='train', shuffle_files=True)
ds = ds.batch(32)

# %% [markdown]
# ---
# ## Step 3 — Take one batch from dataset and display the images

# %%
fig, ax = plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5,5))

for sample in ds.take(1):
    images, labels = sample["image"], sample["label"]
    for i in range(3):
        for j in range(3):
            ax[i][j].imshow(images[i*3+j].numpy().astype("uint8"))
            ax[i][j].set_title(meta.features['label'].int2str(labels[i*3+j]))
plt.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: use tfds.load() or image_dataset_from_directory() to load images 是机器学习中的常用技术。
#   *use tfds.load() or image_dataset_from_directory() to load images is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Display / 06 Display
# Complete Code / 完整代码
# ===============================

import tensorflow_datasets as tfds
import matplotlib.pyplot as plt

# use tfds.load() or image_dataset_from_directory() to load images
ds, meta = tfds.load('citrus_leaves', with_info=True, split='train', shuffle_files=True)
ds = ds.batch(32)

# Take one batch from dataset and display the images
fig, ax = plt.subplots(3, 3, sharex=True, sharey=True, figsize=(5,5))

for sample in ds.take(1):
    images, labels = sample["image"], sample["label"]
    for i in range(3):
        for j in range(3):
            ax[i][j].imshow(images[i*3+j].numpy().astype("uint8"))
            ax[i][j].set_title(meta.features['label'].int2str(labels[i*3+j]))
plt.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 5
