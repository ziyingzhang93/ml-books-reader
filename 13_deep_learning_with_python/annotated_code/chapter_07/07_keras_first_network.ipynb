# %% [markdown]
# # 07 — Keras First Network / Keras
#
# **Chapter 07 — File 1 of 2 / 第07章 — 第1个文件（共2个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **first neural network with keras tutorial**.
#
# 本脚本演示 **first neural network with keras tutorial**。

# %% [markdown]
# ---
# ## Step 1 — first neural network with keras tutorial

# %%
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# ---
# ## Step 2 — load the dataset

# %%
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')

# %% [markdown]
# ---
# ## Step 3 — split into input (X) and output (y) variables

# %%
X = dataset[:,0:8]
y = dataset[:,8]

# %% [markdown]
# ---
# ## Step 4 — define the keras model

# %%
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ---
# ## Step 5 — compile the keras model

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# ---
# ## Step 6 — fit the keras model on the dataset

# %%
model.fit(X, y, epochs=150, batch_size=10)

# %% [markdown]
# ---
# ## Step 7 — evaluate the keras model

# %%
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: first neural network with keras tutorial 是机器学习中的常用技术。
#   *first neural network with keras tutorial is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Keras First Network / Keras
# Complete Code / 完整代码
# ===============================

# first neural network with keras tutorial
from numpy import loadtxt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
# load the dataset
dataset = loadtxt('pima-indians-diabetes.csv', delimiter=',')
# split into input (X) and output (y) variables
X = dataset[:,0:8]
y = dataset[:,8]
# define the keras model
model = Sequential()
model.add(Dense(12, input_shape=(8,), activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
# compile the keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# fit the keras model on the dataset
model.fit(X, y, epochs=150, batch_size=10)
# evaluate the keras model
_, accuracy = model.evaluate(X, y)
print('Accuracy: %.2f' % (accuracy*100))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 2
