# %% [markdown]
# # 05 — Regression Evaluate / 回归
#
# **Chapter 14 — File 5 of 12 / 第14章 — 第5个文件（共12个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **evaluate bagging ensemble for regression**.
#
# 本脚本演示 **evaluate bagging ensemble for regression**。

# %% [markdown]
# ---
# ## Step 1 — evaluate bagging ensemble for regression

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.ensemble import BaggingRegressor

# %% [markdown]
# ---
# ## Step 2 — define dataset

# %%
X, y = make_regression(n_samples=1000, n_features=20, n_informative=15, noise=0.1, random_state=5)

# %% [markdown]
# ---
# ## Step 3 — define the model

# %%
model = BaggingRegressor()

# %% [markdown]
# ---
# ## Step 4 — define the evaluation procedure

# %%
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ---
# ## Step 5 — evaluate the model and collect the results

# %%
n_scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

# %% [markdown]
# ---
# ## Step 6 — report performance

# %%
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: evaluate bagging ensemble for regression 是机器学习中的常用技术。
#   *evaluate bagging ensemble for regression is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Regression Evaluate / 回归
# Complete Code / 完整代码
# ===============================

# evaluate bagging ensemble for regression
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.ensemble import BaggingRegressor
# define dataset
X, y = make_regression(n_samples=1000, n_features=20, n_informative=15, noise=0.1, random_state=5)
# define the model
model = BaggingRegressor()
# define the evaluation procedure
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate the model and collect the results
n_scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# report performance
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 6 of 12
