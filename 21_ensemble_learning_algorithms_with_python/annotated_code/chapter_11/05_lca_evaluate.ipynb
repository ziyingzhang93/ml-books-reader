# %% [markdown]
# # 05 — Lca Evaluate / 模型评估
#
# **Chapter 11 — File 5 of 9 / 第11章 — 第5个文件（共9个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **evaluate dynamic classifier selection DCS-LA using local class accuracy**.
#
# 本脚本演示 **evaluate dynamic classifier selection DCS-LA using local class accuracy**。

# %% [markdown]
# ---
# ## Step 1 — evaluate dynamic classifier selection DCS-LA using local class accuracy

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from deslib.dcs.lca import LCA

# %% [markdown]
# ---
# ## Step 2 — define dataset

# %%
X, y = make_classification(n_samples=10000, n_features=20, n_informative=15, n_redundant=5, random_state=7)

# %% [markdown]
# ---
# ## Step 3 — define the model

# %%
model = LCA()

# %% [markdown]
# ---
# ## Step 4 — define the evaluation procedure

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ---
# ## Step 5 — evaluate the model

# %%
n_scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)

# %% [markdown]
# ---
# ## Step 6 — report performance

# %%
print('Mean Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: evaluate dynamic classifier selection DCS-LA using local class accuracy 是机器学习中的常用技术。
#   *evaluate dynamic classifier selection DCS-LA using local class accuracy is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Lca Evaluate / 模型评估
# Complete Code / 完整代码
# ===============================

# evaluate dynamic classifier selection DCS-LA using local class accuracy
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from deslib.dcs.lca import LCA
# define dataset
X, y = make_classification(n_samples=10000, n_features=20, n_informative=15, n_redundant=5, random_state=7)
# define the model
model = LCA()
# define the evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate the model
n_scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# report performance
print('Mean Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 6 of 9
