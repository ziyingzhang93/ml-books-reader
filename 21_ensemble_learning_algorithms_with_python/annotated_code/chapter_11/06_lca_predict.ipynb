# %% [markdown]
# # 06 — Lca Predict / 06 Lca Predict
#
# **Chapter 11 — File 6 of 9 / 第11章 — 第6个文件（共9个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **make a prediction with DCS-LA using local class accuracy**.
#
# 本脚本演示 **make a prediction with DCS-LA using local class accuracy**。

# %% [markdown]
# ---
# ## Step 1 — make a prediction with DCS-LA using local class accuracy

# %%
from sklearn.datasets import make_classification
from deslib.dcs.lca import LCA

# %% [markdown]
# ---
# ## Step 2 — define dataset

# %%
X, y = make_classification(n_samples=10000, n_features=20, n_informative=15, n_redundant=5, random_state=7)

# %% [markdown]
# ---
# ## Step 3 — define the model

# %%
model = LCA()

# %% [markdown]
# ---
# ## Step 4 — fit the model on the whole dataset

# %%
model.fit(X, y)

# %% [markdown]
# ---
# ## Step 5 — make a single prediction

# %%
row = [0.2929949, -4.21223056, -1.288332, -2.17849815, -0.64527665, 2.58097719, 0.28422388, -7.1827928, -1.91211104, 2.73729512, 0.81395695, 3.96973717, -2.66939799, 3.34692332, 4.19791821, 0.99990998, -0.30201875, -4.43170633, -2.82646737, 0.44916808]
yhat = model.predict([row])

# %% [markdown]
# ---
# ## Step 6 — summarize the prediction

# %%
print('Predicted Class: %d' % yhat[0])

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: make a prediction with DCS-LA using local class accuracy 是机器学习中的常用技术。
#   *make a prediction with DCS-LA using local class accuracy is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Lca Predict / 06 Lca Predict
# Complete Code / 完整代码
# ===============================

# make a prediction with DCS-LA using local class accuracy
from sklearn.datasets import make_classification
from deslib.dcs.lca import LCA
# define dataset
X, y = make_classification(n_samples=10000, n_features=20, n_informative=15, n_redundant=5, random_state=7)
# define the model
model = LCA()
# fit the model on the whole dataset
model.fit(X, y)
# make a single prediction
row = [0.2929949, -4.21223056, -1.288332, -2.17849815, -0.64527665, 2.58097719, 0.28422388, -7.1827928, -1.91211104, 2.73729512, 0.81395695, 3.96973717, -2.66939799, 3.34692332, 4.19791821, 0.99990998, -0.30201875, -4.43170633, -2.82646737, 0.44916808]
yhat = model.predict([row])
# summarize the prediction
print('Predicted Class: %d' % yhat[0])

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 7 of 9
