# %% [markdown]
# # 06 — Ovo Evaluate / 模型评估
#
# **Chapter 08 — File 6 of 7 / 第08章 — 第6个文件（共7个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **evaluate SVM for multi-class classification using one-vs-one**.
#
# 本脚本演示 **evaluate SVM for multi-class classification using one-vs-one**。

# %% [markdown]
# ---
# ## Step 1 — evaluate SVM for multi-class classification using one-vs-one

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.svm import SVC
from sklearn.multiclass import OneVsOneClassifier

# %% [markdown]
# ---
# ## Step 2 — define dataset

# %%
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, n_classes=3, random_state=1)

# %% [markdown]
# ---
# ## Step 3 — define model

# %%
model = SVC()

# %% [markdown]
# ---
# ## Step 4 — define the one-vs-one strategy

# %%
ovo = OneVsOneClassifier(model)

# %% [markdown]
# ---
# ## Step 5 — define the evaluation procedure

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ---
# ## Step 6 — evaluate the model and collect the scores

# %%
n_scores = cross_val_score(ovo, X, y, scoring='accuracy', cv=cv, n_jobs=-1)

# %% [markdown]
# ---
# ## Step 7 — summarize the performance

# %%
print('Mean Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: evaluate SVM for multi-class classification using one-vs-one 是机器学习中的常用技术。
#   *evaluate SVM for multi-class classification using one-vs-one is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Ovo Evaluate / 模型评估
# Complete Code / 完整代码
# ===============================

# evaluate SVM for multi-class classification using one-vs-one
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.svm import SVC
from sklearn.multiclass import OneVsOneClassifier
# define dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, n_classes=3, random_state=1)
# define model
model = SVC()
# define the one-vs-one strategy
ovo = OneVsOneClassifier(model)
# define the evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate the model and collect the scores
n_scores = cross_val_score(ovo, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# summarize the performance
print('Mean Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 7 of 7
