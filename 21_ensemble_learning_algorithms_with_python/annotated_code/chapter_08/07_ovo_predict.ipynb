# %% [markdown]
# # 07 — Ovo Predict / 07 Ovo Predict
#
# **Chapter 08 — File 7 of 7 / 第08章 — 第7个文件（共7个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **make a prediction with SVM using one-vs-one**.
#
# 本脚本演示 **make a prediction with SVM using one-vs-one**。

# %% [markdown]
# ---
# ## Step 1 — make a prediction with SVM using one-vs-one

# %%
from sklearn.datasets import make_classification
from sklearn.svm import SVC
from sklearn.multiclass import OneVsOneClassifier

# %% [markdown]
# ---
# ## Step 2 — define dataset

# %%
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, n_classes=3, random_state=1)

# %% [markdown]
# ---
# ## Step 3 — define model

# %%
model = SVC()

# %% [markdown]
# ---
# ## Step 4 — define the one-vs-one strategy

# %%
ovo = OneVsOneClassifier(model)

# %% [markdown]
# ---
# ## Step 5 — fit the model on the whole dataset

# %%
ovo.fit(X, y)

# %% [markdown]
# ---
# ## Step 6 — make a single prediction

# %%
row = [1.89149379, -0.39847585, 1.63856893, 0.01647165, 1.51892395, -3.52651223, 1.80998823, 0.58810926, -0.02542177, -0.52835426]
yhat = ovo.predict([row])
print('Predicted Class: %d' % yhat[0])

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: make a prediction with SVM using one-vs-one 是机器学习中的常用技术。
#   *make a prediction with SVM using one-vs-one is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Ovo Predict / 07 Ovo Predict
# Complete Code / 完整代码
# ===============================

# make a prediction with SVM using one-vs-one
from sklearn.datasets import make_classification
from sklearn.svm import SVC
from sklearn.multiclass import OneVsOneClassifier
# define dataset
X, y = make_classification(n_samples=1000, n_features=10, n_informative=5, n_redundant=5, n_classes=3, random_state=1)
# define model
model = SVC()
# define the one-vs-one strategy
ovo = OneVsOneClassifier(model)
# fit the model on the whole dataset
ovo.fit(X, y)
# make a single prediction
row = [1.89149379, -0.39847585, 1.63856893, 0.01647165, 1.51892395, -3.52651223, 1.80998823, 0.58810926, -0.02542177, -0.52835426]
yhat = ovo.predict([row])
print('Predicted Class: %d' % yhat[0])
