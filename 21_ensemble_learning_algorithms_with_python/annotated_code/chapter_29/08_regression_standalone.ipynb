# %% [markdown]
# # 08 — Regression Standalone / 回归
#
# **Chapter 29 — File 8 of 9 / 第29章 — 第8个文件（共9个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **evaluate base models in isolation on the regression dataset**.
#
# 本脚本演示 **evaluate base models in isolation on the regression dataset**。

# %% [markdown]
# ---
# ## Step 1 — evaluate base models in isolation on the regression dataset

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# %% [markdown]
# ---
# ## Step 2 — get the dataset

# %%
def get_dataset():
	X, y = make_regression(n_samples=10000, n_features=20, n_informative=10, noise=0.3, random_state=7)
	return X, y

# %% [markdown]
# ---
# ## Step 3 — get a list of base models

# %%
def get_models():
	models = list()
	models.append(('lr', LinearRegression()))
	models.append(('knn', KNeighborsRegressor()))
	models.append(('cart', DecisionTreeRegressor()))
	models.append(('svm', SVR()))
	return models

# %% [markdown]
# ---
# ## Step 4 — define dataset

# %%
X, y = get_dataset()

# %% [markdown]
# ---
# ## Step 5 — split dataset into train and test sets

# %%
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.5, random_state=1)

# %% [markdown]
# ---
# ## Step 6 — summarize data split

# %%
print('Train: %s, Test: %s' % (X_train_full.shape, X_test.shape))

# %% [markdown]
# ---
# ## Step 7 — create the base models

# %%
models = get_models()

# %% [markdown]
# ---
# ## Step 8 — evaluate standalone model

# %%
for name, model in models:

# %% [markdown]
# ---
# ## Step 9 — fit the model on the training dataset

# %%
model.fit(X_train_full, y_train_full)

# %% [markdown]
# ---
# ## Step 10 — make a prediction on the test dataset

# %%
yhat = model.predict(X_test)

# %% [markdown]
# ---
# ## Step 11 — evaluate the predictions

# %%
score = mean_absolute_error(y_test, yhat)

# %% [markdown]
# ---
# ## Step 12 — report the score

# %%
print('>%s MAE: %.3f' % (name, score))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: evaluate base models in isolation on the regression dataset 是机器学习中的常用技术。
#   *evaluate base models in isolation on the regression dataset is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Regression Standalone / 回归
# Complete Code / 完整代码
# ===============================

# evaluate base models in isolation on the regression dataset
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR

# get the dataset
def get_dataset():
	X, y = make_regression(n_samples=10000, n_features=20, n_informative=10, noise=0.3, random_state=7)
	return X, y

# get a list of base models
def get_models():
	models = list()
	models.append(('lr', LinearRegression()))
	models.append(('knn', KNeighborsRegressor()))
	models.append(('cart', DecisionTreeRegressor()))
	models.append(('svm', SVR()))
	return models

# define dataset
X, y = get_dataset()
# split dataset into train and test sets
X_train_full, X_test, y_train_full, y_test = train_test_split(X, y, test_size=0.5, random_state=1)
# summarize data split
print('Train: %s, Test: %s' % (X_train_full.shape, X_test.shape))
# create the base models
models = get_models()
# evaluate standalone model
for name, model in models:
	# fit the model on the training dataset
	model.fit(X_train_full, y_train_full)
	# make a prediction on the test dataset
	yhat = model.predict(X_test)
	# evaluate the predictions
	score = mean_absolute_error(y_test, yhat)
	# report the score
	print('>%s MAE: %.3f' % (name, score))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 9 of 9
