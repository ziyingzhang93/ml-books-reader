# %% [markdown]
# # 01 — Version / 库版本信息
#
# **Chapter 23 — File 1 of 12 / 第23章 — 第1个文件（共12个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **check xgboost library version**.
#
# 本脚本演示 **check xgboost library version**。

# %% [markdown]
# ---
# ## Step 1 — check xgboost library version

# %%
import xgboost
print(xgboost.__version__)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: check xgboost library version 是机器学习中的常用技术。
#   *check xgboost library version is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Version / 库版本信息
# Complete Code / 完整代码
# ===============================

# check xgboost library version
import xgboost
print(xgboost.__version__)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 12
