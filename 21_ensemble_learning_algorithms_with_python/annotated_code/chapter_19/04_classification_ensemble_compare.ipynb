# %% [markdown]
# # 04 — Classification Ensemble Compare / 分类
#
# **Chapter 19 — File 4 of 7 / 第19章 — 第4个文件（共7个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **comparison of data transform ensemble to each contributing member for classification**.
#
# 本脚本演示 **comparison of data transform ensemble to each contributing member for classification**。

# %% [markdown]
# ---
# ## Step 1 — comparison of data transform ensemble to each contributing member for classification

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — get a voting ensemble of models

# %%
def get_ensemble():

# %% [markdown]
# ---
# ## Step 3 — define the base models

# %%
models = list()

# %% [markdown]
# ---
# ## Step 4 — normalization

# %%
norm = Pipeline([('s', MinMaxScaler()), ('m', DecisionTreeClassifier())])
	models.append(('norm', norm))

# %% [markdown]
# ---
# ## Step 5 — standardization

# %%
st = Pipeline([('s', StandardScaler()), ('m', DecisionTreeClassifier())])
	models.append(('std', st))

# %% [markdown]
# ---
# ## Step 6 — robust

# %%
robust = Pipeline([('s', RobustScaler()), ('m', DecisionTreeClassifier())])
	models.append(('robust', robust))

# %% [markdown]
# ---
# ## Step 7 — power

# %%
power = Pipeline([('s', PowerTransformer()), ('m', DecisionTreeClassifier())])
	models.append(('power', power))

# %% [markdown]
# ---
# ## Step 8 — quantile

# %%
quant = Pipeline([('s', QuantileTransformer(n_quantiles=100, output_distribution='normal')), ('m', DecisionTreeClassifier())])
	models.append(('quant', quant))

# %% [markdown]
# ---
# ## Step 9 — kbins

# %%
kbins = Pipeline([('s', KBinsDiscretizer(n_bins=20, encode='ordinal')), ('m', DecisionTreeClassifier())])
	models.append(('kbins', kbins))

# %% [markdown]
# ---
# ## Step 10 — define the voting ensemble

# %%
ensemble = VotingClassifier(estimators=models, voting='hard')

# %% [markdown]
# ---
# ## Step 11 — return a list of tuples each with a name and model

# %%
return models + [('ensemble', ensemble)]

# %% [markdown]
# ---
# ## Step 12 — define dataset

# %%
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=1)

# %% [markdown]
# ---
# ## Step 13 — get models

# %%
models = get_ensemble()

# %% [markdown]
# ---
# ## Step 14 — evaluate each model

# %%
results = list()
for name, model in models:

# %% [markdown]
# ---
# ## Step 15 — define the evaluation method

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ---
# ## Step 16 — evaluate the model on the dataset

# %%
n_scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)

# %% [markdown]
# ---
# ## Step 17 — store the results

# %%
results.append(n_scores)

# %% [markdown]
# ---
# ## Step 18 — report performance

# %%
print('>%s: %.3f (%.3f)' % (name, mean(n_scores), std(n_scores)))

# %% [markdown]
# ---
# ## Step 19 — plot the results for comparison

# %%
pyplot.boxplot(results, labels=[n for n,_ in models], showmeans=True)
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: comparison of data transform ensemble to each contributing member for classification 是机器学习中的常用技术。
#   *comparison of data transform ensemble to each contributing member for classification is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Classification Ensemble Compare / 分类
# Complete Code / 完整代码
# ===============================

# comparison of data transform ensemble to each contributing member for classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import RobustScaler
from sklearn.preprocessing import PowerTransformer
from sklearn.preprocessing import QuantileTransformer
from sklearn.preprocessing import KBinsDiscretizer
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.pipeline import Pipeline
from matplotlib import pyplot

# get a voting ensemble of models
def get_ensemble():
	# define the base models
	models = list()
	# normalization
	norm = Pipeline([('s', MinMaxScaler()), ('m', DecisionTreeClassifier())])
	models.append(('norm', norm))
	# standardization
	st = Pipeline([('s', StandardScaler()), ('m', DecisionTreeClassifier())])
	models.append(('std', st))
	# robust
	robust = Pipeline([('s', RobustScaler()), ('m', DecisionTreeClassifier())])
	models.append(('robust', robust))
	# power
	power = Pipeline([('s', PowerTransformer()), ('m', DecisionTreeClassifier())])
	models.append(('power', power))
	# quantile
	quant = Pipeline([('s', QuantileTransformer(n_quantiles=100, output_distribution='normal')), ('m', DecisionTreeClassifier())])
	models.append(('quant', quant))
	# kbins
	kbins = Pipeline([('s', KBinsDiscretizer(n_bins=20, encode='ordinal')), ('m', DecisionTreeClassifier())])
	models.append(('kbins', kbins))
	# define the voting ensemble
	ensemble = VotingClassifier(estimators=models, voting='hard')
	# return a list of tuples each with a name and model
	return models + [('ensemble', ensemble)]

# define dataset
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=1)
# get models
models = get_ensemble()
# evaluate each model
results = list()
for name, model in models:
	# define the evaluation method
	cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
	# evaluate the model on the dataset
	n_scores = cross_val_score(model, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
	# store the results
	results.append(n_scores)
	# report performance
	print('>%s: %.3f (%.3f)' % (name, mean(n_scores), std(n_scores)))
# plot the results for comparison
pyplot.boxplot(results, labels=[n for n,_ in models], showmeans=True)
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 7
