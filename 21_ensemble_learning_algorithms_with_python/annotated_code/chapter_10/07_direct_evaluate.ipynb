# %% [markdown]
# # 07 — Direct Evaluate / 模型评估
#
# **Chapter 10 — File 7 of 10 / 第10章 — 第7个文件（共10个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **example of evaluating direct multioutput regression with an SVM model**.
#
# 本脚本演示 **example of evaluating direct multioutput regression with an SVM model**。

# %% [markdown]
# ---
# ## Step 1 — example of evaluating direct multioutput regression with an SVM model

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.multioutput import MultiOutputRegressor
from sklearn.svm import LinearSVR

# %% [markdown]
# ---
# ## Step 2 — define dataset

# %%
X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, n_targets=2, random_state=1, noise=0.5)

# %% [markdown]
# ---
# ## Step 3 — define base model

# %%
model = LinearSVR()

# %% [markdown]
# ---
# ## Step 4 — define the direct multioutput wrapper model

# %%
wrapper = MultiOutputRegressor(model)

# %% [markdown]
# ---
# ## Step 5 — define the evaluation procedure

# %%
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ---
# ## Step 6 — evaluate the model and collect the scores

# %%
n_scores = cross_val_score(wrapper, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)

# %% [markdown]
# ---
# ## Step 7 — summarize performance

# %%
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: example of evaluating direct multioutput regression with an SVM model 是机器学习中的常用技术。
#   *example of evaluating direct multioutput regression with an SVM model is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Direct Evaluate / 模型评估
# Complete Code / 完整代码
# ===============================

# example of evaluating direct multioutput regression with an SVM model
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.multioutput import MultiOutputRegressor
from sklearn.svm import LinearSVR
# define dataset
X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, n_targets=2, random_state=1, noise=0.5)
# define base model
model = LinearSVR()
# define the direct multioutput wrapper model
wrapper = MultiOutputRegressor(model)
# define the evaluation procedure
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate the model and collect the scores
n_scores = cross_val_score(wrapper, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
# summarize performance
print('MAE: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 8 of 10
