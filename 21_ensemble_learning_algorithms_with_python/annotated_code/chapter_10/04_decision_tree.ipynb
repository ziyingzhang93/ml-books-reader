# %% [markdown]
# # 04 — Decision Tree / 决策树
#
# **Chapter 10 — File 4 of 10 / 第10章 — 第4个文件（共10个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **decision tree for multioutput regression**.
#
# 本脚本演示 **decision tree for multioutput regression**。

# %% [markdown]
# ---
# ## Step 1 — decision tree for multioutput regression

# %%
from sklearn.datasets import make_regression
from sklearn.tree import DecisionTreeRegressor

# %% [markdown]
# ---
# ## Step 2 — create datasets

# %%
X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, n_targets=2, random_state=1, noise=0.5)

# %% [markdown]
# ---
# ## Step 3 — define model

# %%
model = DecisionTreeRegressor()

# %% [markdown]
# ---
# ## Step 4 — fit model

# %%
model.fit(X, y)

# %% [markdown]
# ---
# ## Step 5 — make a prediction

# %%
row = [0.21947749, 0.32948997, 0.81560036, 0.440956, -0.0606303, -0.29257894, -0.2820059, -0.00290545, 0.96402263, 0.04992249]
yhat = model.predict([row])

# %% [markdown]
# ---
# ## Step 6 — summarize prediction

# %%
print(yhat[0])

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: decision tree for multioutput regression 是机器学习中的常用技术。
#   *decision tree for multioutput regression is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Decision Tree / 决策树
# Complete Code / 完整代码
# ===============================

# decision tree for multioutput regression
from sklearn.datasets import make_regression
from sklearn.tree import DecisionTreeRegressor
# create datasets
X, y = make_regression(n_samples=1000, n_features=10, n_informative=5, n_targets=2, random_state=1, noise=0.5)
# define model
model = DecisionTreeRegressor()
# fit model
model.fit(X, y)
# make a prediction
row = [0.21947749, 0.32948997, 0.81560036, 0.440956, -0.0606303, -0.29257894, -0.2820059, -0.00290545, 0.96402263, 0.04992249]
yhat = model.predict([row])
# summarize prediction
print(yhat[0])

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 5 of 10
