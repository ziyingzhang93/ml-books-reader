# %% [markdown]
# # 09 — Pool Classifiers Rf / 09 Pool Classifiers Rf
#
# **Chapter 12 — File 9 of 9 / 第12章 — 第9个文件（共9个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **evaluate KNORA-U with a random forest ensemble as the classifier pool**.
#
# 本脚本演示 **evaluate KNORA-U with a random forest ensemble as the classifier pool**。

# %% [markdown]
# ---
# ## Step 1 — evaluate KNORA-U with a random forest ensemble as the classifier pool

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from deslib.des.knora_u import KNORAU
from sklearn.ensemble import RandomForestClassifier
X, y = make_classification(n_samples=10000, n_features=20, n_informative=15, n_redundant=5, random_state=7)

# %% [markdown]
# ---
# ## Step 2 — split the dataset into train and test sets

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=1)

# %% [markdown]
# ---
# ## Step 3 — define classifiers to use in the pool

# %%
pool = RandomForestClassifier(n_estimators=1000)

# %% [markdown]
# ---
# ## Step 4 — fit the classifiers on the training set

# %%
pool.fit(X_train, y_train)

# %% [markdown]
# ---
# ## Step 5 — define the KNORA-U model

# %%
model = KNORAU(pool_classifiers=pool)

# %% [markdown]
# ---
# ## Step 6 — fit the model

# %%
model.fit(X_train, y_train)

# %% [markdown]
# ---
# ## Step 7 — make predictions on the test set

# %%
yhat = model.predict(X_test)

# %% [markdown]
# ---
# ## Step 8 — evaluate predictions

# %%
score = accuracy_score(y_test, yhat)
print('Accuracy: %.3f' % (score))

# %% [markdown]
# ---
# ## Step 9 — evaluate the standalone model

# %%
yhat = pool.predict(X_test)
score = accuracy_score(y_test, yhat)
print('>%s: %.3f' % (pool.__class__.__name__, score))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: evaluate KNORA-U with a random forest ensemble as the classifier pool 是机器学习中的常用技术。
#   *evaluate KNORA-U with a random forest ensemble as the classifier pool is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Pool Classifiers Rf / 09 Pool Classifiers Rf
# Complete Code / 完整代码
# ===============================

# evaluate KNORA-U with a random forest ensemble as the classifier pool
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from deslib.des.knora_u import KNORAU
from sklearn.ensemble import RandomForestClassifier
X, y = make_classification(n_samples=10000, n_features=20, n_informative=15, n_redundant=5, random_state=7)
# split the dataset into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=1)
# define classifiers to use in the pool
pool = RandomForestClassifier(n_estimators=1000)
# fit the classifiers on the training set
pool.fit(X_train, y_train)
# define the KNORA-U model
model = KNORAU(pool_classifiers=pool)
# fit the model
model.fit(X_train, y_train)
# make predictions on the test set
yhat = model.predict(X_test)
# evaluate predictions
score = accuracy_score(y_test, yhat)
print('Accuracy: %.3f' % (score))
# evaluate the standalone model
yhat = pool.predict(X_test)
score = accuracy_score(y_test, yhat)
print('>%s: %.3f' % (pool.__class__.__name__, score))
