# %% [markdown]
# # 06 — Regression Compare Standalone / 回归
#
# **Chapter 28 — File 6 of 8 / 第28章 — 第6个文件（共8个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **compare machine learning models for regression**.
#
# 本脚本演示 **compare machine learning models for regression**。

# %% [markdown]
# ---
# ## Step 1 — compare machine learning models for regression

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from matplotlib import pyplot

# %% [markdown]
# ---
# ## Step 2 — get the dataset

# %%
def get_dataset():
	X, y = make_regression(n_samples=1000, n_features=20, n_informative=15, noise=0.1, random_state=1)
	return X, y

# %% [markdown]
# ---
# ## Step 3 — get a list of models to evaluate

# %%
def get_models():
	models = dict()
	models['knn'] = KNeighborsRegressor()
	models['cart'] = DecisionTreeRegressor()
	models['svm'] = SVR()
	return models

# %% [markdown]
# ---
# ## Step 4 — evaluate a given model using cross-validation

# %%
def evaluate_model(model, X, y):

# %% [markdown]
# ---
# ## Step 5 — define the evaluation procedure

# %%
cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ---
# ## Step 6 — evaluate the model and collect the results

# %%
scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
	return scores

# %% [markdown]
# ---
# ## Step 7 — define dataset

# %%
X, y = get_dataset()

# %% [markdown]
# ---
# ## Step 8 — get the models to evaluate

# %%
models = get_models()

# %% [markdown]
# ---
# ## Step 9 — evaluate the models and store results

# %%
results, names = list(), list()
for name, model in models.items():

# %% [markdown]
# ---
# ## Step 10 — evaluate the model

# %%
scores = evaluate_model(model, X, y)

# %% [markdown]
# ---
# ## Step 11 — store the results

# %%
results.append(scores)
	names.append(name)

# %% [markdown]
# ---
# ## Step 12 — summarize the performance along the way

# %%
print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))

# %% [markdown]
# ---
# ## Step 13 — plot model performance for comparison

# %%
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: compare machine learning models for regression 是机器学习中的常用技术。
#   *compare machine learning models for regression is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Regression Compare Standalone / 回归
# Complete Code / 完整代码
# ===============================

# compare machine learning models for regression
from numpy import mean
from numpy import std
from sklearn.datasets import make_regression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedKFold
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from matplotlib import pyplot

# get the dataset
def get_dataset():
	X, y = make_regression(n_samples=1000, n_features=20, n_informative=15, noise=0.1, random_state=1)
	return X, y

# get a list of models to evaluate
def get_models():
	models = dict()
	models['knn'] = KNeighborsRegressor()
	models['cart'] = DecisionTreeRegressor()
	models['svm'] = SVR()
	return models

# evaluate a given model using cross-validation
def evaluate_model(model, X, y):
	# define the evaluation procedure
	cv = RepeatedKFold(n_splits=10, n_repeats=3, random_state=1)
	# evaluate the model and collect the results
	scores = cross_val_score(model, X, y, scoring='neg_mean_absolute_error', cv=cv, n_jobs=-1)
	return scores

# define dataset
X, y = get_dataset()
# get the models to evaluate
models = get_models()
# evaluate the models and store results
results, names = list(), list()
for name, model in models.items():
	# evaluate the model
	scores = evaluate_model(model, X, y)
	# store the results
	results.append(scores)
	names.append(name)
	# summarize the performance along the way
	print('>%s %.3f (%.3f)' % (name, mean(scores), std(scores)))
# plot model performance for comparison
pyplot.boxplot(results, labels=names, showmeans=True)
pyplot.show()

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 7 of 8
