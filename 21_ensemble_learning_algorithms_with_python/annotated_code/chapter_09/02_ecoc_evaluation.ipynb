# %% [markdown]
# # 02 — Ecoc Evaluation / 模型评估
#
# **Chapter 09 — File 2 of 4 / 第09章 — 第2个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **evaluate error-correcting output codes for multi-class classification**.
#
# 本脚本演示 **evaluate error-correcting output codes for multi-class classification**。

# %% [markdown]
# ---
# ## Step 1 — evaluate error-correcting output codes for multi-class classification

# %%
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OutputCodeClassifier

# %% [markdown]
# ---
# ## Step 2 — define dataset

# %%
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=1, n_classes=3)

# %% [markdown]
# ---
# ## Step 3 — define the binary classification model

# %%
model = LogisticRegression()

# %% [markdown]
# ---
# ## Step 4 — define the ecoc model

# %%
ecoc = OutputCodeClassifier(model, code_size=2, random_state=1)

# %% [markdown]
# ---
# ## Step 5 — define the evaluation procedure

# %%
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)

# %% [markdown]
# ---
# ## Step 6 — evaluate the model and collect the scores

# %%
n_scores = cross_val_score(ecoc, X, y, scoring='accuracy', cv=cv, n_jobs=-1)

# %% [markdown]
# ---
# ## Step 7 — summarize the performance

# %%
print('Mean Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: evaluate error-correcting output codes for multi-class classification 是机器学习中的常用技术。
#   *evaluate error-correcting output codes for multi-class classification is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Ecoc Evaluation / 模型评估
# Complete Code / 完整代码
# ===============================

# evaluate error-correcting output codes for multi-class classification
from numpy import mean
from numpy import std
from sklearn.datasets import make_classification
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OutputCodeClassifier
# define dataset
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=1, n_classes=3)
# define the binary classification model
model = LogisticRegression()
# define the ecoc model
ecoc = OutputCodeClassifier(model, code_size=2, random_state=1)
# define the evaluation procedure
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
# evaluate the model and collect the scores
n_scores = cross_val_score(ecoc, X, y, scoring='accuracy', cv=cv, n_jobs=-1)
# summarize the performance
print('Mean Accuracy: %.3f (%.3f)' % (mean(n_scores), std(n_scores)))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 4
