# %% [markdown]
# # 03 — Ecoc Predict / 03 Ecoc Predict
#
# **Chapter 09 — File 3 of 4 / 第09章 — 第3个文件（共4个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **use error-correcting output codes model as a final model and make a prediction**.
#
# 本脚本演示 **use error-correcting output codes model as a final model and make a prediction**。

# %% [markdown]
# ---
# ## Step 1 — use error-correcting output codes model as a final model and make a prediction

# %%
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OutputCodeClassifier

# %% [markdown]
# ---
# ## Step 2 — define dataset

# %%
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=1, n_classes=3)

# %% [markdown]
# ---
# ## Step 3 — define the binary classification model

# %%
model = LogisticRegression()

# %% [markdown]
# ---
# ## Step 4 — define the ecoc model

# %%
ecoc = OutputCodeClassifier(model, code_size=2, random_state=1)

# %% [markdown]
# ---
# ## Step 5 — fit the model on the whole dataset

# %%
ecoc.fit(X, y)

# %% [markdown]
# ---
# ## Step 6 — make a single prediction

# %%
row = [0.04339387, 2.75542632, -3.79522705, -0.71310994, -3.08888853, -1.2963487, -1.92065166, -3.15609907, 1.37532356, 3.61293237, 1.00353523, -3.77126962, 2.26638828, -10.22368666, -0.35137382, 1.84443763, 3.7040748, 2.50964286, 2.18839505, -2.31211692]
yhat = ecoc.predict([row])
print('Predicted Class: %d' % yhat[0])

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: use error-correcting output codes model as a final model and make a prediction 是机器学习中的常用技术。
#   *use error-correcting output codes model as a final model and make a prediction is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Ecoc Predict / 03 Ecoc Predict
# Complete Code / 完整代码
# ===============================

# use error-correcting output codes model as a final model and make a prediction
from sklearn.datasets import make_classification
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OutputCodeClassifier
# define dataset
X, y = make_classification(n_samples=1000, n_features=20, n_informative=15, n_redundant=5, random_state=1, n_classes=3)
# define the binary classification model
model = LogisticRegression()
# define the ecoc model
ecoc = OutputCodeClassifier(model, code_size=2, random_state=1)
# fit the model on the whole dataset
ecoc.fit(X, y)
# make a single prediction
row = [0.04339387, 2.75542632, -3.79522705, -0.71310994, -3.08888853, -1.2963487, -1.92065166, -3.15609907, 1.37532356, 3.61293237, 1.00353523, -3.77126962, 2.26638828, -10.22368666, -0.35137382, 1.84443763, 3.7040748, 2.50964286, 2.18839505, -2.31211692]
yhat = ecoc.predict([row])
print('Predicted Class: %d' % yhat[0])

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 4 of 4
