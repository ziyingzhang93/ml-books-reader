# %% [markdown]
# # 01 — Predict / Predict
#
# **Chapter 08 — File 3 of 3 / 第08章 — 第3个文件（共3个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Example of making a prediction with coefficients**.
#
# 本脚本演示 **Example of making a prediction with coefficients**。

# %% [markdown]
# ---
# ## Step 1 — Example of making a prediction with coefficients
# Make a prediction

# %%
def predict(row, coefficients):
	yhat = coefficients[0]
	for i in range(len(row)-1):
		yhat += coefficients[i + 1] * row[i]
	return yhat

dataset = [[1, 1], [2, 3], [4, 3], [3, 2], [5, 5]]
coef = [0.4, 0.8]
for row in dataset:
	yhat = predict(row, coef)
	print("Expected=%.3f, Predicted=%.3f" % (row[-1], yhat))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Example of making a prediction with coefficients 是机器学习中的常用技术。
#   *Example of making a prediction with coefficients is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Predict / Predict
# Complete Code / 完整代码
# ===============================

# Example of making a prediction with coefficients

# Make a prediction
def predict(row, coefficients):
	yhat = coefficients[0]
	for i in range(len(row)-1):
		yhat += coefficients[i + 1] * row[i]
	return yhat

dataset = [[1, 1], [2, 3], [4, 3], [3, 2], [5, 5]]
coef = [0.4, 0.8]
for row in dataset:
	yhat = predict(row, coef)
	print("Expected=%.3f, Predicted=%.3f" % (row[-1], yhat))
