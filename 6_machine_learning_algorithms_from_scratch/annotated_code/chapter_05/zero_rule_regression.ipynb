# %% [markdown]
# # 01 — Zero Rule Regression / 回归
#
# **Chapter 05 — File 3 of 3 / 第05章 — 第3个文件（共3个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Example of Zero Rule Regression Predictions**.
#
# 本脚本演示 **Example of Zero Rule Regression Predictions**。

# %% [markdown]
# ---
# ## Step 1 — Example of Zero Rule Regression Predictions

# %%
from random import seed

# %% [markdown]
# ---
# ## Step 2 — zero rule algorithm for regression

# %%
def zero_rule_algorithm_regression(train, test):
	output_values = [row[-1] for row in train]
	prediction = sum(output_values) / float(len(output_values))
	predicted = [prediction for i in range(len(test))]
	return predicted

seed(1)
train = [[10], [15], [12], [15], [18], [20]]
test = [[None], [None], [None], [None]]
predictions = zero_rule_algorithm_regression(train, test)
print(predictions)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Example of Zero Rule Regression Predictions 是机器学习中的常用技术。
#   *Example of Zero Rule Regression Predictions is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Zero Rule Regression / 回归
# Complete Code / 完整代码
# ===============================

# Example of Zero Rule Regression Predictions
from random import seed

# zero rule algorithm for regression
def zero_rule_algorithm_regression(train, test):
	output_values = [row[-1] for row in train]
	prediction = sum(output_values) / float(len(output_values))
	predicted = [prediction for i in range(len(test))]
	return predicted

seed(1)
train = [[10], [15], [12], [15], [18], [20]]
test = [[None], [None], [None], [None]]
predictions = zero_rule_algorithm_regression(train, test)
print(predictions)
