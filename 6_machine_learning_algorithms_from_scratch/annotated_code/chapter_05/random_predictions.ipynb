# %% [markdown]
# # 01 — Random Predictions / Random Predictions
#
# **Chapter 05 — File 1 of 3 / 第05章 — 第1个文件（共3个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Example of Making Random Predictions**.
#
# 本脚本演示 **Example of Making Random Predictions**。

# %% [markdown]
# ---
# ## Step 1 — Example of Making Random Predictions

# %%
from random import seed
from random import randrange

# %% [markdown]
# ---
# ## Step 2 — Generate random predictions

# %%
def random_algorithm(train, test):
	output_values = [row[-1] for row in train]
	unique = list(set(output_values))
	predicted = list()
	for _ in test:
		index = randrange(len(unique))
		predicted.append(unique[index])
	return predicted

seed(1)
train = [[0], [1], [0], [1], [0], [1]]
test = [[None], [None], [None], [None]]
predictions = random_algorithm(train, test)
print(predictions)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Example of Making Random Predictions 是机器学习中的常用技术。
#   *Example of Making Random Predictions is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Random Predictions / Random Predictions
# Complete Code / 完整代码
# ===============================

# Example of Making Random Predictions
from random import seed
from random import randrange

# Generate random predictions
def random_algorithm(train, test):
	output_values = [row[-1] for row in train]
	unique = list(set(output_values))
	predicted = list()
	for _ in test:
		index = randrange(len(unique))
		predicted.append(unique[index])
	return predicted

seed(1)
train = [[0], [1], [0], [1], [0], [1]]
test = [[None], [None], [None], [None]]
predictions = random_algorithm(train, test)
print(predictions)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 3
