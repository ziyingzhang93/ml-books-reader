# %% [markdown]
# # 01 — Zero Rule Classification / 分类
#
# **Chapter 05 — File 2 of 3 / 第05章 — 第2个文件（共3个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Example of Zero Rule Classification Predictions**.
#
# 本脚本演示 **Example of Zero Rule Classification Predictions**。

# %% [markdown]
# ---
# ## Step 1 — Example of Zero Rule Classification Predictions

# %%
from random import seed

# %% [markdown]
# ---
# ## Step 2 — zero rule algorithm for classification

# %%
def zero_rule_algorithm_classification(train, test):
	output_values = [row[-1] for row in train]
	prediction = max(set(output_values), key=output_values.count)
	predicted = [prediction for i in range(len(test))]
	return predicted

seed(1)
train = [['0'], ['0'], ['0'], ['0'], ['1'], ['1']]
test = [[None], [None], [None], [None]]
predictions = zero_rule_algorithm_classification(train, test)
print(predictions)

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Example of Zero Rule Classification Predictions 是机器学习中的常用技术。
#   *Example of Zero Rule Classification Predictions is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Zero Rule Classification / 分类
# Complete Code / 完整代码
# ===============================

# Example of Zero Rule Classification Predictions
from random import seed

# zero rule algorithm for classification
def zero_rule_algorithm_classification(train, test):
	output_values = [row[-1] for row in train]
	prediction = max(set(output_values), key=output_values.count)
	predicted = [prediction for i in range(len(test))]
	return predicted

seed(1)
train = [['0'], ['0'], ['0'], ['0'], ['1'], ['1']]
test = [[None], [None], [None], [None]]
predictions = zero_rule_algorithm_classification(train, test)
print(predictions)

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 3 of 3
