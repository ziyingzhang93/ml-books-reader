# %% [markdown]
# # 01 — Gaussian Pdf / Gaussian Pdf
#
# **Chapter 12 — File 1 of 6 / 第12章 — 第1个文件（共6个）**
#
# ---
#
# ## Summary / 总结
#
# This script demonstrates **Example of Gaussian PDF**.
#
# 本脚本演示 **Example of Gaussian PDF**。

# %% [markdown]
# ---
# ## Step 1 — Example of Gaussian PDF

# %%
from math import sqrt
from math import pi
from math import exp

# %% [markdown]
# ---
# ## Step 2 — Calculate the Gaussian probability distribution function for x

# %%
def calculate_probability(x, mean, stdev):
	exponent = exp(-((x-mean)**2 / (2 * stdev**2 )))
	return (1 / (sqrt(2 * pi) * stdev)) * exponent

# %% [markdown]
# ---
# ## Step 3 — Test Gaussian PDF

# %%
print(calculate_probability(1.0, 1.0, 1.0))
print(calculate_probability(2.0, 1.0, 1.0))
print(calculate_probability(0.0, 1.0, 1.0))

# %% [markdown]
# ---
# ## Learning Notes / 学习笔记
#
# - **概念**: Example of Gaussian PDF 是机器学习中的常用技术。
#   *Example of Gaussian PDF is a common technique in machine learning.*
#
# - **ML 应用**: 本示例展示了如何在实践中应用该技术。
#   *This example shows how to apply the technique in practice.*

# %% [markdown]
# ---
# ## Complete Code / 完整代码一览
#
# Below is the full code for quick reference. / 以下是完整代码，供快速参考。

# %%
# ===============================
# Gaussian Pdf / Gaussian Pdf
# Complete Code / 完整代码
# ===============================

# Example of Gaussian PDF
from math import sqrt
from math import pi
from math import exp

# Calculate the Gaussian probability distribution function for x
def calculate_probability(x, mean, stdev):
	exponent = exp(-((x-mean)**2 / (2 * stdev**2 )))
	return (1 / (sqrt(2 * pi) * stdev)) * exponent

# Test Gaussian PDF
print(calculate_probability(1.0, 1.0, 1.0))
print(calculate_probability(2.0, 1.0, 1.0))
print(calculate_probability(0.0, 1.0, 1.0))

# %% [markdown]
# ---
#
# ➡️ **Next / 下一步**: File 2 of 6
